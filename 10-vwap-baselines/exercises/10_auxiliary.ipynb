# %% [markdown]
# # Clase 10 — Auxiliares
#
# Profundización opcional sobre *VWAP I — Baselines de volumen*.

# %% [markdown]
# ### Auxiliares
#
# Profundización opcional, mismo formato: comprobación plegada + solución desplegable. No hacen falta para seguir el curso.

# %% [markdown]
# ### A1. El perfil se normaliza solo
#
# Comprueba que un perfil sin normalizar `[2,2,2,2,2]` ejecuta lo mismo que `[1,1,1,1,1]`: guarda ambos `executed` en `a` y `b`.
#
# <sub>practicas: pesos relativos</sub>

# %%
from exchange import Market, Backtest, Side
from exchange.strategies import VWAPStrategy
a = None
b = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(a - b) < 1e-9
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# from exchange import Market, Backtest, Side
# from exchange.strategies import VWAPStrategy
# def run(p):
#     r = Backtest(Market.sample(), VWAPStrategy('BTCUSDT', Side.BUY, 1.0, 5, profile=p)).run()
#     return sum(f.size for f in r.fills)
# a = run([2,2,2,2,2]); b = run([1,1,1,1,1])
# ```
#
# </details>

# %% [markdown]
# ## Fin de los auxiliares
#
# Vuelve al cuaderno principal cuando quieras.
