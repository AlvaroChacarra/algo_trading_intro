# %% [markdown]
# # 🐍 Clase 11 · VWAP II — Volumen dinámico
#
# > El perfil fijo asume que hoy es como la media. Pero el flujo reciente informa. Predecir el volumen del próximo intervalo a partir de los anteriores afina el schedule.
#
# **Hoy construyes:** predecir el perfil de volumen con datos recientes.

# %% [markdown]
# ### Cómo funciona este cuaderno
#
# 1. Escribe tu respuesta en la celda de código.
# 2. Debajo hay una **✅ comprobación plegada**: ejecútala con `Shift+Enter` para validarte (despliégala si quieres ver el `assert`).
# 3. ¿Atascado? Abre **💡 Ver solución**.
#
# **Núcleo:** los primeros (en clase) · **Si vamos bien:** el resto · **Más:** el cuaderno de auxiliares.

# %% [markdown]
# ### 1. Media rolada
#
# Escribe `rolling_mean(xs, k)` que devuelva la media de los últimos k elementos.
#
# <sub>practicas: ventana de los últimos k</sub>

# %%
def rolling_mean(xs, k):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(rolling_mean([1,2,3,4], 2) - 3.5) < 1e-9
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def rolling_mean(xs, k):
#     return sum(xs[-k:]) / k
# ```
#
# </details>

# %% [markdown]
# ### 2. Predice el próximo volumen
#
# Dada `volumes`, predice el siguiente como la media de los últimos 3. Guarda `pred`.
#
# <sub>practicas: usar la ventana</sub>

# %%
volumes = [100, 120, 90, 110, 130]
pred = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(pred - 110) < 1e-9
print('ok  pred=%.1f' % pred)

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# pred = sum(volumes[-3:]) / 3
# ```
#
# </details>

# %% [markdown]
# ### 3. Perfil dinámico
#
# Dadas predicciones `preds`, conviértelas en un perfil que sume 1. Guarda `profile`.
#
# <sub>practicas: normalizar predicciones</sub>

# %%
preds = [120, 80, 200]
profile = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(sum(profile) - 1) < 1e-9
assert profile[2] > profile[0] > profile[1], 'más peso donde más volumen'
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# total = sum(preds)
# profile = [p/total for p in preds]
# ```
#
# </details>

# %% [markdown]
# ### 4. Factor de corrección
#
# Escribe `correction(target_so_far, executed, remaining_slices)`: cuánto mandar ahora para volver al plan. Si vas por detrás, > lo normal.
#
# <sub>practicas: ir a tiempo</sub>

# %%
def correction(target_so_far, executed, remaining_slices):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(correction(0.5, 0.3, 2) - 0.1) < 1e-9, 'faltan 0.2 en 2 trozos -> 0.1'
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def correction(target_so_far, executed, remaining_slices):
#     return (target_so_far - executed) / remaining_slices
# ```
#
# </details>

# %% [markdown]
# ## Cierre
#
# No basta con la media histórica: el volumen de los últimos minutos también te dice qué viene.
#
# Si llegas al ejercicio 3 ya tienes el núcleo. Los siguientes y los auxiliares consolidan.
#
# **Siguiente clase:** seguimos construyendo el motor sobre esta pieza.
