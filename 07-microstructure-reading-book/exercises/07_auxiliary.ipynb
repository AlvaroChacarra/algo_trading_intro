# %% [markdown]
# # Clase 7 — Auxiliares · el gimnasio
#
# 2 ejercicios cortos sobre *Microestructura — Leer el libro*: drills para ganar soltura con las primitivas y profundizaciones opcionales.

# %% [markdown]
# ### El gimnasio
#
# Drills cortos para automatizar las primitivas de Python con datos de mercado, más una profundización final. Mismo formato de siempre: escribe tu código, ejecuta la **✅ comprobación plegada** (`Shift+Enter`) y, si te atascas, abre **💡 Ver solución**. Ninguno debería llevarte más de un par de minutos. No hacen falta para seguir el curso — pero te hacen rápido.
#
# **Dosis mínima:** el calentamiento entero + los dos primeros drills de cada bloque. El resto, para volver otro día.

# %% [markdown]
# ### A1. Spread medio de la sesión
#
# Recorre todos los snapshots y guarda `avg_spread`, la media del spread.
#
# <sub>practicas: recorrer el mercado</sub>

# %%
from exchange import Market
m = Market.sample()
avg_spread = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert avg_spread > 0
print('ok  avg_spread=%.2f' % avg_spread)

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# from exchange import Market
# m = Market.sample()
# spreads = []
# while True:
#     b = m.step()
#     if b is None: break
#     spreads.append(b.spread)
# avg_spread = sum(spreads) / len(spreads)
# ```
#
# </details>

# %% [markdown]
# ### A2. ¿Predice el imbalance?
#
# Cuenta cuántas veces, cuando `imbalance(1) > 0`, el mid del siguiente snapshot sube. Guarda el conteo en `up_after_positive`.
#
# <sub>practicas: señal vs siguiente mid</sub>

# %%
from exchange import Market
m = Market.sample()
up_after_positive = 0

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert up_after_positive >= 0
print('ok  veces que sube tras imbalance+:', up_after_positive)

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# from exchange import Market
# m = Market.sample()
# prev = m.step()
# up_after_positive = 0
# while True:
#     cur = m.step()
#     if cur is None: break
#     if prev.imbalance(1) is not None and prev.imbalance(1) > 0 and cur.mid > prev.mid:
#         up_after_positive += 1
#     prev = cur
# ```
#
# </details>

# %% [markdown]
# ## Fin de los auxiliares
#
# Vuelve al cuaderno principal cuando quieras.
