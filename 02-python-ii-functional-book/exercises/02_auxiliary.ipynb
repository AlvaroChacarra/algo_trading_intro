# %% [markdown]
# # Clase 2 — Auxiliares · el gimnasio
#
# 24 ejercicios cortos sobre *Python II — El libro funcional*: drills para ganar soltura con las primitivas y profundizaciones opcionales.

# %% [markdown]
# ### El gimnasio
#
# Drills cortos para automatizar las primitivas de Python con datos de mercado, más una profundización final. Mismo formato de siempre: escribe tu código, ejecuta la **✅ comprobación plegada** (`Shift+Enter`) y, si te atascas, abre **💡 Ver solución**. Ninguno debería llevarte más de un par de minutos. No hacen falta para seguir el curso — pero te hacen rápido.

# %% [markdown]
# ---
#
# ## 🏋️ Gimnasio · Bloque 1 — Funciones con oficio
#
# Defaults, devolver varias cosas y componer: las funciones dejan de ser cajas de una línea.

# %% [markdown]
# ### A1. Tu primera quote
#
# Escribe `make_quote(mid, spread)` que devuelva `(bid, ask)`: el mid menos/más medio spread.
#
# <sub>practicas: función que devuelve tupla</sub>

# %%
def make_quote(mid, spread):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
q = make_quote(99975, 50)
assert q == (99950.0, 100000.0), 'bid = mid - spread/2, ask = mid + spread/2'
print('ok ->', q)

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def make_quote(mid, spread):
#     return (mid - spread / 2, mid + spread / 2)
# ```
#
# </details>

# %% [markdown]
# ### A2. Comisión con default
#
# Escribe `fee(notional, bps=1)`: la comisión en unidades de cuenta. Si no te pasan `bps`, vale 1.
#
# <sub>practicas: parámetros por defecto</sub>

# %%
def fee(notional, bps=1):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(fee(100000) - 10.0) < 1e-9, 'sin bps usa el default de 1'
assert abs(fee(100000, 5) - 50.0) < 1e-9
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def fee(notional, bps=1):
#     return notional * bps / 10000
# ```
#
# </details>

# %% [markdown]
# ### A3. Al tick más cercano
#
# Escribe `round_to_tick(price, tick=10)`: redondea el precio al múltiplo de `tick` más cercano.
#
# > 💡 Divide por el tick, redondea, multiplica de vuelta.
#
# <sub>practicas: round dentro de una función</sub>

# %%
def round_to_tick(price, tick=10):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert round_to_tick(99973) == 99970
assert round_to_tick(99976) == 99980
assert round_to_tick(99973, 25) == 99975
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def round_to_tick(price, tick=10):
#     return round(price / tick) * tick
# ```
#
# </details>

# %% [markdown]
# ### A4. Spread en puntos básicos
#
# Escribe `spread_bps(bid, ask)`: el spread relativo al mid, en bps (`(ask - bid) / mid * 10000`).
#
# <sub>practicas: componer un cálculo</sub>

# %%
def spread_bps(bid, ask):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(spread_bps(99950, 100000) - 5.0012503) < 1e-4
print('ok -> ~5 bps')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def spread_bps(bid, ask):
#     mid = (bid + ask) / 2
#     return (ask - bid) / mid * 10000
# ```
#
# </details>

# %% [markdown]
# ### A5. La función que decide
#
# Escribe `classify_spread(spread)`: `'tight'` si ≤ 20, `'normal'` si ≤ 60, `'wide'` si no.
#
# <sub>practicas: lógica dentro de funciones</sub>

# %%
def classify_spread(spread):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert classify_spread(10) == 'tight'
assert classify_spread(50) == 'normal'
assert classify_spread(100) == 'wide'
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def classify_spread(spread):
#     if spread <= 20:
#         return 'tight'
#     elif spread <= 60:
#         return 'normal'
#     return 'wide'
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## 🏋️ Gimnasio · Bloque 2 — Tuplas y unpacking
#
# Devolver y desmontar pares de valores sin ceremonias.

# %% [markdown]
# ### A6. Desempaqueta la quote
#
# `quote` es una tupla `(bid, ask)`. Desempaquétala en `bid` y `ask` y calcula `mid`.
#
# <sub>practicas: unpacking</sub>

# %%
quote = (99950, 100000)
bid = None
ask = None
mid = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert bid == 99950 and ask == 100000
assert mid == 99975.0
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# bid, ask = quote
# mid = (bid + ask) / 2
# ```
#
# </details>

# %% [markdown]
# ### A7. El feed venía cruzado
#
# Este feed llegó invertido (bid > ask es imposible). Intercámbialos en **una sola línea** con unpacking.
#
# <sub>practicas: swap con tuplas</sub>

# %%
bid = 100000
ask = 99950
# una linea

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert bid == 99950 and ask == 100000
print('ok -> libro descruzado')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# bid, ask = ask, bid
# ```
#
# </details>

# %% [markdown]
# ### A8. Estadísticas del libro
#
# Escribe `book_stats(bids, asks)` que devuelva `(best_bid, best_ask, spread)`, y desempaqueta el resultado en tres variables.
#
# <sub>practicas: return múltiple</sub>

# %%
bids = [99930, 99950, 99940]
asks = [100010, 100005, 100020]
def book_stats(bids, asks):
    pass

best_bid, best_ask, spread = None, None, None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert (best_bid, best_ask, spread) == (99950, 100005, 55)
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def book_stats(bids, asks):
#     bb = max(bids)
#     ba = min(asks)
#     return bb, ba, ba - bb
#
# best_bid, best_ask, spread = book_stats(bids, asks)
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## 🏋️ Gimnasio · Bloque 3 — Dicts anidados: tu primer portfolio
#
# Un dict de dicts lleva la cuenta de N símbolos sin duplicar variables — el embrión del PositionTracker de la clase 5.

# %% [markdown]
# ### A9. Léelo
#
# Guarda `btc_position` y `eth_cash` leyendo el dict anidado (dos corchetes seguidos).
#
# <sub>practicas: acceso anidado</sub>

# %%
portfolio = {
    'BTCUSDT': {'position': 0.5, 'cash': -49975.0},
    'ETHUSDT': {'position': 2.0, 'cash': -7000.0},
}
btc_position = None
eth_cash = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert btc_position == 0.5
assert eth_cash == -7000.0
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# btc_position = portfolio['BTCUSDT']['position']
# eth_cash = portfolio['ETHUSDT']['cash']
# ```
#
# </details>

# %% [markdown]
# ### A10. Un fill lo mueve
#
# Ejecutas una compra de 0.1 BTC a 100000. Actualiza en `portfolio` la `position` (+0.1) y la `cash` (−0.1 × 100000) de BTCUSDT.
#
# <sub>practicas: escribir en anidado</sub>

# %%
portfolio = {
    'BTCUSDT': {'position': 0.5, 'cash': -49975.0},
    'ETHUSDT': {'position': 2.0, 'cash': -7000.0},
}
# actualiza el dict anidado

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(portfolio['BTCUSDT']['position'] - 0.6) < 1e-9
assert abs(portfolio['BTCUSDT']['cash'] - (-59975.0)) < 1e-9
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# portfolio['BTCUSDT']['position'] = portfolio['BTCUSDT']['position'] + 0.1
# portfolio['BTCUSDT']['cash'] = portfolio['BTCUSDT']['cash'] - 0.1 * 100000
# ```
#
# </details>

# %% [markdown]
# ### A11. Símbolo nuevo, con cuidado
#
# Vas a operar SOLUSDT. Si no está en `portfolio`, créalo con `{'position': 0.0, 'cash': 0.0}` — sin tocar los que ya existen.
#
# <sub>practicas: in + inicialización</sub>

# %%
portfolio = {
    'BTCUSDT': {'position': 0.5, 'cash': -49975.0},
    'ETHUSDT': {'position': 2.0, 'cash': -7000.0},
}
# comprueba y crea

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert portfolio['SOLUSDT'] == {'position': 0.0, 'cash': 0.0}
assert portfolio['BTCUSDT']['position'] == 0.5, 'no toques lo existente'
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# if 'SOLUSDT' not in portfolio:
#     portfolio['SOLUSDT'] = {'position': 0.0, 'cash': 0.0}
# ```
#
# </details>

# %% [markdown]
# ### A12. Recorre el portfolio
#
# Cuenta en `n_active` cuántos símbolos tienen posición distinta de 0, recorriendo con `.items()`.
#
# <sub>practicas: items()</sub>

# %%
portfolio = {
    'BTCUSDT': {'position': 0.5, 'cash': -49975.0},
    'ETHUSDT': {'position': 2.0, 'cash': -7000.0},
    'SOLUSDT': {'position': 0.0, 'cash': 0.0},
}
n_active = 0

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert n_active == 2
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# n_active = 0
# for sym, acct in portfolio.items():
#     if acct['position'] != 0:
#         n_active = n_active + 1
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## 🏋️ Gimnasio · Bloque 4 — Bucles avanzados
#
# while, break, continue, enumerate y zip: el control fino del flujo.

# %% [markdown]
# ### A13. Caída hasta el stop
#
# El precio cae 120 en cada tick. Simula con `while`: mientras `price > stop`, réstale 120 y cuenta los ticks en `n_ticks`.
#
# <sub>practicas: while</sub>

# %%
price = 100000
stop = 99500
n_ticks = 0
# while ...

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert price == 99400 and n_ticks == 5
print('ok -> el stop salta tras', n_ticks, 'ticks')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# n_ticks = 0
# while price > stop:
#     price = price - 120
#     n_ticks = n_ticks + 1
# ```
#
# </details>

# %% [markdown]
# ### A14. Primer nivel con tamaño
#
# Busca el precio del **primer** nivel con `size >= 0.2` y guárdalo en `first_ok`. Corta el bucle con `break` en cuanto lo encuentres.
#
# <sub>practicas: break</sub>

# %%
levels = [
    {'price': 99950, 'size': 0.05},
    {'price': 99940, 'size': 0.30},
    {'price': 99930, 'size': 0.50},
]
first_ok = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert first_ok == 99940, 'el primero que cumple, no el mas grande'
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# first_ok = None
# for lv in levels:
#     if lv['size'] >= 0.2:
#         first_ok = lv['price']
#         break
# ```
#
# </details>

# %% [markdown]
# ### A15. Ignora los ticks corruptos
#
# El feed mete precios imposibles (≤ 0). Calcula `clean_avg`, la media de los ticks válidos, saltando los corruptos con `continue`.
#
# <sub>practicas: continue</sub>

# %%
ticks = [99975, -1, 99990, 0, 100005]
total = 0
count = 0
# for ... continue
clean_avg = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(clean_avg - 99990.0) < 1e-9, 'la media de los 3 validos'
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# total = 0
# count = 0
# for t in ticks:
#     if t <= 0:
#         continue
#     total = total + t
#     count = count + 1
# clean_avg = total / count
# ```
#
# </details>

# %% [markdown]
# ### A16. ¿En qué posición está el mejor?
#
# Encuentra `best_i`, el índice del bid más alto, recorriendo con `enumerate` (sin usar `.index()`).
#
# <sub>practicas: enumerate</sub>

# %%
bids = [99930, 99950, 99940]
best_i = 0

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert best_i == 1
print('ok -> el mejor bid vive en la posicion', best_i)

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# best_i = 0
# for i, p in enumerate(bids):
#     if p > bids[best_i]:
#         best_i = i
# ```
#
# </details>

# %% [markdown]
# ### A17. Dos listas de la mano
#
# `prices` y `sizes` van en paralelo. Con `zip`, construye `notionals` (lista de `p*s`) y su `total`.
#
# <sub>practicas: zip</sub>

# %%
prices = [99950, 99960, 99970, 99980]
sizes = [0.1, 0.2, 0.3, 0.4]
notionals = []
total = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert len(notionals) == 4
assert all(abs(n - e) < 1e-6 for n, e in zip(notionals, [9995.0, 19992.0, 29991.0, 39992.0]))
assert abs(total - 99970.0) < 1e-6
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# notionals = []
# for p, s in zip(prices, sizes):
#     notionals.append(p * s)
# total = sum(notionals)
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## 🏋️ Gimnasio · Bloque 5 — Mini-retos del libro
#
# Comprensiones + todo lo anterior, aplicado al libro con el que cerraste el cuaderno principal.

# %% [markdown]
# ### A18. Nocionales en una línea
#
# Construye `notionals` (precio × tamaño de cada orden) con una comprensión de lista.
#
# <sub>practicas: comprensión de lista</sub>

# %%
book = [
    {'side':'buy','price':99980,'size':0.1}, {'side':'buy','price':99990,'size':0.2},
    {'side':'sell','price':100010,'size':0.15}, {'side':'sell','price':100005,'size':0.1},
]
notionals = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert len(notionals) == 4
assert abs(notionals[0] - 9998.0) < 1e-6
assert abs(sum(notionals) - 54998.0) < 1e-6
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# notionals = [o['price'] * o['size'] for o in book]
# ```
#
# </details>

# %% [markdown]
# ### A19. Filtra los grandes
#
# Quédate en `big_orders` solo con las órdenes de `size >= 0.15`, con una comprensión con `if`.
#
# <sub>practicas: comprensión con if</sub>

# %%
book = [
    {'side':'buy','price':99980,'size':0.1}, {'side':'buy','price':99990,'size':0.2},
    {'side':'sell','price':100010,'size':0.15}, {'side':'sell','price':100005,'size':0.1},
]
big_orders = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert len(big_orders) == 2
assert all(o['size'] >= 0.15 for o in big_orders)
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# big_orders = [o for o in book if o['size'] >= 0.15]
# ```
#
# </details>

# %% [markdown]
# ### A20. El VWAP de tus fills
#
# El precio medio ponderado por volumen: `vwap = Σ(p·s) / Σ(s)`. Calcúlalo — es el benchmark que perseguirás en la clase 12.
#
# <sub>practicas: sum con generador</sub>

# %%
fills = [
    {'price': 100000, 'size': 0.5},
    {'price': 99900, 'size': 1.0},
    {'price': 99950, 'size': 0.5},
]
vwap = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(vwap - 99937.5) < 1e-9
print('ok ->', vwap)

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# vwap = sum(f['price'] * f['size'] for f in fills) / sum(f['size'] for f in fills)
# ```
#
# </details>

# %% [markdown]
# ### A21. El gran reto: resumen del libro
#
# Escribe `book_summary(book)` que devuelva un dict con `best_bid`, `best_ask`, `spread` y `n_orders`.
#
# <sub>practicas: todo junto en una función</sub>

# %%
book = [
    {'side':'buy','price':99980,'size':0.1}, {'side':'buy','price':99990,'size':0.2},
    {'side':'sell','price':100010,'size':0.15}, {'side':'sell','price':100005,'size':0.1},
]
def book_summary(book):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
s = book_summary(book)
assert s['best_bid'] == 99990 and s['best_ask'] == 100005
assert s['spread'] == 15 and s['n_orders'] == 4
print('ok ->', s)

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def book_summary(book):
#     bb = max(o['price'] for o in book if o['side'] == 'buy')
#     ba = min(o['price'] for o in book if o['side'] == 'sell')
#     return {'best_bid': bb, 'best_ask': ba, 'spread': ba - bb, 'n_orders': len(book)}
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## 🏋️ Para terminar — el puente a la clase 3
#
# Los auxiliares clásicos: acumular sobre el libro, proteger tus datos y contar el dolor que resuelve la POO.

# %% [markdown]
# ### A22. Nocional total del libro
#
# Escribe `total_notional(book)` = suma de `price * size` de todas las órdenes.
#
# <sub>practicas: acumular sobre el libro</sub>

# %%
book = [{'price':100,'size':0.5},{'price':200,'size':0.25}]
def total_notional(book):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(total_notional(book) - 100) < 1e-9
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def total_notional(book):
#     return sum(o['price'] * o['size'] for o in book)
# ```
#
# </details>

# %% [markdown]
# ### A23. Órdenes con seguridad
#
# Haz que `make_order` lance `ValueError` si `side` no es `'buy'` ni `'sell'`. Las funciones también protegen tus datos.
#
# <sub>practicas: validar en una función</sub>

# %%
def make_order(symbol, side, price, size):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
try:
    make_order('X','byu',1,1)
    raise SystemExit('deberia haber fallado')
except ValueError:
    pass
assert make_order('X','buy',1,1)['side'] == 'buy'
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def make_order(symbol, side, price, size):
#     if side not in ('buy','sell'):
#         raise ValueError('side debe ser buy o sell')
#     return {'symbol': symbol, 'side': side, 'price': price, 'size': size}
# ```
#
# </details>

# %% [markdown]
# ### A24. Cuenta el problema
#
# ¿Cuántas de tus funciones reciben `book` como primer argumento (add, cancel, best_bid, best_ask, imbalance, spread, mid)? Guárdalo en `funcs_con_book`. En la clase 3 todas serán **métodos** de un objeto `OrderBook`.
#
# <sub>practicas: reflexión → POO</sub>

# %%
funcs_con_book = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert funcs_con_book == 7
print('ok -> un dato + las funciones que lo manosean = un OBJETO (clase 3)')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# funcs_con_book = 7
# ```
#
# </details>

# %% [markdown]
# ## Fin de los auxiliares
#
# Vuelve al cuaderno principal cuando quieras.
