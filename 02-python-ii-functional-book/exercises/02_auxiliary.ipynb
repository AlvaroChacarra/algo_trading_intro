# %% [markdown]
# # Clase 2 — Auxiliares
#
# Profundización opcional sobre *Python II — El libro funcional*.

# %% [markdown]
# ### Auxiliares
#
# Profundización opcional, mismo formato: comprobación plegada + solución desplegable. No hacen falta para seguir el curso.

# %% [markdown]
# ### A1. Spread y mid
#
# Usando best_bid/best_ask, escribe `spread(book)` y `mid(book)`.
#
# <sub>practicas: componer funciones</sub>

# %%
def best_bid(book):
    return max(o['price'] for o in book if o['side']=='buy')
def best_ask(book):
    return min(o['price'] for o in book if o['side']=='sell')
book = [{'side':'buy','price':100},{'side':'sell','price':102}]
def spread(book):
    pass
def mid(book):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert spread(book) == 2
assert mid(book) == 101
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def spread(book):
#     return best_ask(book) - best_bid(book)
# def mid(book):
#     return (best_bid(book) + best_ask(book)) / 2
# ```
#
# </details>

# %% [markdown]
# ### A2. Nocional total
#
# Escribe `total_notional(book)` = suma de price*size de todas las órdenes.
#
# <sub>practicas: acumular sobre el libro</sub>

# %%
book = [{'price':100,'size':0.5},{'price':200,'size':0.25}]
def total_notional(book):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(total_notional(book) - 100) < 1e-9
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def total_notional(book):
#     return sum(o['price'] * o['size'] for o in book)
# ```
#
# </details>

# %% [markdown]
# ### A3. Cuenta el problema
#
# Define `funcs_que_reciben_book = 5` (add, cancel, best_bid, best_ask, imbalance). En la próxima clase, todas serán métodos de un objeto `OrderBook`.
#
# <sub>practicas: reflexión + conteo</sub>

# %%
funcs_que_reciben_book = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert funcs_que_reciben_book == 5
print('ok — eso es composición pidiendo una clase')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# funcs_que_reciben_book = 5
# ```
#
# </details>

# %% [markdown]
# ## Fin de los auxiliares
#
# Vuelve al cuaderno principal cuando quieras.
