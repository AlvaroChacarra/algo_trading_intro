# %% [markdown]
# # Clase 2 · Tu proyecto
#
# En L1 calculaste una quote. Hoy obtienes los mejores precios entre varias órdenes, con una función reutilizable.

# %% [markdown]
# <a id="L02-P01"></a>
#
# ### Leer varias órdenes
#
# Abre [functional.py](../../student_project/exchange/functional.py). Completa `best_prices(orders)`; `make_order` ya está proporcionada.
#
# Recibe una lista de órdenes con `side` y `price`. Devuelve `(mejor_bid, mejor_ask)`: el mayor precio de compra y el menor de venta. Un lado sin órdenes devuelve `None`; no modifiques la lista recibida.
#
# Con compras a 98 y 99 y ventas a 102 y 101 esperamos `(99, 101)`. Solo compras → `(99, None)`; lista vacía → `(None, None)`.
#
# <details><summary>Pista</summary>
#
# Separa los precios de cada lado con un bucle o una comprensión. Comprueba que hay precios antes de llamar a `max` o `min`. `return bid, ask` devuelve ambos valores juntos.
#
# </details>
#
# Guarda el archivo y ejecuta la comprobación siguiente con **Shift+Enter**.

# %%
from practice_checks import comprobar_proyecto
comprobar_proyecto(2)

# %% [markdown]
# En L3 importarás esta misma función desde otro archivo.
