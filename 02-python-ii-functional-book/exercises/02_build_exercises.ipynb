# %% [markdown]
# # Clase 2 · Construcción en clase
#
# En el notebook, convierte la lectura de varias órdenes en best_prices. Después usa la misma función en un programa Python.
#
# Guarda una copia como **mi_principal.ipynb** aquí. Completa y ejecuta las celdas de arriba abajo con **Shift+Enter**. Compara las salidas con lo esperado. `None` o `pass` marcan una respuesta pendiente.
#
# Al terminar: **Restart Kernel and Run All Cells** para comprobar que no dependes de ejecuciones antiguas.

# %% [markdown]
# <a id="L02-P01"></a>
#
# ### Leer varias órdenes
#
# Completa `best_prices(orders)`: recibe una lista de órdenes y devuelve `(bid, ask)`.
#
# El bid es el mayor precio de compra; el ask, el menor de venta. Si falta un lado, su precio es `None`. Conserva la lista y sus órdenes sin modificarlas.
#
# Predice el par para el libro dado. Después ejecuta la función con ambos lados, solo compras, solo ventas y una lista vacía.

# %%
orders = [
    {'side': 'buy', 'price': 98, 'size': 1},
    {'side': 'sell', 'price': 103, 'size': 2},
    {'side': 'buy', 'price': 99, 'size': 4},
    {'side': 'sell', 'price': 101, 'size': 1},
]
def best_prices(orders):
    # Selecciona un precio por lado y devuelve el par.
    pass

# %%
print('ambos lados:', best_prices(orders))
print('solo compras:', best_prices([{'side': 'buy', 'price': 99}]))
print('solo ventas:', best_prices([{'side': 'sell', 'price': 101}]))
print('vacío:', best_prices([]))
print('libro después:', orders)

# %% [markdown]
# **Resultado esperado:** Ambos lados: `(99, 101)`; solo compras: `(99, None)`; solo ventas: `(None, 101)`; vacío: `(None, None)`. El libro conserva sus cuatro órdenes en el mismo orden.

# %% [markdown]
# <details>
# <summary>Pista</summary>
#
# Separa los precios por lado. Comprueba si hay candidatos antes de aplicar `max` o `min`; `return bid, ask` devuelve ambos juntos.
#
# </details>

# %% [markdown]
# ## El mismo ejercicio como programa
#
# El notebook sirve para investigar por partes. Un `.py` ejecuta un programa entero y permite reutilizar funciones.
#
# Copia **main.py** como **mi_main.py** aquí y traslada las mismas respuestas. `main()` reúne las llamadas; la condición final lo inicia al ejecutar el archivo. Lo estudiaremos en L3.
#
# Desde esta carpeta `exercises`:
#
# ```bash
# python mi_main.py
# ```
#
# Deben salir los mismos resultados. El notebook ya cubre el ejercicio.
#
# En L3 reutilizarás tu best_prices para describir el mercado y distinguirás ejecutar un archivo de importar sus funciones.
