# %% [markdown]
# # 🐍 Clase 2 · Python II — El libro funcional
#
# > Pasar de scripts sueltos a funciones que construyen y modifican un libro de órdenes. Al final verás por qué tantas funciones compartiendo el mismo libro piden ser un objeto.
#
# **Hoy construyes:** funciones add_order / cancel / imbalance.
#
# ⏱️ 🟢 núcleo ~17 min · 🔵 si vamos bien +30 min · 🟣 bonus +2 min.

# %% [markdown]
# ### Cómo funciona este cuaderno
#
# 1. Escribe tu respuesta en la celda de código.
# 2. Debajo hay una **✅ comprobación plegada**: ejecútala con `Shift+Enter` para validarte (despliégala si quieres ver el `assert`).
# 3. ¿Atascado? Algunos ejercicios traen una **💭 Pista** intermedia; si no basta, abre **💡 Ver solución**.
#
# Cada ejercicio lleva su etiqueta: **🟢 núcleo** (en clase) · **🔵 si vamos bien** · **🟣 bonus** (el cuaderno de auxiliares profundiza más).

# %% [markdown]
# ### 1. Tu fábrica de órdenes
#
# <sub>🟢 núcleo · ~5 min</sub>
#
# Escribe `make_order(symbol, side, price, size)` que **devuelva** el dict de la orden. Una función-fábrica: la llamas con distintos datos y te construye la orden.
#
# > 💡 El cuerpo es un solo `return` con el dict.
#
# <sub>practicas: funciones que devuelven datos</sub>

# %%
def make_order(symbol, side, price, size):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert make_order.__code__.co_consts != (None,), '⏸ implementa make_order: su cuerpo sigue siendo pass'
o = make_order('BTCUSDT','buy',99950,0.10)
assert o == {'symbol':'BTCUSDT','side':'buy','price':99950,'size':0.10}
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def make_order(symbol, side, price, size):
#     return {'symbol': symbol, 'side': side, 'price': price, 'size': size}
# ```
#
# </details>

# %% [markdown]
# ### 2. Añade al libro
#
# <sub>🟢 núcleo · ~5 min</sub>
#
# Escribe `add_order(book, order)` que añada la orden al libro y lo **devuelva**.
#
# > 💡 `book.append(order)` y luego `return book`.
#
# <sub>practicas: listas: append</sub>

# %%
def add_order(book, order):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert add_order.__code__.co_consts != (None,), '⏸ implementa add_order: su cuerpo sigue siendo pass'
b = add_order([], {'side':'buy'})
assert b == [{'side':'buy'}]
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def add_order(book, order):
#     book.append(order)
#     return book
# ```
#
# </details>

# %% [markdown]
# ### 3. Cancela una orden, paso a paso
#
# <sub>🟢 núcleo · ~4 min</sub>
#
# Escribe `cancel_order(book, order_id)` con `result = []`, un `for` y `append`. Debe devolver una lista **nueva** sin la orden cuyo `id` coincide.
#
# > 💡 Recorre las órdenes y añade a `result` solo las que tengan otro id.
#
# <sub>practicas: for + if + append</sub>

# %%
book = [{'id':1,'side':'buy'},{'id':2,'side':'sell'}]
def cancel_order(book, order_id):
    result = []
    # recorre, filtra y devuelve result

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
out = cancel_order(book, 1)
assert out == [{'id':2,'side':'sell'}]
assert book == [{'id':1,'side':'buy'},{'id':2,'side':'sell'}], 'book original no cambia'
assert book is not out, 'debe ser otra lista'
print('ok -> book is out:', book is out)

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def cancel_order(book, order_id):
#     result = []
#     for o in book:
#         if o['id'] != order_id:
#             result.append(o)
#     return result
# ```
#
# </details>

# %% [markdown]
# ### 4. Comprime el filtro
#
# <sub>🟢 núcleo · ~3 min</sub>
#
# Reescribe la misma `cancel_order` con una comprensión. La conducta debe ser idéntica: lista nueva, orden original intacta.
#
# <sub>practicas: list comprehension</sub>

# %%
book = [{'id':1,'side':'buy'},{'id':2,'side':'sell'}]
def cancel_order(book, order_id):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert cancel_order.__code__.co_consts != (None,), '⏸ implementa cancel_order: su cuerpo sigue siendo pass'
out = cancel_order(book, 1)
assert out == [{'id':2,'side':'sell'}]
assert book is not out and len(book) == 2
print('ok -> misma conducta, menos sintaxis')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def cancel_order(book, order_id):
#     return [o for o in book if o['id'] != order_id]
# ```
#
# </details>

# %% [markdown]
# ### 5. Mejor bid y mejor ask
#
# <sub>🔵 si vamos bien · ~6 min</sub>
#
# Escribe `best_bid(book)` (precio de compra más **alto**) y `best_ask(book)` (precio de venta más **bajo**).
#
# <sub>practicas: max / min con filtro</sub>

# %%
book = [{'side':'buy','price':99980},{'side':'sell','price':100010},{'side':'buy','price':99990}]
def best_bid(book):
    pass

def best_ask(book):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert best_bid.__code__.co_consts != (None,), '⏸ implementa best_bid: su cuerpo sigue siendo pass'
assert best_ask.__code__.co_consts != (None,), '⏸ implementa best_ask: su cuerpo sigue siendo pass'
assert best_bid(book) == 99990
assert best_ask(book) == 100010
print('ok')

# %% [markdown]
# <details>
# <summary>💭 Pista (antes de mirar la solución)</summary>
#
# Filtra dentro de la expresión generadora: `max(o['price'] for o in book if o['side']=='buy')`. Para el ask, cambia `max` por `min` y el lado.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def best_bid(book):
#     return max(o['price'] for o in book if o['side']=='buy')
#
# def best_ask(book):
#     return min(o['price'] for o in book if o['side']=='sell')
# ```
#
# </details>

# %% [markdown]
# ### 6. Imbalance del libro
#
# <sub>🔵 si vamos bien · ~6 min</sub>
#
# Escribe `imbalance(book)` = (vol_compra − vol_venta) / (vol_compra + vol_venta), en [−1, 1]. Cerca de +1 = empuja a comprar.
#
# <sub>practicas: presión compra/venta</sub>

# %%
book = [{'side':'buy','size':3},{'side':'sell','size':1}]
def imbalance(book):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert imbalance.__code__.co_consts != (None,), '⏸ implementa imbalance: su cuerpo sigue siendo pass'
assert abs(imbalance(book) - 0.5) < 1e-9, 'imbalance debe ser 0.5'
print('ok')

# %% [markdown]
# <details>
# <summary>💭 Pista (antes de mirar la solución)</summary>
#
# Suma primero cada lado en dos variables (`b` y `s`) con `sum(o['size'] for o in book if ...)`; la fórmula final es `(b - s) / (b + s)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def imbalance(book):
#     b = sum(o['size'] for o in book if o['side']=='buy')
#     s = sum(o['size'] for o in book if o['side']=='sell')
#     return (b - s) / (b + s)
# ```
#
# </details>

# %% [markdown]
# ### 7. Spread y mid, componiendo funciones
#
# <sub>🔵 si vamos bien · ~6 min</sub>
#
# Usando `best_bid` y `best_ask` ya escritas, define `spread(book)` y `mid(book)`. Una función puede llamar a otras.
#
# <sub>practicas: componer funciones</sub>

# %%
def best_bid(book):
    return max(o['price'] for o in book if o['side']=='buy')
def best_ask(book):
    return min(o['price'] for o in book if o['side']=='sell')
book = [{'side':'buy','price':100},{'side':'sell','price':102}]
def spread(book):
    pass

def mid(book):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert spread.__code__.co_consts != (None,), '⏸ implementa spread: su cuerpo sigue siendo pass'
assert mid.__code__.co_consts != (None,), '⏸ implementa mid: su cuerpo sigue siendo pass'
assert spread(book) == 2
assert mid(book) == 101
print('ok')

# %% [markdown]
# <details>
# <summary>💭 Pista (antes de mirar la solución)</summary>
#
# No repitas lógica: dentro de `spread` llama a `best_ask(book) - best_bid(book)`. `mid` es la media de esas dos mismas llamadas.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def spread(book):
#     return best_ask(book) - best_bid(book)
#
# def mid(book):
#     return (best_bid(book) + best_ask(book)) / 2
# ```
#
# </details>

# %% [markdown]
# ### 8. Construye y lee tu libro
#
# <sub>🔵 si vamos bien · ~6 min</sub>
#
# Júntalo todo. Con `make_order` y `add_order`, monta un libro con: compra 99980 (0.10), compra 99990 (0.20), venta 100010 (0.15). Luego léelo: guarda `bb = best_bid`, `sp = spread (best_ask − best_bid)` e `imb = imbalance`.
#
# > 💡 Empieza `book = []` y añade tres órdenes.
#
# <sub>practicas: juntar todas las funciones</sub>

# %%
def make_order(symbol, side, price, size):
    return {'symbol': symbol, 'side': side, 'price': price, 'size': size}
def add_order(book, order):
    book.append(order); return book
def best_bid(book):
    return max(o['price'] for o in book if o['side']=='buy')
def best_ask(book):
    return min(o['price'] for o in book if o['side']=='sell')
def imbalance(book):
    b=sum(o['size'] for o in book if o['side']=='buy'); s=sum(o['size'] for o in book if o['side']=='sell'); return (b-s)/(b+s)
book = []
# anade 3 ordenes y calcula bb, sp, imb

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert bb == 99990, 'best_bid debe ser 99990'
assert abs(sp - 20) < 1e-9, 'spread debe ser 20'
assert abs(imb - 1/3) < 1e-9, 'imbalance debe ser 0.333...'
print('ok  libro leido ->', bb, sp, round(imb,3))

# %% [markdown]
# <details>
# <summary>💭 Pista (antes de mirar la solución)</summary>
#
# Cada alta es `book = add_order(book, make_order('BTCUSDT', lado, precio, tamaño))`. Después, tres llamadas de lectura sobre el mismo `book`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# book = []
# book = add_order(book, make_order('BTCUSDT','buy',99980,0.10))
# book = add_order(book, make_order('BTCUSDT','buy',99990,0.20))
# book = add_order(book, make_order('BTCUSDT','sell',100010,0.15))
# bb = best_bid(book)
# sp = best_ask(book) - best_bid(book)
# imb = imbalance(book)
# ```
#
# </details>

# %% [markdown]
# ### 9. Lista nueva no significa deep copy
#
# <sub>🔵 si vamos bien · ~3 min</sub>
#
# Cancela la orden 1 y guarda `new_list` y `same_order`: comprueba si la orden id=2 dentro de ambas listas sigue siendo el **mismo dict**.
#
# <sub>practicas: identidad y referencias</sub>

# %%
book = [{'id':1,'size':0.5},{'id':2,'size':0.2}]
def cancel_order(book, order_id):
    return [o for o in book if o['id'] != order_id]
new_list = None
same_order = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert new_list is not None, '⏸ new_list sigue en None: completa el ejercicio antes de validar'
assert same_order is not None, '⏸ same_order sigue en None: completa el ejercicio antes de validar'
assert new_list is not book, 'la lista exterior es nueva'
assert same_order is True, 'los dicts interiores no se copiaron'
print('ok -> nueva lista, mismos objetos supervivientes')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# new_list = cancel_order(book, 1)
# same_order = new_list[0] is book[1]
# ```
#
# </details>

# %% [markdown]
# ### 10. Una función como criterio
#
# <sub>🔵 si vamos bien · ~3 min</sub>
#
# Define `get_price(order)` y úsala como `key` para ordenar `orders` de menor a mayor precio. Pasa la función, no su resultado.
#
# <sub>practicas: sorted(key=get_price)</sub>

# %%
orders = [{'id':'A','price':105},{'id':'B','price':100},{'id':'C','price':110}]
def get_price(order):
    pass

ordered = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert ordered is not None, '⏸ ordered sigue en None: completa el ejercicio antes de validar'
assert get_price.__code__.co_consts != (None,), '⏸ implementa get_price: su cuerpo sigue siendo pass'
assert [o['id'] for o in ordered] == ['B','A','C']
assert get_price(orders[0]) == 105
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def get_price(order):
#     return order['price']
#
# ordered = sorted(orders, key=get_price)
# ```
#
# </details>

# %% [markdown]
# ### 11. Sustituye el nombre por lambda
#
# <sub>🟣 bonus · ~2 min</sub>
#
# Ordena las mismas órdenes con `key=lambda order: order['price']`. Guarda el resultado en `ordered`.
#
# <sub>practicas: lambda como callback</sub>

# %%
orders = [{'id':'A','price':105},{'id':'B','price':100},{'id':'C','price':110}]
ordered = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert ordered is not None, '⏸ ordered sigue en None: completa el ejercicio antes de validar'
assert [o['id'] for o in ordered] == ['B','A','C']
print('ok -> misma salida')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# ordered = sorted(orders, key=lambda order: order['price'])
# ```
#
# </details>

# %% [markdown]
# ## Cierre
#
# Funciones sueltas que comparten el mismo estado están pidiendo a gritos ser un objeto.
#
# Si llegas al ejercicio 3 ya tienes el núcleo. Los siguientes y los auxiliares consolidan.
#
# **Siguiente clase:** seguimos construyendo el motor sobre esta pieza.

# %% [markdown]
# ## 🚀 Llévatelo a un `.py`
#
# Un notebook va genial para explorar, pero el código de verdad vive en archivos `.py` que se ejecutan enteros de una vez. Abre **`order_book.py`**: es lo que acabas de construir, ordenado y de una pieza.
#
# Ejecútalo desde una terminal:
#
# ```bash
# python order_book.py
# ```
#
# …o aquí mismo, en la siguiente celda:

# %%
# !python order_book.py

# %% [markdown]
# > En la **clase 4** este código dará el salto a **clases** (POO): el mismo código, mejor organizado.
