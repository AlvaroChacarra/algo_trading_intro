# %% [markdown]
# # Clase 3 — Auxiliares
#
# Profundización opcional sobre *OOP I — Order y Trade*.

# %% [markdown]
# ## Ejercicios auxiliares
#
# Profundización opcional para consolidar fuera de clase. No hacen falta para seguir el curso.

# %% [markdown]
# ## A1. Lados con seguridad
#
# **Practicas:** validar en __init__.
#
# Haz que `Order.__init__` lance `ValueError` si `side` no es 'buy' ni 'sell'.

# %%
class Order:
    def __init__(self, symbol, side, price, size):
        pass

# %%
try:
    Order('X','byu',1,1); raise SystemExit('deberia fallar')
except ValueError:
    print('ok')

# %% [markdown]
# ### Solución guiada
#
# ```python
# class Order:
#     def __init__(self, symbol, side, price, size):
#         if side not in ('buy','sell'):
#             raise ValueError('side debe ser buy o sell')
#         self.symbol=symbol; self.side=side; self.price=price; self.size=size
# ```

# %% [markdown]
# ## A2. El paquete real
#
# **Practicas:** usar exchange.orders.
#
# Importa `Order` y `Side` de `exchange.orders` y crea una orden de compra. Comprueba `order.notional()`.

# %%
from exchange.orders import Order, Side
order = None

# %%
from exchange.orders import Order
assert isinstance(order, Order)
assert abs(order.notional() - order.price*order.size) < 1e-9
print('ok')

# %% [markdown]
# ### Solución guiada
#
# ```python
# from exchange.orders import Order, Side
# order = Order('BTCUSDT', Side.BUY, 0.5, price=100)
# ```

# %% [markdown]
# ## Fin de los auxiliares
#
# Vuelve al cuaderno principal cuando quieras.
