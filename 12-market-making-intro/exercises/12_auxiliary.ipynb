# %% [markdown]
# # Clase 12 — Auxiliares
#
# Profundización opcional sobre *Market making — Intro*.

# %% [markdown]
# ## Ejercicios auxiliares
#
# Profundización opcional para consolidar fuera de clase. No hacen falta para seguir el curso.

# %% [markdown]
# ## A1. Utilidad CARA
#
# **Practicas:** aversión al riesgo.
#
# Escribe `cara_utility(wealth, gamma)` = -exp(-gamma * wealth). Más gamma = más aversión. Comprueba que es creciente en wealth.

# %%
import math
def cara_utility(wealth, gamma):
    pass

# %%
assert cara_utility(10, 0.1) > cara_utility(5, 0.1)
print('ok')

# %% [markdown]
# ### Solución guiada
#
# ```python
# import math
# def cara_utility(wealth, gamma):
#     return -math.exp(-gamma * wealth)
# ```

# %% [markdown]
# ## Fin de los auxiliares
#
# Vuelve al cuaderno principal cuando quieras.
