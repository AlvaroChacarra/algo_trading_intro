# %% [markdown]
# # 🐍 Clase 5 · Microestructura — Leer el libro
#
# > Cargar 500 snapshots reales de BTCUSDT y leer el mercado: spread, mid, imbalance, microprice y profundidad. El OrderBook deja de ser una foto y se vuelve una lente.
#
# **Hoy construyes:** métricas de mercado sobre snapshots reales de BTC.

# %% [markdown]
# ### Cómo funciona este cuaderno
#
# 1. Escribe tu respuesta en la celda de código.
# 2. Debajo hay una **✅ comprobación plegada**: ejecútala con `Shift+Enter` para validarte (despliégala si quieres ver el `assert`).
# 3. ¿Atascado? Abre **💡 Ver solución**.
#
# **Núcleo:** los primeros (en clase) · **Si vamos bien:** el resto · **Más:** el cuaderno de auxiliares.

# %% [markdown]
# ### 1. Carga el mercado
#
# Crea `m = Market.sample()` y avanza un snapshot: `book = m.step()`. Guarda `n = len(m)`.
#
# <sub>practicas: Market.sample y step</sub>

# %%
from exchange import Market
# m, book, n

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
from exchange import OrderBook
assert n == 500, 'deben ser 500 snapshots'
assert isinstance(book, OrderBook)
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# from exchange import Market
# m = Market.sample()
# book = m.step()
# n = len(m)
# ```
#
# </details>

# %% [markdown]
# ### 2. Spread y mid del primer snapshot
#
# Del `book`, guarda `spread` y `mid`.
#
# <sub>practicas: propiedades del libro</sub>

# %%
from exchange import Market
book = Market.sample().step()
spread = None
mid = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert spread > 0, 'el spread debe ser positivo'
assert book.best_bid < mid < book.best_ask
print('ok  spread=%.2f mid=%.2f' % (spread, mid))

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# spread = book.spread
# mid = book.mid
# ```
#
# </details>

# %% [markdown]
# ### 3. Imbalance a 1 y 5 niveles
#
# Guarda `imb1 = book.imbalance(1)` e `imb5 = book.imbalance(5)`. Ambos en [-1, 1].
#
# <sub>practicas: imbalance(levels)</sub>

# %%
from exchange import Market
book = Market.sample().step()
imb1 = None
imb5 = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert -1 <= imb1 <= 1 and -1 <= imb5 <= 1
print('ok  imb1=%.3f imb5=%.3f' % (imb1, imb5))

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# imb1 = book.imbalance(1)
# imb5 = book.imbalance(5)
# ```
#
# </details>

# %% [markdown]
# ### 4. Microprice
#
# Guarda `micro = book.microprice`. Debe caer entre best_bid y best_ask.
#
# <sub>practicas: microprice</sub>

# %%
from exchange import Market
book = Market.sample().step()
micro = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert book.best_bid <= micro <= book.best_ask
print('ok  micro=%.2f mid=%.2f' % (micro, book.mid))

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# micro = book.microprice
# ```
#
# </details>

# %% [markdown]
# ### 5. Profundidad por lado
#
# Importa `Side` y guarda `bid_depth` y `ask_depth` sumando 5 niveles de cada lado.
#
# <sub>practicas: depth(side, levels)</sub>

# %%
from exchange import Market
book = Market.sample().step()
from exchange import Side
bid_depth = None
ask_depth = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert bid_depth > 0 and ask_depth > 0
print('ok  bid=%.2f ask=%.2f' % (bid_depth, ask_depth))

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# from exchange import Side
# bid_depth = book.depth(Side.BUY, 5)
# ask_depth = book.depth(Side.SELL, 5)
# ```
#
# </details>

# %% [markdown]
# ## Cierre
#
# El imbalance y el microprice te dicen hacia dónde empuja el libro antes de que se mueva el mid.
#
# Si llegas al ejercicio 3 ya tienes el núcleo. Los siguientes y los auxiliares consolidan.
#
# **Siguiente clase:** seguimos construyendo el motor sobre esta pieza.
