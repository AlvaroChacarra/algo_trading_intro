# %% [markdown]
# # 📊 **Limit Order Book (LOB) - Dinámica Visual**
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; color: white; text-align: center;">
#     <h2>🚀 Entendiendo la Mecánica de los Mercados Financieros</h2>
#     <p><i>"El corazón de todos los mercados electrónicos modernos"</i></p>
# </div>
#
# ---
#
# ## 🎯 **¿Qué aprenderemos hoy?**
#
# En este notebook exploraremos **visualmente** cómo funciona un **Limit Order Book**, el mecanismo fundamental que impulsa los mercados financieros modernos.
#
# ### 📋 **Agenda del Tutorial:**
# 1. 🔍 **Conceptos Fundamentales** - ¿Qué es un LOB?
# 2. 📈 **Visualización Estática** - Componentes básicos
# 3. ⚡ **Simulación Interactiva** - Órdenes en acción
# 4. 🎬 **Animaciones Dinámicas** - Mercado en tiempo real
# 5. 📊 **Métricas del Mercado** - Análisis avanzado
# 6. 💼 **Caso Práctico** - Simulación realista

# %% [markdown]
# ## 🔍 **1. Conceptos Fundamentales**
#
# ### 🤔 **¿Qué es un Limit Order Book?**
#
# Un **Limit Order Book (LOB)** es una estructura de datos que mantiene todas las órdenes de compra y venta pendientes para un activo financiero específico, organizadas por precio y tiempo.
#
# <div style="background-color: #f8f9fa; border-left: 5px solid #28a745; padding: 15px; margin: 10px 0; color: #2c3e50;">
# <h4 style="color: #2c3e50;">🎯 <b>Definición Simple:</b></h4>
# <p style="color: #2c3e50;">Imagina un <b>libro de órdenes</b> como una <b>subasta continua</b> donde:</p>
# <ul style="color: #2c3e50;">
#     <li>📘 <b>Lado COMPRA (Bid)</b>: Lista de compradores dispuestos a pagar diferentes precios</li>
#     <li>📕 <b>Lado VENTA (Ask)</b>: Lista de vendedores dispuestos a vender a diferentes precios</li>
# </ul>
# </div>
#
# ### 🏗️ **Componentes Principales:**
#
# | 🔧 **Componente** | 📝 **Descripción** | 🎨 **Visualización** |
# |:---|:---|:---|
# | **🟢 Bid Side** | Órdenes de compra (lado izquierdo) | Precios decrecientes ⬇️ |
# | **🔴 Ask Side** | Órdenes de venta (lado derecho) | Precios crecientes ⬆️ |
# | **💰 Best Bid** | Precio más alto de compra | Mayor precio en bid side |
# | **💸 Best Ask** | Precio más bajo de venta | Menor precio en ask side |
# | **📏 Spread** | Diferencia: Best Ask - Best Bid | "Costo de liquidez" |
# | **📊 Mid Price** | (Best Bid + Best Ask) / 2 | Precio "justo" teórico |
#
# ### 🎭 **Analogía del Mercado:**
#
# <div style="background: linear-gradient(90deg, #74b9ff, #0984e3); padding: 15px; border-radius: 8px; color: white;">
# <h4>🏪 <b>Piensa en un Bazar Tradicional:</b></h4>
# <ul>
#     <li>🛒 <b>Compradores</b> gritan: "¡Compro manzanas a $2!"</li>
#     <li>🍎 <b>Vendedores</b> gritan: "¡Vendo manzanas a $3!"</li>
#     <li>💱 Una <b>transacción</b> ocurre cuando alguien acepta el precio del otro</li>
#     <li>📋 El <b>LOB</b> es como un megáfono que organiza todos estos gritos</li>
# </ul>
# </div>

# %% [markdown]
# ### 📋 **Tipos de Órdenes:**
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px; margin: 20px 0;">
#
# <div style="background: linear-gradient(135deg, #a8e6cf, #7fcdcd); padding: 15px; border-radius: 8px; color: white;">
# <h4 style="color: white;">📌 <b>LIMIT ORDER</b></h4>
# <ul style="color: white;">
#     <li><b>Precio específico</b> 🎯</li>
#     <li><b>Se añade al book</b> 📚</li>
#     <li><b>Espera matching</b> ⏳</li>
#     <li><b>Ejemplo:</b> "Compro 100 AAPL a $150"</li>
# </ul>
# </div>
#
# <div style="background: linear-gradient(135deg, #ffb3ba, #ff677d); padding: 15px; border-radius: 8px; color: white;">
# <h4>⚡ <b>MARKET ORDER</b></h4>
# <ul>
#     <li><b>Ejecución inmediata</b> 🚀</li>
#     <li><b>Al mejor precio disponible</b> 💰</li>
#     <li><b>Consume liquidez</b> 🔥</li>
#     <li><b>Ejemplo:</b> "Compro 100 AAPL YA"</li>
# </ul>
# </div>
#
# </div>
#
# ### ⚙️ **¿Cómo Funciona la Mecánica?**
#
# ```
# 🔄 FLUJO BÁSICO DEL LOB:
#
# 1️⃣ LLEGA ORDEN → 2️⃣ ¿PUEDE EJECUTARSE? → 3️⃣ SI: MATCH ✅ / NO: AL BOOK 📚
#
# ┌─────────────┐    ┌─────────────┐    ┌─────────────┐
# │   ORDEN     │    │   MATCHING  │    │  RESULTADO  │
# │   NUEVA     │───▶│   ENGINE    │───▶│   TRADE O   │
# │             │    │             │    │   PENDING   │
# └─────────────┘    └─────────────┘    └─────────────┘
# ```
#
# ### 🧠 **Reglas de Prioridad:**
#
# <div style="background-color: #2c3e50; border: 1px solid #34495e; padding: 15px; border-radius: 5px; color: white;">
# <h4 style="color: white;">📏 <b>¿Qué orden se ejecuta primero?</b></h4>
# <ol style="color: white;">
#     <li><b>🥇 PRECIO</b>: Mejor precio tiene prioridad</li>
#     <li><b>🥈 TIEMPO</b>: Si mismo precio → Primero en llegar, primero en servirse (FIFO)</li>
# </ol>
#
# <p style="color: white;"><b>Ejemplo:</b> Si hay 3 órdenes de compra a $100, se ejecuta la que llegó primero ⏰</p>
# </div>

# %% [markdown]
# ### 🎨 **Ejemplo Visual Conceptual:**
#
# Imagina el LOB como una **escalera de precios**:
#
# ```
#                     📊 LIMIT ORDER BOOK
#
#     COMPRA (BID) 💰              💰 VENTA (ASK)
#
#     $149.95  │ 500 shares       300 shares │ $150.05
#     $149.90  │ 200 shares       150 shares │ $150.10
#     $149.85  │ 800 shares       600 shares │ $150.15
#     $149.80  │ 300 shares       400 shares │ $150.20
#
#              ↑                           ↑
#          Best Bid                   Best Ask
#          ($149.95)                  ($150.05)
#
#                    Spread = $0.10
#                 Mid Price = $150.00
# ```
#
# <div style="background: linear-gradient(135deg, #74b9ff, #0984e3); padding: 20px; border-radius: 10px; color: white; text-align: center; margin: 20px 0;">
# <h3>🚀 ¡Ahora vamos a crear nuestro primer LOB visual!</h3>
# <p>En las siguientes celdas configuraremos las herramientas y crearemos visualizaciones interactivas</p>
# </div>
#
# ---

# %%
import sys
import os

# Añadir el directorio actual para poder importar archivos .py
directorio_actual = os.getcwd()
if directorio_actual not in sys.path:
    sys.path.append(directorio_actual)

print(f"✅ Configuración lista. Directorio: {directorio_actual}")
print("🎯 Ahora puedes importar cualquier archivo .py de esta carpeta")
# Out:
# ✅ Configuración lista. Directorio: c:\Users\O005428\Desktop\ICAI\first_lesson_lob
# 🎯 Ahora puedes importar cualquier archivo .py de esta carpeta

# %% [markdown]
# ## 📈 **2. Visualización Estática - Componentes Básicos**
#
# <div style="background: linear-gradient(135deg, #fd79a8, #e84393); padding: 20px; border-radius: 10px; color: white; text-align: center; margin: 20px 0;">
# <h3>🎯 Objetivo: Crear nuestro primer LOB visual</h3>
# <p>Construiremos paso a paso un Limit Order Book funcional con visualizaciones atractivas</p>
# </div>
#
# ### 🏗️ **¿Qué vamos a construir?**
#
# En esta sección crearemos:
#
# | 🛠️ **Componente** | 📝 **Descripción** | 🎨 **Visual** |
# |:---|:---|:---|
# | **📚 Clase LOB** | Estructura para manejar órdenes | Sistema básico |
# | **📊 LOB Estático** | Visualización con datos fijos | Gráfico bid/ask |
# | **📏 Métricas** | Spread, mid-price, profundidad | Indicadores clave |
# | **🎨 Styling** | Colores y formato profesional | Plotly interactivo |
#
# ---

# %%
# 📦 IMPORTAR CLASE LIMITORDERBOOK
from LimitOrderBook import LimitOrderBook

print("✅ Clase LimitOrderBook importada correctamente")
print("🎯 Lista para usar!")
# Out:
# ✅ Clase LimitOrderBook importada correctamente
# 🎯 Lista para usar!

# %%
# 📊 CREACIÓN DEL LOB CON DATOS DE EJEMPLO
print("🎲 Generando datos de ejemplo para el LOB...")

# Crear instancia del LOB y cargar datos de muestra
lob = LimitOrderBook("AAPL")
resultado = lob.load_sample_data()

print(f"📘 Órdenes BID añadidas: {resultado['bid_orders_added']}")
print(f"📕 Órdenes ASK añadidas: {resultado['ask_orders_added']}")

# Mostrar resumen del LOB
summary = lob.get_book_summary()
print("\n" + "="*50)
print("📋 RESUMEN DEL LIMIT ORDER BOOK")
print("="*50)
print(f"🏷️  Símbolo: {summary['symbol']}")
print(f"💰 Best Bid: ${summary['best_bid']}")
print(f"💸 Best Ask: ${summary['best_ask']}")
print(f"📏 Spread: ${summary['spread']}")
print(f"📊 Mid Price: ${summary['mid_price']}")
print(f"📘 Niveles Bid: {summary['bid_levels']}")
print(f"📕 Niveles Ask: {summary['ask_levels']}")
print("="*50)
# Out:
# 🎲 Generando datos de ejemplo para el LOB...
# 📘 Órdenes BID añadidas: 8
# 📕 Órdenes ASK añadidas: 8
#
# ...
# 📋 RESUMEN DEL LIMIT ORDER BOOK
# ...
# 🏷️  Símbolo: AAPL
# 💰 Best Bid: $149.95
# 💸 Best Ask: $150.05
# 📏 Spread: $0.1
# 📊 Mid Price: $150.0
# 📘 Niveles Bid: 8
# 📕 Niveles Ask: 8
# ...

# %%
# 🚀 ¡GENEREMOS NUESTRO PRIMER LOB VISUAL!
print("🎬 Generando la primera visualización del Limit Order Book...")
print("📊 Usando el método integrado en la clase...")

# Crear y mostrar la visualización usando el método de la clase
fig = lob.plot_static("🎯 Mi Primer Limit Order Book - AAPL")
fig.show()

print("\n🎉 ¡FELICIDADES! Has creado tu primer Limit Order Book visual")
print("\n🤔 Ahora responde estas preguntas analizando el gráfico:")
print("\n🔍 PREGUNTAS DE ANÁLISIS:")
print("━" * 50)
print("❓ ¿Cuál es el mejor bid (precio más alto de compra)?")
print("❓ ¿Cuál es el mejor ask (precio más bajo de venta)?")
print("❓ ¿A qué precio tendrías que comprar si quisieras comprar AHORA MISMO?")
print("❓ ¿A qué precio tendrías que vender si quisieras vender AHORA MISMO?")
print("❓ ¿Cuál es el mid price? ¿Crees que es el precio 'justo' (fair price)?")
print("❓ ¿Cuál es el spread? ¿Crees que el half-spread es como una 'comisión de entrada'?")
print("━" * 50)
print("💡 Pista: Las respuestas están en las métricas mostradas arriba y en las líneas del gráfico")
# Out:
# 🎬 Generando la primera visualización del Limit Order Book...
# 📊 Usando el método integrado en la clase...
#         <div style='background: linear-gradient(135deg, #74b9ff, #0984e3); padding: 15px; border-radius: 8px; color: white; margin: 10px 0;'>
#             <h4>📊 Métricas del Mercado:</h4>
#             <p><b>💰 Best Bid:</b> $149.95 | <b>💸 Best Ask:</b> $150.05</p>
#             <p><b>📏 Spread:</b> $0.10 | <b>📊 Mid Price:</b> $150.00</p>
#         </div>
# 🎉 ¡FELICIDADES! Has creado tu primer Limit Order Book visual
#
# 🤔 Ahora responde estas preguntas analizando el gráfico:
#
# 🔍 PREGUNTAS DE ANÁLISIS:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ❓ ¿Cuál es el mejor bid (precio más alto de compra)?
# ❓ ¿Cuál es el mejor ask (precio más bajo de venta)?
# ❓ ¿A qué precio tendrías que comprar si quisieras comprar AHORA MISMO?
# ❓ ¿A qué precio tendrías que vender si quisieras vender AHORA MISMO?
# ❓ ¿Cuál es el mid price? ¿Crees que es el precio 'justo' (fair price)?
# ...

# %% [markdown]
# ## 🧠 **Quiz: ¿Entendiste el Limit Order Book?**
#
# <div style="background: linear-gradient(135deg, #00b894, #00a085); padding: 20px; border-radius: 10px; color: white; text-align: center; margin: 20px 0;">
# <h3>🎯 ¡Pon a prueba tus conocimientos!</h3>
# <p>Responde estas 5 preguntas para verificar que comprendes cómo funciona un LOB</p>
# </div>
#
# ---
#
# ### **📝 Pregunta 1: Conceptos Básicos**
#
# <div style="background-color: #f8f9fa; border-left: 5px solid #e74c3c; padding: 15px; margin: 10px 0; color: #2c3e50;">
# <h4 style="color: #e74c3c;">🤔 <b>¿Cuál es la diferencia principal entre una orden LIMIT y una orden MARKET?</b></h4>
# <p style="color: #2c3e50;"><b>A)</b> Las órdenes LIMIT se ejecutan más rápido</p>
# <p style="color: #2c3e50;"><b>B)</b> Las órdenes MARKET especifican un precio exacto, las LIMIT no</p>
# <p style="color: #2c3e50;"><b>C)</b> Las órdenes LIMIT especifican un precio exacto, las MARKET se ejecutan al mejor precio disponible</p>
# <p style="color: #2c3e50;"><b>D)</b> No hay diferencia entre ambas</p>
# </div>
#
# ---
#
# ### **📊 Pregunta 2: Estructura del LOB**
#
# <div style="background-color: #f8f9fa; border-left: 5px solid #f39c12; padding: 15px; margin: 10px 0; color: #2c3e50;">
# <h4 style="color: #f39c12;">💰 <b>Si el Best Bid es $149.95 y el Best Ask es $150.05, ¿cuál es el Spread?</b></h4>
# <p style="color: #2c3e50;"><b>A)</b> $300.00</p>
# <p style="color: #2c3e50;"><b>B)</b> $0.10</p>
# <p style="color: #2c3e50;"><b>C)</b> $150.00</p>
# <p style="color: #2c3e50;"><b>D)</b> $149.90</p>
# </div>
#
# ---
#
# ### **⚡ Pregunta 3: Prioridad de Órdenes**
#
# <div style="background-color: #f8f9fa; border-left: 5px solid #9b59b6; padding: 15px; margin: 10px 0; color: #2c3e50;">
# <h4 style="color: #9b59b6;">🏃‍♂️ <b>¿Qué orden se ejecuta primero según las reglas de prioridad?</b></h4>
# <p style="color: #2c3e50;"><b>Escenario:</b> Hay 3 órdenes de compra:</p>
# <ul style="color: #2c3e50;">
# <li>Orden A: $100.00 (llegó a las 10:00)</li>
# <li>Orden B: $101.00 (llegó a las 10:05)</li>
# <li>Orden C: $100.00 (llegó a las 10:03)</li>
# </ul>
# <p style="color: #2c3e50;"><b>A)</b> Orden A (por tiempo)</p>
# <p style="color: #2c3e50;"><b>B)</b> Orden B (por precio)</p>
# <p style="color: #2c3e50;"><b>C)</b> Orden C (por tiempo)</p>
# <p style="color: #2c3e50;"><b>D)</b> Se ejecutan todas al mismo tiempo</p>
# </div>
#
# ---
#
# ### **🎨 Pregunta 4: Visualización**
#
# <div style="background-color: #f8f9fa; border-left: 5px solid #00b894; padding: 15px; margin: 10px 0; color: #2c3e50;">
# <h4 style="color: #00b894;">📈 <b>En nuestro gráfico del LOB, ¿qué representa el lado verde (BID)?</b></h4>
# <p style="color: #2c3e50;"><b>A)</b> Órdenes de venta ordenadas de menor a mayor precio</p>
# <p style="color: #2c3e50;"><b>B)</b> Órdenes de compra ordenadas de mayor a menor precio</p>
# <p style="color: #2c3e50;"><b>C)</b> Transacciones completadas</p>
# <p style="color: #2c3e50;"><b>D)</b> El precio del mercado actual</p>
# </div>
#
# ---
#
# ### **🧮 Pregunta 5: Cálculos**
#
# <div style="background-color: #f8f9fa; border-left: 5px solid #3498db; padding: 15px; margin: 10px 0; color: #2c3e50;">
# <h4 style="color: #3498db;">🔢 <b>¿Cómo se calcula el Mid Price?</b></h4>
# <p style="color: #2c3e50;"><b>A)</b> Best Ask - Best Bid</p>
# <p style="color: #2c3e50;"><b>B)</b> (Best Bid + Best Ask) / 2</p>
# <p style="color: #2c3e50;"><b>C)</b> Best Bid × Best Ask</p>
# <p style="color: #2c3e50;"><b>D)</b> Suma de todas las órdenes / número de órdenes</p>
# </div>
#
# ---
#
# <div style="background: linear-gradient(135deg, #fdcb6e, #e17055); padding: 15px; border-radius: 8px; color: white; text-align: center; margin: 20px 0;">
# <h4>🎯 <b>¡Piensa en tus respuestas!</b></h4>
# <p>En la siguiente celda encontrarás las respuestas correctas con explicaciones detalladas</p>
# </div>

# %%
# 🎯 RESPUESTAS DEL QUIZ - ¡Ejecuta para ver las soluciones!
print("📦 Importando QuizSolver...")

from QuizSolver import QuizSolver

print("✅ QuizSolver importado correctamente")

# Crear instancia del solucionador de quiz
quiz = QuizSolver()

print("🎯 Iniciando presentación de respuestas...")

# Mostrar todas las respuestas con explicaciones
quiz.show_quiz_answers()
# Out:
# 📦 Importando QuizSolver...
# ✅ QuizSolver importado correctamente
# 🎯 Iniciando presentación de respuestas...
# 🎉 ¡RESPUESTAS DEL QUIZ LOB!
# ...
#         <div style='background: linear-gradient(135deg, #00b894, #00a085); padding: 15px; border-radius: 8px; color: white; margin: 10px 0;'>
#             <h4>📝 Pregunta 1: Respuesta Correcta = <b>C</b></h4>
#             <p><b>✅ Explicación:</b> Las órdenes LIMIT especifican un precio exacto y esperan en el book hasta encontrar un match. Las órdenes MARKET se ejecutan inmediatamente al mejor precio disponible en ese momento.</p>
#         </div>
#         <div style='background: linear-gradient(135deg, #fdcb6e, #e17055); padding: 15px; border-radius: 8px; color: white; margin: 10px 0;'>
#             <h4>📊 Pregunta 2: Respuesta Correcta = <b>B</b></h4>
#             <p><b>✅ Explicación:</b> Spread = Best Ask - Best Bid = $150.05 - $149.95 = $0.10. El spread representa el "costo de liquidez" del mercado.</p>
#         </div>
# ...

# %% [markdown]
# ---
#
# ## ⚡ **3. Simulación Interactiva - Órdenes en Acción**
#
# <div style="background: linear-gradient(135deg, #00cec9, #00b894); padding: 20px; border-radius: 10px; color: white; text-align: center; margin: 20px 0;">
# <h3>🎯 Objetivo: Simular órdenes reales en el LOB</h3>
# <p>Vamos a crear un sistema interactivo donde podrás enviar órdenes y ver cómo se ejecutan en tiempo real</p>
# </div>
#
# ### 🏗️ **¿Qué vamos a construir?**
#
# En esta sección usaremos nuestra **aplicación unificada InteractiveApp** que incluye:
#
# | 🛠️ **Componente** | 📝 **Descripción** | 🎨 **Funcionalidad** |
# |:---|:---|:---|
# | **🔧 LOB Completo** | Sistema integrado de matching | Limit + Market Orders |
# | **⚡ Market Orders** | Órdenes SIN precio específico | Ejecución inmediata |
# | **📌 Limit Orders** | Órdenes CON precio específico | Se añaden al book |
# | **🎮 Interfaz Interactiva** | Controles para enviar órdenes | Widgets de Jupyter |
# | **📊 Visualización en Vivo** | LOB que se actualiza en tiempo real | Gráfico dinámico |
# | **📈 Métricas Tiempo Real** | Stats actualizadas automáticamente | Best bid/ask, spread, etc. |
#
# ### 🚨 **Diferencias Clave:**
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px; margin: 20px 0;">
#
# <div style="background: linear-gradient(135deg, #a8e6cf, #7fcdcd); padding: 15px; border-radius: 8px; color: white;">
# <h4 style="color: white;">📌 <b>LIMIT ORDER</b></h4>
# <ul style="color: white;">
#     <li><b>CON precio específico</b> 🎯</li>
#     <li><b>Ejemplo:</b> "Compro 100 @ $149.90"</li>
#     <li><b>Se añade al book</b> 📚</li>
#     <li><b>Espera matching</b> ⏳</li>
# </ul>
# </div>
#
# <div style="background: linear-gradient(135deg, #fd79a8, #e84393); padding: 15px; border-radius: 8px; color: white;">
# <h4>⚡ <b>MARKET ORDER</b></h4>
# <ul>
#     <li><b>SIN precio específico</b> 🚀</li>
#     <li><b>Ejemplo:</b> "Compro 100 YA"</li>
#     <li><b>Ejecución inmediata</b> ⚡</li>
#     <li><b>Al mejor precio disponible</b> 💰</li>
# </ul>
# </div>
#
# </div>
#
# ---

# %%
# 🎯 APLICACIÓN INTERACTIVA DEL LOB
# Layout optimizado: Panel izquierdo (controles + stats) + Panel derecho (LOB grande)

# Limpiar instancia anterior si existe
if 'app' in globals():
    del app

# Limpiar cache de módulos para recargar cambios
import sys
if 'InteractiveApp' in sys.modules:
    del sys.modules['InteractiveApp']

# Re-importar con el nuevo layout y fuente ajustada
from InteractiveApp import InteractiveApp

# Crear instancia con datos de muestra
app = InteractiveApp()
app.load_sample_data()

# Mostrar interfaz con layout mejorado
from IPython.display import display
display(app.main_layout)
# Out:
# 🎲 Datos de muestra cargados en el LOB
# ...

# %% [markdown]
# ## 🎯 ¿Cómo usar el simulador?
#
# ### 📝 **Limit Orders** (Órdenes Limitadas)
# - Especifica **precio** y **cantidad**
# - Se añade al LOB en el nivel de precio indicado
# - **No se ejecuta inmediatamente** (a menos que cruce el spread)
#
# ### ⚡ **Market Orders** (Órdenes de Mercado)
# - Solo especifica **cantidad** (el precio se deshabilita)
# - **Se ejecuta inmediatamente** contra las mejores órdenes del lado opuesto
# - Puede ejecutarse parcialmente si no hay suficiente liquidez
#
# ### 🧪 **Experimentos que puedes hacer:**
#
# 1. **Envía una Limit Order BUY a $99**: Verás que se añade al lado de compra
# 2. **Envía una Market Order SELL de 20 acciones**: Se ejecutará contra los mejores bids
# 3. **Observa cómo cambia el spread** después de cada orden
# 4. **Prueba cruzar el spread** con una limit order (ej: BUY a $101.5)
#
# ¡Experimenta y observa cómo reacciona el mercado! 🚀
#
# ---
#
# ## 🧠 **Quiz Avanzado: Microestructura de Mercados**
#
# <div style="background: linear-gradient(135deg, #e17055, #f39c12); padding: 20px; border-radius: 10px; color: white; text-align: center; margin: 20px 0;">
# <h3>🔥 Desafío para Estudiantes de Máster</h3>
# <p>Preguntas complejas sobre situaciones reales que ocurren en los mercados financieros</p>
# <p><i>"¿Estás preparado para pensar como un trader profesional?"</i></p>
# </div>
#
# ---
#
# ### **🚨 PREGUNTA 1: Market Order Gigante**
#
# <div style="background-color: #fff3cd; border-left: 5px solid #f39c12; padding: 15px; margin: 10px 0; color: #856404;">
# <h4 style="color: #856404;">💥 <b>Situación:</b> Un hedge fund quiere comprar 500,000 acciones YA (market order)</h4>
# <p style="color: #856404;">El LOB actual solo tiene 50,000 acciones disponibles en el lado ASK (venta). ¿Qué sucede?</p>
#
# <p style="color: #856404;"><b>A)</b> La orden se rechaza automáticamente</p>
# <p style="color: #856404;"><b>B)</b> Solo se ejecutan 50,000 acciones y el resto se cancela</p>
# <p style="color: #856404;"><b>C)</b> Se ejecutan 50,000 y el resto se convierte en limit order al último precio</p>
# <p style="color: #856404;"><b>D)</b> El precio sube dramáticamente mientras "devora" todos los asks disponibles</p>
# </div>
#
# <div style='background: linear-gradient(135deg, #f39c12, #e67e22); padding: 20px; border-radius: 10px; color: white; margin: 15px 0;'>
# <h4>💥 <b>RESPUESTA: D</b> ✅</h4>
# <h4>Explicación Profesional:</h4>
# <p><b>🎯 Concepto Clave:</b> MARKET IMPACT & PRICE SLIPPAGE</p>
#
# <ul>
# <li><b>Fase 1:</b> Se ejecutan las primeras 50,000 acciones a precios actuales</li>
# <li><b>Fase 2:</b> El algoritmo "camina por el book" buscando más liquidez</li>
# <li><b>Fase 3:</b> Precios suben dramáticamente (puede ser +5-10%)</li>
# <li><b>Impacto:</b> El propio trade mueve el mercado ("moving the market")</li>
# </ul>
#
# <p><b>🏛️ En la realidad:</b> Los grandes fondos usan algoritmos TWAP/VWAP para fragmentar órdenes grandes y minimizar market impact.</p>
# <p><b>⚠️ Riesgo:</b> Esto puede activar stop-losses en cascada y crear volatilidad extrema.</p>
# </div>
#
# ---
#
# ### **🏃‍♂️ PREGUNTA 2: Desaparición Súbita de Liquidez**
#
# <div style="background-color: #f8d7da; border-left: 5px solid #dc3545; padding: 15px; margin: 10px 0; color: #721c24;">
# <h4 style="color: #721c24;">👻 <b>Escenario:</b> De repente, TODO el lado ASK desaparece en 1 segundo</h4>
# <p style="color: #721c24;">¿Cuáles podrían ser las causas de este "flash crash" en el LOB?</p>
#
# <p style="color: #721c24;"><b>A)</b> Error técnico del exchange</p>
# <p style="color: #721c24;"><b>B)</b> Algoritmos de HFT retirando liquidez simultáneamente</p>
# <p style="color: #721c24;"><b>C)</b> Noticia inesperada que cambió la percepción del mercado</p>
# <p style="color: #721c24;"><b>D)</b> Todas las anteriores son posibles</p>
# </div>
#
# <div style='background: linear-gradient(135deg, #e74c3c, #c0392b); padding: 20px; border-radius: 10px; color: white; margin: 15px 0;'>
# <h4>👻 <b>RESPUESTA: D</b> ✅</h4>
# <h4>Análisis Multi-Factor:</h4>
#
# <div style='background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px; margin: 10px 0;'>
# <p><b>🤖 Factor HFT:</b> Algoritmos de alta frecuencia retiran órdenes en milisegundos cuando detectan:</p>
# <ul>
# <li>Flujo de órdenes agresivo</li>
# <li>Cambios en correlaciones</li>
# <li>Señales de información privilegiada</li>
# </ul>
# </div>
#
# <div style='background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px; margin: 10px 0;'>
# <p><b>📰 Factor Fundamental:</b> Noticias inesperadas (earnings miss, crisis geopolítica, etc.)</p>
# </div>
#
# <div style='background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px; margin: 10px 0;'>
# <p><b>⚙️ Factor Técnico:</b> Fallos de conectividad, errores de software</p>
# </div>
#
# <p><b>💡 Insight Profesional:</b> Los "flash crashes" son multicausales. La liquidez moderna es más frágil que antes.</p>
# </div>
#
# ---
#
# ### **📊 PREGUNTA 3: Order Flow Imbalance**
#
# <div style="background-color: #e2e3e5; border-left: 5px solid #6c757d; padding: 15px; margin: 10px 0; color: #495057;">
# <h4 style="color: #495057;">⚖️ <b>Observación:</b> Durante 30 minutos, llegan 90% buy orders vs 10% sell orders</h4>
# <p style="color: #495057;">¿Qué indica este <b>order flow imbalance</b> severo?</p>
#
# <p style="color: #495057;"><b>A)</b> Probable movimiento alcista del precio</p>
# <p style="color: #495057;"><b>B)</b> Posible información privilegiada en el mercado</p>
# <p style="color: #495057;"><b>C)</b> Los market makers ajustarán sus precios al alza</p>
# <p style="color: #495057;"><b>D)</b> Todas las anteriores</p>
# </div>
#
# <div style='background: linear-gradient(135deg, #9b59b6, #8e44ad); padding: 20px; border-radius: 10px; color: white; margin: 15px 0;'>
# <h4>⚖️ <b>RESPUESTA: D</b> ✅</h4>
# <h4>Análisis Predictivo:</h4>
#
# <p><b>📊 Implicaciones Inmediatas:</b></p>
# <ul>
# <li><b>Presión alcista:</b> Exceso de demanda vs oferta</li>
# <li><b>Market makers</b> ajustarán precios al alza para equilibrar riesgo</li>
# <li><b>Spread widening:</b> Mayor incertidumbre = mayor spread</li>
# </ul>
#
# <p><b>🕵️ Señales de Información Asimétrica:</b></p>
# <ul>
# <li>Posible filtración de earnings positivos</li>
# <li>Rumores de M&A (fusiones/adquisiciones)</li>
# <li>Información privilegiada de insiders</li>
# </ul>
#
# <p><b>🎯 Estrategia Profesional:</b> Los traders institucionales monitorizan order flow imbalance como indicador predictor (especialmente útil en timeframes de 5-30 minutos).</p>
# </div>
#
# ---
#
# ### **🕵️ PREGUNTA 4: Detectando Información Asimétrica**
#
# <div style="background-color: #d1ecf1; border-left: 5px solid #0c5460; padding: 15px; margin: 10px 0; color: #0c5460;">
# <h4 style="color: #0c5460;">🔍 <b>Patrón Sospechoso:</b> Órdenes grandes y precisas llegan justo antes de anuncios</h4>
# <p style="color: #0c5460;">Un trader siempre coloca órdenes de 100,000 acciones exactamente 10 minutos antes de earnings calls. ¿Qué podría estar pasando?</p>
#
# <p style="color: #0c5460;"><b>A)</b> Coincidencia estadística</p>
# <p style="color: #0c5460;"><b>B)</b> Algoritmo muy sofisticado de predicción</p>
# <p style="color: #0c5460;"><b>C)</b> Posible insider trading (información privilegiada)</p>
# <p style="color: #0c5460;"><b>D)</b> Market making legítimo</p>
# </div>
#
# <div style='background: linear-gradient(135deg, #16a085, #1abc9c); padding: 20px; border-radius: 10px; color: white; margin: 15px 0;'>
# <h4>🕵️ <b>RESPUESTA: C</b> ✅</h4>
# <h4>Análisis Forense del Trading:</h4>
#
# <p><b>🚨 Red Flags de Insider Trading:</b></p>
# <ul>
# <li><b>Timing preciso:</b> Siempre antes de eventos importantes</li>
# <li><b>Volúmenes inusuales:</b> Órdenes mucho mayores a lo normal</li>
# <li><b>Consistencia sospechosa:</b> Rentabilidad "imposible"</li>
# </ul>
#
# <div style='background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px; margin: 10px 0;'>
# <p><b>⚖️ Marco Legal:</b></p>
# <ul>
# <li>Violación de regulaciones SEC/CNMV</li>
# <li>Sanciones penales y civiles</li>
# <li>Prohibición de operar en mercados</li>
# </ul>
# </div>
#
# <p><b>🛡️ Detección Moderna:</b> Los exchanges usan ML y AI para detectar patrones anómalos en tiempo real.</p>
# </div>
#
# ---
#
# ### **⚡ PREGUNTA 5: High-Frequency Trading Impact**
#
# <div style="background-color: #f3e2f3; border-left: 5px solid #6f42c1; padding: 15px; margin: 10px 0; color: #493558;">
# <h4 style="color: #493558;">🤖 <b>Fenómeno HFT:</b> El spread cambia 1000 veces por segundo</h4>
# <p style="color: #493558;">Los algoritmos de alta frecuencia están constantemente ajustando precios. ¿Cuál es el impacto en traders retail?</p>
#
# <p style="color: #493558;"><b>A)</b> Mejores precios para todos (menor spread)</p>
# <p style="color: #493558;"><b>B)</b> Mayor dificultad para traders manuales</p>
# <p style="color: #493558;"><b>C)</b> Aumento de la volatilidad intraday</p>
# <p style="color: #493558;"><b>D)</b> Todas las anteriores</p>
# </div>
#
# <div style='background: linear-gradient(135deg, #6c5ce7, #a29bfe); padding: 20px; border-radius: 10px; color: white; margin: 15px 0;'>
# <h4>🤖 <b>RESPUESTA: D</b> ✅</h4>
# <h4>Paradoja del HFT:</h4>
#
# <div style='display: grid; grid-template-columns: 1fr 1fr; gap: 15px; margin: 15px 0;'>
# <div style='background: rgba(255,255,255,0.1); padding: 15px; border-radius: 5px;'>
# <h5>✅ BENEFICIOS</h5>
# <ul>
# <li>Spreads más estrechos</li>
# <li>Mayor liquidez promedio</li>
# <li>Eficiencia de precios</li>
# <li>Menores costos de transacción</li>
# </ul>
# </div>
# <div style='background: rgba(255,255,255,0.1); padding: 15px; border-radius: 5px;'>
# <h5>❌ PROBLEMAS</h5>
# <ul>
# <li>Volatilidad intraday</li>
# <li>Flash crashes</li>
# <li>Liquidez "fantasma"</li>
# <li>Ventaja tecnológica injusta</li>
# </ul>
# </div>
# </div>
#
# <p><b>🎯 Realidad para Retail Traders:</b> Necesitan adaptarse usando órdenes inteligentes (iceberg, hidden, etc.) y timeframes más largos.</p>
# </div>
#
# ---
#
# ### **💣 PREGUNTA 6: Circuit Breaker**
#
# <div style="background-color: #f8d7da; border-left: 5px solid #721c24; padding: 15px; margin: 10px 0; color: #721c24;">
# <h4 style="color: #721c24;">🛑 <b>Crisis:</b> El precio cae 20% en 5 minutos, se activa circuit breaker</h4>
# <p style="color: #721c24;">El mercado se pausa por 15 minutos. ¿Qué esperarías que pase cuando reabre?</p>
#
# <p style="color: #721c24;"><b>A)</b> Vuelta inmediata a precios normales</p>
# <p style="color: #721c24;"><b>B)</b> Spread extremadamente ancho (baja liquidez)</p>
# <p style="color: #721c24;"><b>C)</b> Avalancha de órdenes acumuladas</p>
# <p style="color: #721c24;"><b>D)</b> B y C son correctas</p>
# </div>
#
# <div style='background: linear-gradient(135deg, #e55039, #ff3838); padding: 20px; border-radius: 10px; color: white; margin: 15px 0;'>
# <h4>🛑 <b>RESPUESTA: D</b> ✅</h4>
# <h4>Dinámica Post-Pausa:</h4>
#
# <p><b>⚡ Al Reabrir el Mercado:</b></p>
# <ul>
# <li><b>Spread masivo:</b> Market makers aumentan spreads por incertidumbre</li>
# <li><b>Órdenes acumuladas:</b> 15 minutos de presión de venta reprimida</li>
# <li><b>Volatilidad extrema:</b> Primeros minutos muy turbulentos</li>
# <li><b>Volume spike:</b> Picos de volumen 5-10x superiores a lo normal</li>
# </ul>
#
# <div style='background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px; margin: 10px 0;'>
# <p><b>🧠 Psicología del Mercado:</b></p>
# <p>La pausa amplifica el pánico. Los inversores interpretan el circuit breaker como confirmación de que "algo muy malo está pasando".</p>
# </div>
#
# <p><b>📈 Oportunidad:</b> Algunos traders contrarian ven estos momentos como oportunidades de compra (si tienen liquidez y aguante psicológico).</p>
# </div>
#
# ---
#
# <div style='background: linear-gradient(135deg, #667eea, #764ba2); padding: 25px; border-radius: 15px; color: white; text-align: center; margin: 25px 0;'>
# <h2>🎓 EVALUACIÓN NIVEL MÁSTER</h2>
#
# <div style='text-align: left; margin: 20px auto; max-width: 600px;'>
# <h4>🏆 Criterios de Evaluación:</h4>
# <ul>
# <li><b>6/6 Correctas:</b> 🌟 Listo para trading institucional</li>
# <li><b>4-5/6:</b> 📈 Excelente comprensión de microestructura</li>
# <li><b>3/6:</b> 📚 Buen nivel, revisar conceptos avanzados</li>
# <li><b>1-2/6:</b> 🤔 Necesita más estudio de mercados reales</li>
# <li><b>0/6:</b> 📖 Volver a conceptos fundamentales</li>
# </ul>
# </div>
#
# <h4>💡 COMPETENCIAS EVALUADAS:</h4>
# <p>✅ Market Impact & Price Discovery<br>
# ✅ Liquidity Dynamics & HFT Effects<br>
# ✅ Information Asymmetry Detection<br>
# ✅ Crisis Management & Circuit Breakers<br>
# ✅ Order Flow Analysis<br>
# ✅ Regulatory & Ethical Awareness</p>
#
# <div style='background: rgba(255,255,255,0.1); padding: 15px; border-radius: 8px; margin: 20px 0;'>
# <h4>🚀 PRÓXIMO NIVEL:</h4>
# <p>Si dominaste este quiz, estás preparado para temas como:</p>
# <p><b>• Dark Pools • Algorithmic Trading • Market Making • Risk Management</b></p>
# </div>
# </div>

# %% [markdown]
# # 🎬 **4. ANIMACIONES DINÁMICAS - MERCADO EN MOVIMIENTO**
#
# ---
#
# <div style='background: linear-gradient(135deg, #ff6b6b, #ee5a52); padding: 25px; border-radius: 15px; color: white; text-align: center; margin: 25px 0;'>
# <h2>🚀 SIMULACIÓN EN TIEMPO REAL</h2>
# <p><b>Vamos a ver cómo se mueve el LOB en vivo</b></p>
# </div>

# %%
# 🚀 CREAR SIMULADOR AVANZADO

from UltimateOrderBookLesson import UltimateOrderBookLesson
# Crear la instancia del Ultimate Order Book
ultimate_lob = UltimateOrderBookLesson(lob)
# Out:
# 📊 Generando vista actual del mercado simulado...
# ✅ UltimateOrderBook optimizado creado!

# %%
# 📊 VISTA ESTÁTICA DEL SIMULADOR

print("📊 Generando vista actual del mercado simulado...")

# Generar datos de mercado
ultimate_lob.simulate_market_tick()

# Mostrar estado actual en texto
if ultimate_lob.mid_price_history:
    mid_price = ultimate_lob.mid_price_history[-1]
    spread = ultimate_lob.spread_history[-1]
    
    print(f"💰 Mid Price: ${mid_price:.2f}")
    print(f"📏 Spread: ${spread:.3f}")
    
    # Mostrar mejores precios
    bid_prices = sorted(ultimate_lob.current_bids.keys(), reverse=True)
    ask_prices = sorted(ultimate_lob.current_asks.keys())
    
    if bid_prices and ask_prices:
        print(f"🟢 Best Bid: ${bid_prices[0]:.2f}")
        print(f"🔴 Best Ask: ${ask_prices[0]:.2f}")

print("\n🎯 Para ver el gráfico completo:")
print("   ultimate_lob.create_orderbook_visualization().show()")
# Out:
# 📊 Generando vista actual del mercado simulado...
# 💰 Mid Price: $149.54
# 📏 Spread: $0.430
# 🟢 Best Bid: $149.33
# 🔴 Best Ask: $149.76
#
# 🎯 Para ver el gráfico completo:
#    ultimate_lob.create_orderbook_visualization().show()

# %%
# 🎬 SIMULACIÓN EN TIEMPO REAL

print("🎬 Iniciando simulación de mercado en tiempo real...")
print("⚡ Configuración:")
print("   • Duración: 10 segundos")
print("   • Actualización cada 1.5 segundos")
print("   • Visualización completa del LOB")
print()
print("🚀 ¡Comenzando simulación!")

# Iniciar simulación optimizada
ultimate_lob.start_simulation(duration=10, update_interval=1.5)
# Out:
# 💰 Mid Price: $149.12
# 📏 Spread: $0.194
# ✅ Simulación completada!
# ✅ Simulación completada!

# %% [markdown]
# ## Escenario de crash simulado

# %% [markdown]
# ## 💥 **4.1 Escenario de Crisis - Simulación de Crash del Mercado**
#
# <div style='background: linear-gradient(135deg, #e74c3c, #c0392b); padding: 25px; border-radius: 15px; color: white; text-align: center; margin: 25px 0;'>
# <h2>🚨 SIMULACIÓN DE CRISIS FINANCIERA</h2>
# <p><b>¿Qué pasa cuando el pánico se apodera del mercado?</b></p>
# <p><i>"Veremos en tiempo real cómo colapsa la liquidez del lado BID"</i></p>
# </div>
#
# ### 🎯 **¿Qué vamos a simular?**
#
# <div style="background-color: #fff3cd; border-left: 5px solid #f39c12; padding: 15px; margin: 10px 0; color: #856404;">
# <h4 style="color: #f39c12;">⚠️ <b>Escenario: "Bid Side Crash"</b></h4>
# <p style="color: #856404;">Un evento que simula una <b>crisis de liquidez</b> donde los compradores huyen del mercado pero los vendedores mantienen sus precios altos.</p>
#
# <p style="color: #856404;"><b>📊 Condiciones Iniciales:</b></p>
# <ul style="color: #856404;">
#     <li><b>Bid Side:</b> Oscila normalmente entre $99-$100</li>
#     <li><b>Ask Side:</b> Oscila normalmente entre $100-$101</li>
#     <li><b>Spread:</b> Aproximadamente $1.00 (mercado líquido)</li>
# </ul>
#
# <p style="color: #856404;"><b>🚨 Durante la Crisis (Tick 10+):</b></p>
# <ul style="color: #856404;">
#     <li><b>Bid Side:</b> ¡COLAPSA! Cae a rango $98-$99</li>
#     <li><b>Ask Side:</b> Se mantiene estable en $100-$101</li>
#     <li><b>Spread:</b> Se AMPLÍA a $2-$3 (pérdida de liquidez)</li>
#     <li><b>Volumen Bid:</b> Se reduce drásticamente (~60% menos)</li>
# </ul>
# </div>
#
# ### 🔬 **¿Por qué es importante este escenario?**
#
# <div style="background-color: #e2e3e5; border-left: 5px solid #6c757d; padding: 15px; margin: 10px 0; color: #495057;">
# <h4 style="color: #495057;">🎓 <b>Lecciones de Microestructura:</b></h4>
#
# <p style="color: #495057;"><b>1. Asimetría de Información:</b> Los compradores reciben "malas noticias" primero</p>
# <p style="color: #495057;"><b>2. Behavior Heterogéneo:</b> Vendedores y compradores reaccionan diferente</p>
# <p style="color: #495057;"><b>3. Fragmentación de Liquidez:</b> El mercado se vuelve menos eficiente</p>
# <p style="color: #495057;"><b>4. Price Discovery:</b> El precio "justo" se vuelve más difícil de determinar</p>
# </div>
#
# ---

# %%
# Crear el simulador
ultimate_lob = UltimateOrderBookLesson(lob)

# Ejecutar simulación de crisis del bid
ultimate_lob.simulate_bid_crash_scenario(
    crash_tick=10,        # Crisis en el tick 10
    duration=50,         # 50 ticks total
    update_interval=0.1  # Actualización cada 1.2s
)
# Out:
# 📊 TICK 30 | BID_CRASH
# 💰 Mid Price: $99.19
# 📏 Spread: $1.905
# 🟢 Best Bid: $97.29
# 🔴 Best Ask: $101.10
# 📊 Condición: Crisis de Liquidez
# ✅ Simulación del Bid Crash completada!
#
# 📊 RESUMEN FINAL:
# 🔸 Spread inicial promedio: ~$1.00
# 🔸 Spread final promedio: ~$2.50
# 🔸 Impacto en mid price: ~$0.75 down
# 🔸 Pérdida de liquidez bid: ~60%

# %% [markdown]
# # 📊 **5. MÉTRICAS DEL MERCADO - ANÁLISIS CUANTITATIVO**
#
# ---
#
# <div style='background: linear-gradient(135deg, #00b894, #00a085); padding: 25px; border-radius: 15px; color: white; text-align: center; margin: 25px 0;'>
# <h2>🔬 ANÁLISIS POST-CRISIS</h2>
# <p><b>Ahora que has VISTO la crisis, vamos a MEDIRLA científicamente</b></p>
# <p><i>"¿Cómo cuantifican los profesionales la salud del mercado?"</i></p>
# </div>
#
# ### 🤔 **¿Te has preguntado?**
#
# <div style="background-color: #e8f5e8; border-left: 5px solid #28a745; padding: 15px; margin: 10px 0; color: #155724;">
# <ul style="color: #155724;">
#     <li>🏥 <b>¿Cómo sabemos si un mercado es "saludable" o "enfermo"?</b></li>
#     <li>🔍 <b>¿Qué métricas usan los reguladores para detectar manipulación?</b></li>
#     <li>📊 <b>¿Cómo miden los traders institucionales el riesgo de liquidez?</b></li>
#     <li>⚡ <b>¿Cómo se determina la eficiencia del price discovery?</b></li>
# </ul>
# </div>
#
# **¡En esta sección lo descubriremos analizando nuestra propia simulación de crisis!**
#
# ### 🛠️ **¿Qué vamos a construir?**
#
# En esta sección usaremos herramientas **profesionales de análisis cuantitativo**:
#
# | 📈 **Área de Análisis** | 📝 **Métricas Clave** | 🎯 **Objetivo** |
# |:---|:---|:---|
# | **💰 Spread Analysis** | Quoted, Effective, Relative Spreads | Medir el costo de liquidez |
# | **📊 Market Depth** | Volumen, Concentración, Simetría | Evaluar disponibilidad de liquidez |
# | **⚡ Volatility Metrics** | Realized, Sharpe, Drawdown | Cuantificar el riesgo |
# | **🔄 Price Impact** | Persistencia, Eficiencia, Mean Reversion | Medir calidad del price discovery |
#
# ---

# %% [markdown]
# ## 💰 **5.1 Métricas Básicas de Calidad del Mercado**
#
# <div style="background: linear-gradient(135deg, #667eea, #764ba2); padding: 20px; border-radius: 10px; color: white; text-align: center; margin: 20px 0;">
# <h3>🎯 Objetivo: Analizar científicamente la simulación de crisis</h3>
# <p>Usaremos métricas que emplean fondos de inversión, bancos de inversión y reguladores financieros</p>
# </div>
#
# ### 🔬 **¿Qué vamos a analizar?**
#
# Vamos a aplicar **análisis cuantitativo profesional** a los datos que generamos en la simulación de crisis del Punto 4. Específicamente analizaremos:
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px; margin: 20px 0;">
#
# <div style="background: linear-gradient(135deg, #fd79a8, #e84393); padding: 15px; border-radius: 8px; color: white;">
# <h4 style="color: white;">📏 <b>SPREAD ANALYSIS</b></h4>
# <ul style="color: white;">
#     <li><b>Quoted Spread</b>: Ask - Bid</li>
#     <li><b>Relative Spread</b>: En basis points</li>
#     <li><b>Spread Stability</b>: Coeficiente de variación</li>
#     <li><b>Tight/Wide Periods</b>: % tiempo en spreads extremos</li>
# </ul>
# </div>
#
# <div style="background: linear-gradient(135deg, #00cec9, #00b894); padding: 15px; border-radius: 8px; color: white;">
# <h4>📊 <b>MARKET DEPTH</b></h4>
# <ul>
#     <li><b>Total Volume</b>: Liquidez disponible</li>
#     <li><b>Liquidity Imbalance</b>: Bid vs Ask ratio</li>
#     <li><b>Concentration</b>: % liquidez en primer nivel</li>
#     <li><b>Depth Symmetry</b>: Balance bid/ask</li>
# </ul>
# </div>
#
# </div>
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px; margin: 20px 0;">
#
# <div style="background: linear-gradient(135deg, #a8e6cf, #7fcdcd); padding: 15px; border-radius: 8px; color: white;">
# <h4 style="color: white;">⚡ <b>VOLATILITY METRICS</b></h4>
# <ul style="color: white;">
#     <li><b>Realized Volatility</b>: Desviación estándar retornos</li>
#     <li><b>Sharpe Ratio</b>: Risk-adjusted returns</li>
#     <li><b>Skewness & Kurtosis</b>: Forma distribución</li>
#     <li><b>Maximum Drawdown</b>: Pérdida máxima</li>
# </ul>
# </div>
#
# <div style="background: linear-gradient(135deg, #6c5ce7, #a29bfe); padding: 15px; border-radius: 8px; color: white;">
# <h4>🔄 <b>PRICE IMPACT</b></h4>
# <ul>
#     <li><b>Market Efficiency</b>: Eficiencia price discovery</li>
#     <li><b>Price Persistence</b>: Autocorrelación retornos</li>
#     <li><b>Mean Reversion</b>: Fuerza de reversión</li>
#     <li><b>Discovery Speed</b>: Velocidad ajuste precios</li>
# </ul>
# </div>
#
# </div>
#
# ### 📚 **¿Por qué son importantes estas métricas?**
#
# <div style="background-color: #fff3cd; border-left: 5px solid #f39c12; padding: 15px; margin: 10px 0; color: #856404;">
# <h4 style="color: #f39c12;">🏛️ <b>Uso en la Industria Financiera:</b></h4>
# <ul style="color: #856404;">
#     <li><b>🏦 Bancos de Inversión</b>: Evalúan riesgo de market making</li>
#     <li><b>📊 Hedge Funds</b>: Optimizan estrategias de ejecución</li>
#     <li><b>⚖️ Reguladores</b>: Monitorizan estabilidad financiera</li>
#     <li><b>📈 Exchanges</b>: Mejoran estructura de mercado</li>
#     <li><b>🎓 Académicos</b>: Investigan microestructura</li>
# </ul>
# </div>
#
# ---

# %%
# 📦 IMPORTAR ANALIZADOR DE CALIDAD DE MERCADO

# Limpiar cache si es necesario
import sys
if 'MarketQualityAnalyzer' in sys.modules:
    del sys.modules['MarketQualityAnalyzer']

from MarketQualityAnalyzer import MarketQualityAnalyzer

print("✅ MarketQualityAnalyzer importado correctamente")
print("🎯 Listo para analizar la calidad del mercado!")

# Verificar que tenemos datos de la simulación
if 'ultimate_lob' in locals() and ultimate_lob.mid_price_history:
    print(f"📊 Datos disponibles: {len(ultimate_lob.mid_price_history)} períodos de simulación")
    print("🚀 ¡Perfecto! Podemos proceder con el análisis")
else:
    print("⚠️  No se encontraron datos de simulación. Ejecuta primero el punto 4 (crisis scenario)")
    print("💡 Recomendación: Ejecuta las celdas de simulación de crisis antes de continuar")
# Out:
# ✅ MarketQualityAnalyzer importado correctamente
# 🎯 Listo para analizar la calidad del mercado!
# 📊 Datos disponibles: 30 períodos de simulación
# 🚀 ¡Perfecto! Podemos proceder con el análisis

# %%
# 🔬 CREAR ANALIZADOR E INICIALIZAR CON DATOS DE CRISIS

print("🔬 Inicializando Market Quality Analyzer...")
print("📊 Conectando con datos de simulación de crisis...")

# Crear instancia del analizador con nuestros datos de crisis
market_analyzer = MarketQualityAnalyzer(ultimate_lob)

print("✅ Analizador inicializado correctamente")
print("🎯 Conectado a simulación con datos de bid crash scenario")

# Verificar conexión con datos
try:
    test_data = market_analyzer.extract_market_data()
    print(f"\n📈 Resumen de datos disponibles:")
    print(f"   • Períodos totales: {test_data['n_periods']}")
    print(f"   • Rango de precios: ${min(test_data['mid_prices']):.2f} - ${max(test_data['mid_prices']):.2f}")
    print(f"   • Rango de spreads: ${min(test_data['spreads']):.3f} - ${max(test_data['spreads']):.3f}")
    print(f"   • Retornos disponibles: {len(test_data['returns'])}")
    print("\n🚀 ¡Datos cargados exitosamente! Listos para análisis cuantitativo")
    
except Exception as e:
    print(f"❌ Error al extraer datos: {e}")
    print("💡 Asegúrate de haber ejecutado la simulación de crisis en el Punto 4")
# Out:
# 🔬 Inicializando Market Quality Analyzer...
# 📊 Conectando con datos de simulación de crisis...
# ✅ Analizador inicializado correctamente
# 🎯 Conectado a simulación con datos de bid crash scenario
#
# 📈 Resumen de datos disponibles:
#    • Períodos totales: 30
#    • Rango de precios: $98.96 - $100.43
#    • Rango de spreads: $0.712 - $2.786
#    • Retornos disponibles: 29
#
# 🚀 ¡Datos cargados exitosamente! Listos para análisis cuantitativo

# %%
# 💰 ANÁLISIS DETALLADO DE SPREAD METRICS

print("💰 Calculando métricas avanzadas de SPREAD...")
print("=" * 60)

# Calcular métricas de spread
spread_metrics = market_analyzer.calculate_spread_metrics()

# Mostrar resultados detallados
if 'error' not in spread_metrics:
    print("📊 SPREAD ANALYSIS - RESULTADOS:")
    print("=" * 60)
    
    # Métricas básicas
    print(f"📏 Quoted Spread (Absoluto):")
    print(f"   • Promedio: ${spread_metrics['quoted_spread_mean']:.4f}")
    print(f"   • Desviación: ${spread_metrics['quoted_spread_std']:.4f}")
    print(f"   • Mediana: ${spread_metrics['quoted_spread_median']:.4f}")
    print(f"   • Rango: ${spread_metrics['quoted_spread_min']:.4f} - ${spread_metrics['quoted_spread_max']:.4f}")
    
    print(f"\n💹 Spread Relativo (Basis Points):")
    if 'relative_spread_mean_bps' in spread_metrics:
        print(f"   • Promedio: {spread_metrics['relative_spread_mean_bps']:.2f} bps")
        print(f"   • Desviación: {spread_metrics['relative_spread_std_bps']:.2f} bps")
        print(f"   • Mediana: {spread_metrics['relative_spread_median_bps']:.2f} bps")
    
    print(f"\n📈 Percentiles de Distribución:")
    print(f"   • P25 (Cuartil 1): ${spread_metrics['quoted_spread_p25']:.4f}")
    print(f"   • P75 (Cuartil 3): ${spread_metrics['quoted_spread_p75']:.4f}")
    print(f"   • P95: ${spread_metrics['quoted_spread_p95']:.4f}")
    print(f"   • P99: ${spread_metrics['quoted_spread_p99']:.4f}")
    
    print(f"\n⚖️ Stability & Market Conditions:")
    print(f"   • Spread Stability: {spread_metrics['spread_stability']:.3f}")
    print(f"   • Tight Market Time: {spread_metrics['tight_spread_ratio']*100:.1f}%")
    print(f"   • Wide Market Time: {spread_metrics['wide_spread_ratio']*100:.1f}%")
    
    # Interpretación
    print(f"\n🎯 INTERPRETACIÓN PROFESIONAL:")
    print("=" * 40)
    
    if spread_metrics['spread_stability'] < 0.3:
        print("✅ ESTABILIDAD: Spread muy estable - Mercado líquido")
    elif spread_metrics['spread_stability'] < 0.6:
        print("⚠️  ESTABILIDAD: Spread moderadamente volátil")
    else:
        print("🚨 ESTABILIDAD: Spread muy volátil - Posible estrés de mercado")
    
    if spread_metrics['relative_spread_mean_bps'] < 10:
        print("✅ LIQUIDEZ: Excelente (spread < 10 bps)")
    elif spread_metrics['relative_spread_mean_bps'] < 50:
        print("⚠️  LIQUIDEZ: Moderada (spread 10-50 bps)")
    else:
        print("🚨 LIQUIDEZ: Baja (spread > 50 bps)")
        
else:
    print(f"❌ Error en cálculo de spread: {spread_metrics['error']}")

print("\n" + "=" * 60)
# Out:
# 💰 Calculando métricas avanzadas de SPREAD...
# ...
# 📊 SPREAD ANALYSIS - RESULTADOS:
# ...
# 📏 Quoted Spread (Absoluto):
#    • Promedio: $1.7483
#    • Desviación: $0.5867
#    • Mediana: $1.8800
#    • Rango: $0.7123 - $2.7861
#
# 💹 Spread Relativo (Basis Points):
#    • Promedio: 175.60 bps
#    • Desviación: 59.16 bps
#    • Mediana: 189.25 bps
#
# 📈 Percentiles de Distribución:
#    • P25 (Cuartil 1): $1.2416
#    • P75 (Cuartil 3): $2.2382
#    • P95: $2.5627
#    • P99: $2.7400
#
# ⚖️ Stability & Market Conditions:
#    • Spread Stability: 0.336
#    • Tight Market Time: 26.7%
#    • Wide Market Time: 26.7%
#
# 🎯 INTERPRETACIÓN PROFESIONAL:
# ...
# ⚠️  ESTABILIDAD: Spread moderadamente volátil
# 🚨 LIQUIDEZ: Baja (spread > 50 bps)
#
# ...

# %% [markdown]
# ### 💰 **Conclusiones del Análisis de Spread**
#
# <div style='background: linear-gradient(135deg, #fd79a8, #e84393); padding: 20px; border-radius: 15px; color: white; margin: 20px 0;'>
# <h3>📊 INTERPRETACIÓN PROFESIONAL - SPREAD METRICS</h3>
# <p><i>¿Qué nos dice el comportamiento del spread sobre la salud del mercado?</i></p>
# </div>
#
# #### 🔍 **Hallazgos Clave:**
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px; margin: 20px 0;">
#
# <div style="background-color: #f8f9fa; border-left: 5px solid #28a745; padding: 15px; color: #2c3e50;">
# <h4 style="color: #28a745;">✅ <b>Aspectos Positivos</b></h4>
# <ul style="color: #2c3e50;">
#     <li><b>Spread Promedio</b>: Indica el costo básico de liquidez</li>
#     <li><b>Percentiles</b>: Muestran la distribución de costos</li>
#     <li><b>Períodos Tight</b>: % de tiempo con spreads bajos</li>
# </ul>
# </div>
#
# <div style="background-color: #fff3cd; border-left: 5px solid #f39c12; padding: 15px; color: #856404;">
# <h4 style="color: #f39c12;">⚠️ <b>Señales de Alerta</b></h4>
# <ul style="color: #856404;">
#     <li><b>Spread Volatility</b>: Inestabilidad en costos</li>
#     <li><b>Períodos Wide</b>: Momentos de baja liquidez</li>
#     <li><b>Basis Points</b>: Costo relativo excesivo</li>
# </ul>
# </div>
#
# </div>
#
# #### 🎯 **Implicaciones para Trading:**
#
# <div style="background: linear-gradient(90deg, #667eea, #764ba2); padding: 15px; border-radius: 8px; color: white; margin: 15px 0;">
# <h4>💼 <b>Para Traders Institucionales:</b></h4>
# <ul>
#     <li>📈 <b>Market Making</b>: Ajustar cotizaciones según volatilidad del spread</li>
#     <li>⚡ <b>Execution Algos</b>: Optimizar timing según períodos tight/wide</li>
#     <li>🔄 <b>Risk Management</b>: Considerar spread como componente de costo</li>
#     <li>📊 <b>Performance Attribution</b>: Separar alpha de costos de liquidez</li>
# </ul>
# </div>
#
# #### 📚 **Conexión Académica:**
#
# | 📖 **Concepto Teórico** | 🔬 **Evidencia Empírica** | 💡 **Insight Práctico** |
# |:---|:---|:---|
# | **Bid-Ask Spread** | Rango observado en datos | Costo de inmediatez en trading |
# | **Liquidity Premium** | Spread vs volatilidad | Mayor incertidumbre = mayor spread |
# | **Market Quality** | Estabilidad del spread | Consistencia indica mercado sano |
# | **Adverse Selection** | Spread en crisis vs normal | Información asimétrica amplía spreads |
#
# ---

# %%
# 📊 ANÁLISIS DE PROFUNDIDAD Y LIQUIDEZ

print("📊 Calculando métricas de MARKET DEPTH y LIQUIDEZ...")
print("=" * 60)

# Calcular métricas de profundidad
depth_metrics = market_analyzer.calculate_depth_metrics()

# Mostrar resultados detallados
if 'error' not in depth_metrics:
    print("📊 MARKET DEPTH ANALYSIS - RESULTADOS:")
    print("=" * 60)
    
    # Volúmenes totales
    print(f"💧 Liquidez Total Disponible:")
    print(f"   • Total Bid Volume: {depth_metrics['total_bid_volume']:,.0f} shares")
    print(f"   • Total Ask Volume: {depth_metrics['total_ask_volume']:,.0f} shares")
    print(f"   • Total Market Volume: {depth_metrics['total_volume']:,.0f} shares")
    
    # Estructura del mercado
    print(f"\n🏗️ Estructura del Mercado:")
    print(f"   • Niveles Bid: {depth_metrics['bid_levels']}")
    print(f"   • Niveles Ask: {depth_metrics['ask_levels']}")
    print(f"   • Total Price Levels: {depth_metrics['total_levels']}")
    
    # Concentración de liquidez
    print(f"\n🎯 Concentración de Liquidez:")
    print(f"   • Concentración Bid: {depth_metrics['bid_concentration']*100:.1f}%")
    print(f"   • Concentración Ask: {depth_metrics['ask_concentration']*100:.1f}%")
    print(f"   • Concentración Promedio: {depth_metrics['avg_concentration']*100:.1f}%")
    
    # Balance y simetría
    print(f"\n⚖️ Balance y Simetría:")
    print(f"   • Liquidity Imbalance: {depth_metrics['liquidity_imbalance']*100:+.1f}%")
    print(f"   • Depth Symmetry: {depth_metrics['depth_symmetry']:.3f}")
    print(f"   • Avg Bid Depth: {depth_metrics['avg_bid_depth']:,.1f} shares/level")
    print(f"   • Avg Ask Depth: {depth_metrics['avg_ask_depth']:,.1f} shares/level")
    
    # Interpretación profesional
    print(f"\n🎯 INTERPRETACIÓN PROFESIONAL:")
    print("=" * 40)
    
    # Evaluar concentración
    avg_concentration = depth_metrics['avg_concentration']
    if avg_concentration < 0.4:
        print("✅ DISTRIBUCIÓN: Liquidez bien distribuida")
    elif avg_concentration < 0.7:
        print("⚠️  DISTRIBUCIÓN: Moderadamente concentrada")
    else:
        print("🚨 DISTRIBUCIÓN: Altamente concentrada - Riesgo de gaps")
    
    # Evaluar balance
    imbalance = abs(depth_metrics['liquidity_imbalance'])
    if imbalance < 0.1:
        print("✅ BALANCE: Mercado bien balanceado")
    elif imbalance < 0.3:
        print("⚠️  BALANCE: Ligero desequilibrio")
    else:
        direction = "hacia COMPRA" if depth_metrics['liquidity_imbalance'] > 0 else "hacia VENTA"
        print(f"🚨 BALANCE: Fuerte desequilibrio {direction}")
    
    # Evaluar simetría
    symmetry = depth_metrics['depth_symmetry']
    if symmetry > 0.8:
        print("✅ SIMETRÍA: Excelente simetría bid/ask")
    elif symmetry > 0.6:
        print("⚠️  SIMETRÍA: Moderada asimetría")
    else:
        print("🚨 SIMETRÍA: Fuerte asimetría - Posible sesgo direccional")
        
else:
    print(f"❌ Error en cálculo de depth: {depth_metrics['error']}")

print("\n" + "=" * 60)
# Out:
# 📊 Calculando métricas de MARKET DEPTH y LIQUIDEZ...
# ...
# 📊 MARKET DEPTH ANALYSIS - RESULTADOS:
# ...
# 💧 Liquidez Total Disponible:
#    • Total Bid Volume: 197 shares
#    • Total Ask Volume: 335 shares
#    • Total Market Volume: 532 shares
#
# 🏗️ Estructura del Mercado:
#    • Niveles Bid: 5
#    • Niveles Ask: 5
#    • Total Price Levels: 10
#
# 🎯 Concentración de Liquidez:
#    • Concentración Bid: 23.4%
#    • Concentración Ask: 15.2%
#    • Concentración Promedio: 19.3%
#
# ⚖️ Balance y Simetría:
#    • Liquidity Imbalance: -25.9%
#    • Depth Symmetry: 0.588
#    • Avg Bid Depth: 39.4 shares/level
#    • Avg Ask Depth: 67.0 shares/level
#
# 🎯 INTERPRETACIÓN PROFESIONAL:
# ...
# ✅ DISTRIBUCIÓN: Liquidez bien distribuida
# ⚠️  BALANCE: Ligero desequilibrio
# 🚨 SIMETRÍA: Fuerte asimetría - Posible sesgo direccional
#
# ...

# %% [markdown]
# ### 📊 **Conclusiones del Análisis de Profundidad**
#
# <div style='background: linear-gradient(135deg, #00cec9, #00b894); padding: 20px; border-radius: 15px; color: white; margin: 20px 0;'>
# <h3>🏗️ INTERPRETACIÓN PROFESIONAL - MARKET DEPTH</h3>
# <p><i>¿Cómo se comporta la liquidez disponible en el mercado?</i></p>
# </div>
#
# #### 🔍 **Análisis Cuantitativo de Liquidez:**
#
# <div style="display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 15px; margin: 20px 0;">
#
# <div style="background-color: #e8f5e8; border-left: 5px solid #28a745; padding: 15px; color: #155724;">
# <h4 style="color: #28a745;">💧 <b>Volumen Total</b></h4>
# <p style="color: #155724;"><b>Indica:</b> Cantidad de liquidez disponible para absorber órdenes grandes</p>
# <p style="color: #155724;"><b>Benchmark:</b> >10,000 shares = líquido</p>
# </div>
#
# <div style="background-color: #fff3cd; border-left: 5px solid #f39c12; padding: 15px; color: #856404;">
# <h4 style="color: #f39c12;">⚖️ <b>Imbalance</b></h4>
# <p style="color: #856404;"><b>Indica:</b> Sesgo direccional del mercado</p>
# <p style="color: #856404;"><b>Benchmark:</b> ±10% = balanceado</p>
# </div>
#
# <div style="background-color: #f8d7da; border-left: 5px solid #dc3545; padding: 15px; color: #721c24;">
# <h4 style="color: #dc3545;">🎯 <b>Concentración</b></h4>
# <p style="color: #721c24;"><b>Indica:</b> Distribución de la liquidez</p>
# <p style="color: #721c24;"><b>Benchmark:</b> <40% = bien distribuida</p>
# </div>
#
# </div>
#
# #### 🚨 **Escenarios de Crisis y Depth:**
#
# <div style="background-color: #2c3e50; border: 1px solid #34495e; padding: 15px; border-radius: 5px; color: white; margin: 15px 0;">
# <h4 style="color: white;">⚠️ <b>¿Qué sucede durante una crisis de liquidez?</b></h4>
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px; margin: 15px 0;">
# <div>
# <h5 style="color: #FF6B35;">🚨 CRISIS SÍNTOMAS:</h5>
# <ul style="color: white;">
#     <li>Volumen total disminuye</li>
#     <li>Imbalance severo (&gt;30%)</li>
#     <li>Concentración aumenta (&gt;70%)</li>
#     <li>Asimetría bid/ask extrema</li>
# </ul>
# </div>
# <div>
# <h5 style="color: #00C851;">✅ MERCADO SANO:</h5>
# <ul style="color: white;">
#     <li>Volumen abundante y estable</li>
#     <li>Balance cerca de 0%</li>
#     <li>Liquidez distribuida</li>
#     <li>Simetría bid/ask alta</li>
# </ul>
# </div>
# </div>
# </div>
#
# #### 🏛️ **Perspectiva Regulatoria:**
#
# <div style="background: linear-gradient(90deg, #9b59b6, #8e44ad); padding: 15px; border-radius: 8px; color: white; margin: 15px 0;">
# <h4>⚖️ <b>¿Cómo usan estas métricas los reguladores?</b></h4>
# <ul>
#     <li>🔍 <b>Surveillance</b>: Detectar manipulación de mercado</li>
#     <li>📊 <b>Systemic Risk</b>: Identificar fragilidad de liquidez</li>
#     <li>🛡️ <b>Circuit Breakers</b>: Trigger basado en depth metrics</li>
#     <li>📈 <b>Market Making</b>: Evaluar obligaciones de MM</li>
# </ul>
# </div>
#
# #### 💡 **Insights Estratégicos:**
#
# | 🎯 **Metric** | 📊 **Interpretación** | 🚀 **Acción Sugerida** |
# |:---|:---|:---|
# | **Alto Imbalance** | Flujo direccional fuerte | Considerar trades contrarian |
# | **Alta Concentración** | Riesgo de gaps de precio | Usar órdenes iceberg |
# | **Baja Simetría** | Sesgo informacional | Investigar catalysts |
# | **Volumen Bajo** | Mercado ilíquido | Fragmentar órdenes grandes |
#
# ---

# %%
# ⚡ ANÁLISIS DE VOLATILIDAD Y RIESGO

print("⚡ Calculando métricas de VOLATILIDAD y RIESGO...")
print("=" * 60)

# Calcular métricas de volatilidad
volatility_metrics = market_analyzer.calculate_volatility_metrics()

# Mostrar resultados detallados
if 'error' not in volatility_metrics:
    print("⚡ VOLATILITY & RISK ANALYSIS - RESULTADOS:")
    print("=" * 60)
    
    # Métricas básicas de volatilidad
    print(f"📈 Volatilidad Básica:")
    print(f"   • Realized Volatility: {volatility_metrics['realized_volatility']*100:.3f}%")
    print(f"   • Log Volatility: {volatility_metrics['log_volatility']*100:.3f}%")
    print(f"   • Annualized Volatility: {volatility_metrics['annualized_volatility']*100:.1f}%")
    print(f"   • Price Variability: ${volatility_metrics['price_variability']:.4f}")
    print(f"   • Spread Volatility: ${volatility_metrics['spread_volatility']:.4f}")
    
    # Métricas de riesgo ajustado
    print(f"\n📊 Risk-Adjusted Metrics:")
    print(f"   • Sharpe Ratio: {volatility_metrics['sharpe_ratio']:.3f}")
    print(f"   • Maximum Drawdown: {volatility_metrics['max_drawdown']*100:.2f}%")
    print(f"   • Volatility Stability: {volatility_metrics['volatility_stability']:.3f}")
    
    # Distribución de retornos
    print(f"\n📐 Distribución de Retornos:")
    print(f"   • Skewness: {volatility_metrics['skewness']:+.3f}")
    print(f"   • Kurtosis (excess): {volatility_metrics['kurtosis']:+.3f}")
    print(f"   • Volatility Clustering: {volatility_metrics['volatility_clustering']:+.3f}")
    
    # Interpretación profesional
    print(f"\n🎯 INTERPRETACIÓN DE RIESGO:")
    print("=" * 40)
    
    # Evaluar nivel de volatilidad
    annual_vol = volatility_metrics['annualized_volatility']
    if annual_vol < 0.15:  # 15%
        print("✅ VOLATILIDAD: Baja - Mercado estable")
    elif annual_vol < 0.30:  # 30%
        print("⚠️  VOLATILIDAD: Moderada - Riesgo normal")
    else:
        print("🚨 VOLATILIDAD: Alta - Mercado estresado")
    
    # Evaluar Sharpe ratio
    sharpe = volatility_metrics['sharpe_ratio']
    if sharpe > 1:
        print("✅ SHARPE: Excelente risk-adjusted performance")
    elif sharpe > 0:
        print("⚠️  SHARPE: Performance positiva pero moderada")
    else:
        print("🚨 SHARPE: Performance negativa")
    
    # Evaluar distribución
    skew = volatility_metrics['skewness']
    kurt = volatility_metrics['kurtosis']
    
    if abs(skew) < 0.5 and abs(kurt) < 2:
        print("✅ DISTRIBUCIÓN: Aproximadamente normal")
    elif abs(skew) < 1 and abs(kurt) < 5:
        print("⚠️  DISTRIBUCIÓN: Moderadamente no-normal")
    else:
        print("🚨 DISTRIBUCIÓN: Fuertemente no-normal - Riesgo de colas")
    
    # Evaluar drawdown
    max_dd = abs(volatility_metrics['max_drawdown'])
    if max_dd < 0.05:  # 5%
        print("✅ DRAWDOWN: Pérdidas controladas")
    elif max_dd < 0.15:  # 15%
        print("⚠️  DRAWDOWN: Pérdidas moderadas")
    else:
        print("🚨 DRAWDOWN: Pérdidas significativas")
        
else:
    print(f"❌ Error en cálculo de volatilidad: {volatility_metrics['error']}")

print("\n" + "=" * 60)
# Out:
# ⚡ Calculando métricas de VOLATILIDAD y RIESGO...
# ...
# ⚡ VOLATILITY & RISK ANALYSIS - RESULTADOS:
# ...
# 📈 Volatilidad Básica:
#    • Realized Volatility: 0.399%
#    • Log Volatility: 0.399%
#    • Annualized Volatility: 240.2%
#    • Price Variability: $0.3973
#    • Spread Volatility: $0.5867
#
# 📊 Risk-Adjusted Metrics:
#    • Sharpe Ratio: -0.050
#    • Maximum Drawdown: -1.46%
#    • Volatility Stability: 0.336
#
# 📐 Distribución de Retornos:
#    • Skewness: +0.000
#    • Kurtosis (excess): -0.443
#    • Volatility Clustering: +0.473
#
# 🎯 INTERPRETACIÓN DE RIESGO:
# ...
# 🚨 VOLATILIDAD: Alta - Mercado estresado
# 🚨 SHARPE: Performance negativa
# ✅ DISTRIBUCIÓN: Aproximadamente normal
# ✅ DRAWDOWN: Pérdidas controladas
#
# ...

# %% [markdown]
# ### ⚡ **Conclusiones del Análisis de Volatilidad**
#
# <div style='background: linear-gradient(135deg, #6c5ce7, #a29bfe); padding: 20px; border-radius: 15px; color: white; margin: 20px 0;'>
# <h3>📊 INTERPRETACIÓN PROFESIONAL - VOLATILITY & RISK</h3>
# <p><i>¿Qué nos dice la volatilidad sobre el riesgo y la incertidumbre del mercado?</i></p>
# </div>
#
# #### 🔬 **Descomposición de la Volatilidad:**
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px; margin: 20px 0;">
#
# <div style="background-color: #e8f4f8; border-left: 5px solid #007BFF; padding: 15px; color: #004085;">
# <h4 style="color: #007BFF;">📈 <b>Realized Volatility</b></h4>
# <ul style="color: #004085;">
#     <li><b>Definición</b>: Volatilidad observada ex-post</li>
#     <li><b>Uso</b>: Risk management, VaR models</li>
#     <li><b>Benchmark</b>: Comparar vs implied vol</li>
# </ul>
# </div>
#
# <div style="background-color: #f3e2f3; border-left: 5px solid #6f42c1; padding: 15px; color: #493558;">
# <h4 style="color: #6f42c1;">🎯 <b>Sharpe Ratio</b></h4>
# <ul style="color: #493558;">
#     <li><b>Definición</b>: Return per unit of risk</li>
#     <li><b>Uso</b>: Performance evaluation</li>
#     <li><b>Benchmark</b>: >1 = excelente</li>
# </ul>
# </div>
#
# </div>
#
# #### 📊 **Distribución de Retornos - Análisis Avanzado:**
#
# <div style="background-color: #2c3e50; border: 1px solid #34495e; padding: 15px; border-radius: 5px; color: white; margin: 15px 0;">
# <h4 style="color: white;">📐 <b>Shape de la Distribución:</b></h4>
#
# <div style="display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 15px; margin: 15px 0;">
# <div style="background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px;">
# <h5 style="color: #FFD700;">📊 SKEWNESS</h5>
# <ul style="color: white; font-size: 14px;">
#     <li><b>Positiva:</b> Cola derecha larga</li>
#     <li><b>Negativa:</b> Cola izquierda larga</li>
#     <li><b>Zero:</b> Simétrica</li>
# </ul>
# </div>
# <div style="background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px;">
# <h5 style="color: #FF6B35;">📊 KURTOSIS</h5>
# <ul style="color: white; font-size: 14px;">
#     <li><b>Alta:</b> Colas gruesas (fat tails)</li>
#     <li><b>Baja:</b> Colas delgadas</li>
#     <li><b>Normal:</b> ≈ 3</li>
# </ul>
# </div>
# <div style="background: rgba(255,255,255,0.1); padding: 10px; border-radius: 5px;">
# <h5 style="color: #00C851;">📊 DRAWDOWN</h5>
# <ul style="color: white; font-size: 14px;">
#     <li><b>Peak-to-trough</b> decline</li>
#     <li><b>Risk measure</b> crucial</li>
#     <li><b>Recovery time</b> importante</li>
# </ul>
# </div>
# </div>
# </div>
#
# #### 🏦 **Aplicaciones en Finanzas Cuantitativas:**
#
# <div style="background: linear-gradient(90deg, #e74c3c, #c0392b); padding: 15px; border-radius: 8px; color: white; margin: 15px 0;">
# <h4>🔬 <b>¿Cómo usan estas métricas los quants?</b></h4>
# <ul>
#     <li>📊 <b>VaR Models</b>: Volatility para calcular Value-at-Risk</li>
#     <li>🎯 <b>Option Pricing</b>: Volatility input en Black-Scholes</li>
#     <li>⚖️ <b>Portfolio Optimization</b>: Risk-adjusted allocation</li>
#     <li>🔄 <b>Risk Budgeting</b>: Allocar riesgo por estrategia</li>
# </ul>
# </div>
#
# #### 🚨 **Alertas de Volatilidad en Trading:**
#
# <div style="display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 15px; margin: 20px 0;">
#
# <div style="background-color: #d4edda; border-left: 5px solid #28a745; padding: 15px; color: #155724;">
# <h4 style="color: #28a745;">✅ <b>Vol Baja</b></h4>
# <p style="color: #155724;"><b>Estrategias:</b></p>
# <ul style="color: #155724; font-size: 14px;">
#     <li>Sell volatility</li>
#     <li>Carry trades</li>
#     <li>Range trading</li>
# </ul>
# </div>
#
# <div style="background-color: #fff3cd; border-left: 5px solid #f39c12; padding: 15px; color: #856404;">
# <h4 style="color: #f39c12;">⚠️ <b>Vol Moderada</b></h4>
# <p style="color: #856404;"><b>Estrategias:</b></p>
# <ul style="color: #856404; font-size: 14px;">
#     <li>Trend following</li>
#     <li>Delta hedging</li>
#     <li>Mixed strategies</li>
# </ul>
# </div>
#
# <div style="background-color: #f8d7da; border-left: 5px solid #dc3545; padding: 15px; color: #721c24;">
# <h4 style="color: #dc3545;">🚨 <b>Vol Alta</b></h4>
# <p style="color: #721c24;"><b>Estrategias:</b></p>
# <ul style="color: #721c24; font-size: 14px;">
#     <li>Buy volatility</li>
#     <li>Crisis alpha</li>
#     <li>Defensive positioning</li>
# </ul>
# </div>
#
# </div>
#
# #### 💡 **Insights Clave para Estudiantes:**
#
# | 🎓 **Concepto** | 📚 **Teoría** | 🌍 **Aplicación Real** |
# |:---|:---|:---|
# | **Volatility Clustering** | Los períodos volátiles tienden a agruparse | HFT algoritmos ajustan posiciones |
# | **Fat Tails** | Eventos extremos más frecuentes que normal | Stress testing en risk management |
# | **Mean Reversion** | Volatilidad tiende a revertir a media | Vol trading strategies |
# | **Asymmetric Volatility** | Vol aumenta más con caídas que subidas | Options market microstructure |
#
# ---

# %%
# 🔄 ANÁLISIS DE PRICE IMPACT Y EFICIENCIA

print("🔄 Calculando métricas de PRICE IMPACT y EFICIENCIA DEL MERCADO...")
print("=" * 70)

# Calcular métricas de price impact
impact_metrics = market_analyzer.calculate_price_impact_metrics()

# Mostrar resultados detallados
if 'error' not in impact_metrics:
    print("🔄 PRICE IMPACT & EFFICIENCY ANALYSIS - RESULTADOS:")
    print("=" * 70)
    
    # Métricas de eficiencia
    print(f"🎯 Eficiencia del Mercado:")
    print(f"   • Market Efficiency: {impact_metrics['market_efficiency']*100:.1f}%")
    print(f"   • Price Discovery Speed: {impact_metrics['price_discovery_speed']:.3f}")
    print(f"   • Price Persistence: {impact_metrics['price_persistence']:+.3f}")
    
    # Métricas de impacto
    print(f"\n💥 Price Impact Metrics:")
    print(f"   • Price-Spread Correlation: {impact_metrics['price_spread_correlation']:+.3f}")
    print(f"   • Price Impact Volatility: ${impact_metrics['price_impact_volatility']:.4f}")
    print(f"   • Impact Asymmetry: {impact_metrics['impact_asymmetry']:+.3f}")
    
    # Métricas de mean reversion
    print(f"\n🔄 Mean Reversion:")
    print(f"   • Mean Reversion Strength: {impact_metrics['mean_reversion_strength']:.3f}")
    
    # Interpretación profesional
    print(f"\n🎯 INTERPRETACIÓN DE EFICIENCIA:")
    print("=" * 50)
    
    # Evaluar eficiencia del mercado
    efficiency = impact_metrics['market_efficiency']
    if efficiency > 0.8:
        print("✅ EFICIENCIA: Mercado altamente eficiente")
        print("   → Price discovery rápido y preciso")
        print("   → Mínima persistencia en retornos")
    elif efficiency > 0.6:
        print("⚠️  EFICIENCIA: Moderadamente eficiente")
        print("   → Price discovery aceptable")
        print("   → Alguna predictabilidad en retornos")
    else:
        print("🚨 EFICIENCIA: Baja eficiencia")
        print("   → Price discovery lento")
        print("   → Alta predictabilidad (posibles ineficiencias)")
    
    # Evaluar persistencia
    persistence = impact_metrics['price_persistence']
    if abs(persistence) < 0.1:
        print("\n✅ PERSISTENCIA: Mínima (ideal para eficiencia)")
    elif abs(persistence) < 0.3:
        print("\n⚠️  PERSISTENCIA: Moderada")
    else:
        if persistence > 0:
            print("\n🚨 PERSISTENCIA: Alta positiva (momentum)")
            print("   → Retornos positivos tienden a seguir")
        else:
            print("\n🚨 PERSISTENCIA: Alta negativa (mean reversion)")
            print("   → Retornos tienden a revertir")
    
    # Evaluar correlación price-spread
    correlation = impact_metrics['price_spread_correlation']
    if abs(correlation) < 0.3:
        print("\n✅ PRICE-SPREAD: Baja correlación (mercado estable)")
    elif abs(correlation) < 0.6:
        print("\n⚠️  PRICE-SPREAD: Correlación moderada")
    else:
        print("\n🚨 PRICE-SPREAD: Alta correlación (mercado estresado)")
        print("   → Cambios de precio impactan fuertemente liquidez")
    
    # Evaluar mean reversion
    mean_rev = impact_metrics['mean_reversion_strength']
    if mean_rev > 0.3:
        print(f"\n✅ MEAN REVERSION: Fuerte ({mean_rev:.3f})")
        print("   → Precios tienden a revertir eficientemente")
    elif mean_rev > 0.1:
        print(f"\n⚠️  MEAN REVERSION: Moderada ({mean_rev:.3f})")
    else:
        print(f"\n🚨 MEAN REVERSION: Débil ({mean_rev:.3f})")
        print("   → Posible momentum o drift en precios")
        
else:
    print(f"❌ Error en cálculo de price impact: {impact_metrics['error']}")

print("\n" + "=" * 70)
# Out:
# 🔄 Calculando métricas de PRICE IMPACT y EFICIENCIA DEL MERCADO...
# ...
# 🔄 PRICE IMPACT & EFFICIENCY ANALYSIS - RESULTADOS:
# ...
# 🎯 Eficiencia del Mercado:
#    • Market Efficiency: 59.8%
#    • Price Discovery Speed: 0.713
#    • Price Persistence: -0.402
#
# 💥 Price Impact Metrics:
#    • Price-Spread Correlation: -0.120
#    • Price Impact Volatility: $0.2234
#    • Impact Asymmetry: -0.052
#
# 🔄 Mean Reversion:
#    • Mean Reversion Strength: 0.402
#
# 🎯 INTERPRETACIÓN DE EFICIENCIA:
# ...
# 🚨 EFICIENCIA: Baja eficiencia
#    → Price discovery lento
#    → Alta predictabilidad (posibles ineficiencias)
#
# 🚨 PERSISTENCIA: Alta negativa (mean reversion)
#    → Retornos tienden a revertir
#
# ✅ PRICE-SPREAD: Baja correlación (mercado estable)
#
# ✅ MEAN REVERSION: Fuerte (0.402)
#    → Precios tienden a revertir eficientemente
#
# ...

# %% [markdown]
# ### 🎯 **Conclusiones del Análisis de Impacto en Precios**
#
# <div style='background: linear-gradient(135deg, #e74c3c, #c0392b); padding: 20px; border-radius: 15px; color: white; margin: 20px 0;'>
# <h3>🚀 INTERPRETACIÓN PROFESIONAL - MARKET IMPACT</h3>
# <p><i>¿Cómo afectan las órdenes grandes al precio y qué dice esto sobre la liquidez del mercado?</i></p>
# </div>
#
# #### 🏗️ **Anatomía del Market Impact:**
#
# <div style="background-color: #2c3e50; border: 1px solid #34495e; padding: 15px; border-radius: 5px; color: white; margin: 15px 0;">
# <h4 style="color: white;">🧮 <b>Descomposición del Impacto:</b></h4>
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 15px; margin: 15px 0;">
# <div style="background: rgba(46, 204, 113, 0.3); padding: 15px; border-radius: 5px; border-left: 4px solid #2ecc71;">
# <h5 style="color: #2ecc71;">🎯 <b>PERMANENT IMPACT</b></h5>
# <ul style="color: white; font-size: 14px;">
#     <li><b>Definición:</b> Cambio precio duradero</li>
#     <li><b>Causa:</b> Información revelada</li>
#     <li><b>Duración:</b> Persistente</li>
#     <li><b>Gestión:</b> Algoritmos de ejecución</li>
# </ul>
# </div>
# <div style="background: rgba(231, 76, 60, 0.3); padding: 15px; border-radius: 5px; border-left: 4px solid #e74c3c;">
# <h5 style="color: #e74c3c;">⚡ <b>TEMPORARY IMPACT</b></h5>
# <ul style="color: white; font-size: 14px;">
#     <li><b>Definición:</b> Cambio precio transitorio</li>
#     <li><b>Causa:</b> Desequilibrio momentáneo</li>
#     <li><b>Duración:</b> Minutos/horas</li>
#     <li><b>Gestión:</b> TWAP, VWAP strategies</li>
# </ul>
# </div>
# </div>
# </div>
#
# #### 📈 **Modelos de Market Impact - Academia vs Industria:**
#
# <div style="display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 15px; margin: 20px 0;">
#
# <div style="background-color: #e8f5e8; border-left: 5px solid #28a745; padding: 15px; color: #155724;">
# <h4 style="color: #28a745;">📊 <b>Modelo Lineal</b></h4>
# <p style="color: #155724; font-size: 14px;"><b>Impact = α × Volume</b></p>
# <ul style="color: #155724; font-size: 13px;">
#     <li>✅ Simple implementación</li>
#     <li>⚠️ Asume linealidad</li>
#     <li>📈 Usado en algoritmos básicos</li>
# </ul>
# </div>
#
# <div style="background-color: #fff3cd; border-left: 5px solid #f39c12; padding: 15px; color: #856404;">
# <h4 style="color: #f39c12;">🧮 <b>Modelo de Raíz</b></h4>
# <p style="color: #856404; font-size: 14px;"><b>Impact = β × √Volume</b></p>
# <ul style="color: #856404; font-size: 13px;">
#     <li>✅ Más realista</li>
#     <li>✅ Captura concavidad</li>
#     <li>📈 Estándar en HFT</li>
# </ul>
# </div>
#
# <div style="background-color: #f8d7da; border-left: 5px solid #dc3545; padding: 15px; color: #721c24;">
# <h4 style="color: #dc3545;">🤖 <b>ML Models</b></h4>
# <p style="color: #721c24; font-size: 14px;"><b>Impact = f(V,T,σ,L...)</b></p>
# <ul style="color: #721c24; font-size: 13px;">
#     <li>✅ Multi-factor</li>
#     <li>✅ No-linear</li>
#     <li>📈 Usado por top-tier funds</li>
# </ul>
# </div>
#
# </div>
#
# #### 💰 **Cost de Trading - Descomposición Profesional:**
#
# <div style="background: linear-gradient(90deg, #667eea, #764ba2); padding: 15px; border-radius: 8px; color: white; margin: 15px 0;">
# <h4>💸 <b>Total Trading Cost = Spread + Impact + Timing + Opportunity</b></h4>
#
# <div style="display: grid; grid-template-columns: 1fr 1fr 1fr 1fr; gap: 10px; margin: 15px 0;">
# <div style="background: rgba(255,255,255,0.2); padding: 10px; border-radius: 5px; text-align: center;">
# <h5 style="color: #FFD700;">📊 SPREAD</h5>
# <p style="font-size: 12px;">Bid-Ask differential</p>
# </div>
# <div style="background: rgba(255,255,255,0.2); padding: 10px; border-radius: 5px; text-align: center;">
# <h5 style="color: #FF6B35;">🎯 IMPACT</h5>
# <p style="font-size: 12px;">Price movement</p>
# </div>
# <div style="background: rgba(255,255,255,0.2); padding: 10px; border-radius: 5px; text-align: center;">
# <h5 style="color: #00C851;">⏰ TIMING</h5>
# <p style="font-size: 12px;">Execution delay</p>
# </div>
# <div style="background: rgba(255,255,255,0.2); padding: 10px; border-radius: 5px; text-align: center;">
# <h5 style="color: #AA66CC;">💼 OPPORTUNITY</h5>
# <p style="font-size: 12px;">Missed alpha</p>
# </div>
# </div>
# </div>
#
# #### 🤖 **Algoritmos de Ejecución - Toolbox del Trader Institucional:**
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px; margin: 20px 0;">
#
# <div style="background-color: #e8f4f8; border: 2px solid #007BFF; padding: 15px; border-radius: 10px;">
# <h4 style="color: #007BFF;">🕐 <b>Time-Based Algorithms</b></h4>
# <ul style="color: #004085; font-size: 14px;">
#     <li><b>TWAP:</b> Time-Weighted Average Price</li>
#     <li><b>VWAP:</b> Volume-Weighted Average Price</li>
#     <li><b>IS:</b> Implementation Shortfall</li>
#     <li><b>POV:</b> Participation of Volume</li>
# </ul>
# </div>
#
# <div style="background-color: #f3e2f3; border: 2px solid #6f42c1; padding: 15px; border-radius: 10px;">
# <h4 style="color: #6f42c1;">🧠 <b>Adaptive Algorithms</b></h4>
# <ul style="color: #493558; font-size: 14px;">
#     <li><b>Smart Order Router:</b> Cross-venue</li>
#     <li><b>Iceberg Orders:</b> Hidden quantity</li>
#     <li><b>Sniper:</b> Liquidity detection</li>
#     <li><b>Guerrilla:</b> Anti-gaming</li>
# </ul>
# </div>
#
# </div>
#
# #### 📊 **Métricas de Performance en Ejecución:**
#
# <div style="background-color: #2c3e50; border: 1px solid #34495e; padding: 15px; border-radius: 5px; color: white; margin: 15px 0;">
# <h4 style="color: white;">📈 <b>TCA - Transaction Cost Analysis:</b></h4>
#
# | 🏆 **Métrica** | 📏 **Fórmula** | 🎯 **Objetivo** | 📊 **Benchmark** |
# |:---|:---|:---|:---|
# | **Arrival Price** | (Execution - Decision) / Decision | Minimizar slippage | < 5 bps |
# | **VWAP Performance** | (Execution - VWAP) / VWAP | Beat market average | < 0 bps |
# | **Implementation Shortfall** | Paper P&L - Real P&L | Total cost measure | < 10 bps |
# | **Market Impact** | Price change vs volume | Liquidity assessment | β < 0.5 |
#
# </div>
#
# #### 🏦 **Dark Pools vs Lit Markets - Strategic Considerations:**
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 15px; margin: 20px 0;">
#
# <div style="background: rgba(0, 0, 0, 0.9); border: 2px solid #333; padding: 15px; border-radius: 10px; color: white;">
# <h4 style="color: #FFD700;">🌑 <b>DARK POOLS</b></h4>
# <h5 style="color: #00C851;">✅ Ventajas:</h5>
# <ul style="color: white; font-size: 13px;">
#     <li>Reduced market impact</li>
#     <li>No information leakage</li>
#     <li>Better prices for large orders</li>
# </ul>
# <h5 style="color: #FF6B35;">❌ Desventajas:</h5>
# <ul style="color: white; font-size: 13px;">
#     <li>Lower fill rates</li>
#     <li>Adverse selection risk</li>
#     <li>Regulatory scrutiny</li>
# </ul>
# </div>
#
# <div style="background: rgba(255, 255, 255, 0.95); border: 2px solid #ddd; padding: 15px; border-radius: 10px; color: #333;">
# <h4 style="color: #007BFF;">☀️ <b>LIT MARKETS</b></h4>
# <h5 style="color: #28a745;">✅ Ventajas:</h5>
# <ul style="color: #333; font-size: 13px;">
#     <li>Guaranteed fills at displayed prices</li>
#     <li>Transparent price discovery</li>
#     <li>Regulatory protection</li>
# </ul>
# <h5 style="color: #dc3545;">❌ Desventajas:</h5>
# <ul style="color: #333; font-size: 13px;">
#     <li>Higher market impact</li>
#     <li>Information leakage</li>
#     <li>Predatory trading</li>
# </ul>
# </div>
#
# </div>
#
# #### 🚨 **Red Flags para Risk Managers:**
#
# <div style="background: linear-gradient(45deg, #ff6b6b, #feca57); padding: 15px; border-radius: 8px; color: white; margin: 15px 0; border: 2px solid #ff4757;">
# <h4>⚠️ <b>Señales de Alarma en Market Impact</b></h4>
# <div style="display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 15px; margin: 10px 0;">
# <div>
# <h5 style="color: #fff;">🔴 <b>Impact Anómalo</b></h5>
# <ul style="font-size: 13px;">
#     <li>Impact > 3σ histórico</li>
#     <li>Non-linear scaling</li>
#     <li>Asimetría buy/sell</li>
# </ul>
# </div>
# <div>
# <h5 style="color: #fff;">🔴 <b>Liquidez Seca</b></h5>
# <ul style="font-size: 13px;">
#     <li>Depth < percentil 10</li>
#     <li>Spread > percentil 90</li>
#     <li>Order book gaps</li>
# </ul>
# </div>
# <div>
# <h5 style="color: #fff;">🔴 <b>Predators</b></h5>
# <ul style="font-size: 13px;">
#     <li>Phantom liquidity</li>
#     <li>Quote stuffing</li>
#     <li>Latency arbitrage</li>
# </ul>
# </div>
# </div>
# </div>
#
# #### 💡 **Aplicación en Asset Management:**
#
# <div style="background-color: #f8f9fa; border: 1px solid #dee2e6; padding: 20px; border-radius: 8px; margin: 15px 0;">
# <h4 style="color: #495057;">🏛️ <b>¿Cómo usa un Portfolio Manager estas métricas?</b></h4>
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px; margin: 15px 0;">
# <div>
# <h5 style="color: #007BFF;">📊 <b>Portfolio Construction:</b></h5>
# <ul style="color: #495057; font-size: 14px;">
#     <li><b>Liquidity constraints</b> en optimization</li>
#     <li><b>Turnover budgets</b> basados en impact</li>
#     <li><b>Position sizing</b> ajustado por costs</li>
# </ul>
# </div>
# <div>
# <h5 style="color: #28a745;">💰 <b>Performance Attribution:</b></h5>
# <ul style="color: #495057; font-size: 14px;">
#     <li><b>Alpha separation</b> from trading costs</li>
#     <li><b>Execution quality</b> monitoring</li>
#     <li><b>Broker evaluation</b> via TCA</li>
# </ul>
# </div>
# </div>
# </div>
#
# ---

# %%
# 📊 DASHBOARD VISUAL COMPLETO

print("📊 Generando Market Quality Dashboard...")
print("🎨 Creando visualización interactiva con todas las métricas...")

# Crear dashboard completo
dashboard_fig = market_analyzer.create_metrics_dashboard(
    title="📊 Market Quality Dashboard - Crisis Scenario Analysis"
)

# Mostrar dashboard
dashboard_fig.show()

print("\n🎉 ¡Dashboard generado exitosamente!")
print("\n🔍 CÓMO INTERPRETAR EL DASHBOARD:")
print("=" * 50)
print("📈 Panel Superior Izquierdo: Evolución de precios (bid, mid, ask)")
print("📏 Panel Superior Derecho: Dinámica del spread a lo largo del tiempo")
print("📊 Panel Medio Izquierdo: Profundidad actual del mercado")
print("⚡ Panel Medio Derecho: Volatilidad rolling (ventana de 10 períodos)")
print("🔄 Panel Inferior Izquierdo: Price changes (cambios de precio)")
print("📈 Panel Inferior Derecho: Gauge del spread promedio")

print(f"\n💡 TIPS DE ANÁLISIS:")
print("• Busca patrones en el spread durante la crisis (tick 10+)")
print("• Observa cómo la volatilidad se dispara durante el crash")
print("• Nota el desequilibrio en la profundidad del mercado")
print("• Analiza la distribución de price changes (colores)")
print("• El gauge muestra si el spread está en niveles normales")
# Out:
# 📊 Generando Market Quality Dashboard...
# 🎨 Creando visualización interactiva con todas las métricas...
# 🎉 ¡Dashboard generado exitosamente!
#
# 🔍 CÓMO INTERPRETAR EL DASHBOARD:
# ...
# 📈 Panel Superior Izquierdo: Evolución de precios (bid, mid, ask)
# 📏 Panel Superior Derecho: Dinámica del spread a lo largo del tiempo
# 📊 Panel Medio Izquierdo: Profundidad actual del mercado
# ⚡ Panel Medio Derecho: Volatilidad rolling (ventana de 10 períodos)
# 🔄 Panel Inferior Izquierdo: Price changes (cambios de precio)
# 📈 Panel Inferior Derecho: Gauge del spread promedio
#
# 💡 TIPS DE ANÁLISIS:
# • Busca patrones en el spread durante la crisis (tick 10+)
# • Observa cómo la volatilidad se dispara durante el crash
# • Nota el desequilibrio en la profundidad del mercado
# • Analiza la distribución de price changes (colores)
# • El gauge muestra si el spread está en niveles normales

# %%
# 📋 REPORTE EJECUTIVO COMPLETO

print("📋 Generando REPORTE EJECUTIVO de Market Quality...")
print("🎯 Resumen completo para presentación a stakeholders...")
print("\n")

# Generar reporte ejecutivo
market_analyzer.print_summary_report()

print("\n" + "🎓 REFLEXIONES ACADÉMICAS:")
print("=" * 70)
print("🤔 Preguntas para el análisis crítico:")
print()
print("1️⃣ ¿Cómo cambió el spread durante la crisis vs períodos normales?")
print("2️⃣ ¿Qué indica el liquidity imbalance sobre el comportamiento de traders?")  
print("3️⃣ ¿La volatilidad observada es consistente con una crisis de liquidez?")
print("4️⃣ ¿Qué nivel de market efficiency esperarías en una crisis real?")
print("5️⃣ ¿Cómo usarían estas métricas los reguladores para intervenir?")
print()
print("💡 Piensa en términos de:")
print("   • Risk management en fondos de inversión")
print("   • Decisiones de market making")
print("   • Regulación de estabilidad financiera")
print("   • Optimización de algoritmos de trading")
print()
print("=" * 70)
# Out:
# 📋 Generando REPORTE EJECUTIVO de Market Quality...
# 🎯 Resumen completo para presentación a stakeholders...
#
#
# ...
# 📊 MARKET QUALITY ANALYSIS REPORT
# ...
# ⏰ Generated: 2025-09-18 17:57:58
#
# 💰 SPREAD ANALYSIS:
#    • Average Spread: $1.7483
#    • Spread Volatility: $0.5867
#    • Relative Spread: 175.60 bps
#    • Spread Stability: 0.336
#    • Tight Market Time: 26.7%
#
# 📊 LIQUIDITY & DEPTH:
#    • Total Volume: 532 shares
#    • Market Levels: 10 price levels
#    • Liquidity Imbalance: -25.9%
#    • Depth Symmetry: 0.588
#    • Top-Level Concentration: 19.3%
#
# ⚡ VOLATILITY & RISK:
#    • Realized Volatility: 0.399%
#    • Annualized Volatility: 240.2%
#    • Sharpe Ratio: -0.050
#    • Skewness: +0.000
#    • Max Drawdown: -1.46%
#
# 🔄 PRICE DISCOVERY & EFFICIENCY:
#    • Market Efficiency: 59.8%
#    • Price Discovery Speed: 0.713
#    • Mean Reversion: 0.402
#    • Price Persistence: -0.402
#
# ...
# 🎯 MARKET HEALTH INTERPRETATION:
#    ⚠️  SPREAD: Moderately volatile
# ...

# %%
# 📊 ANÁLISIS COMPLETO DE LA DISTRIBUCIÓN DE RETORNOS
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px
from scipy import stats
import pandas as pd

# Generar datos de retornos simulados basados en las métricas calculadas
# Usaremos los parámetros de la crisis que ya tenemos
np.random.seed(42)  # Para reproducibilidad

# Simular retornos usando los parámetros del mercado
n_periods = 1000
base_vol = volatility_metrics['realized_volatility'] / np.sqrt(252)  # Vol diaria
mean_return = 0.0001  # Pequeño drift positivo

# Crear retornos con características no normales
returns = []
for i in range(n_periods):
    # Agregar clustering de volatilidad
    if i > 0 and abs(returns[-1]) > 2 * base_vol:
        vol_multiplier = 1.5  # Mayor volatilidad después de movimientos grandes
    else:
        vol_multiplier = 1.0
    
    # Generar return con skew y kurtosis
    random_shock = np.random.standard_t(df=5)  # t-distribution para fat tails
    daily_return = mean_return + base_vol * vol_multiplier * random_shock
    
    # Añadir sesgo ocasional (skew)
    if np.random.random() < 0.1:  # 10% de probabilidad
        daily_return += np.random.exponential(base_vol) * np.random.choice([-1, 1])
    
    returns.append(daily_return)

returns = np.array(returns)

# Calcular estadísticas descriptivas
mean_return = np.mean(returns)
std_return = np.std(returns)
skewness = stats.skew(returns)
kurt = stats.kurtosis(returns)
jarque_bera_stat, jarque_bera_p = stats.jarque_bera(returns)

# Test de normalidad Shapiro-Wilk (para muestras < 5000)
if len(returns) < 5000:
    shapiro_stat, shapiro_p = stats.shapiro(returns)
else:
    # Para muestras grandes usamos Kolmogorov-Smirnov
    ks_stat, ks_p = stats.kstest(returns, 'norm', args=(mean_return, std_return))

print("🔬 ANÁLISIS ESTADÍSTICO DE LA DISTRIBUCIÓN DE RETORNOS")
print("=" * 60)
print(f"📊 Número de observaciones: {len(returns):,}")
print(f"📈 Media: {mean_return:.6f}")
print(f"📊 Desviación estándar: {std_return:.6f}")
print(f"📐 Skewness: {skewness:.4f}")
print(f"📊 Kurtosis: {kurt:.4f}")
print(f"📊 Kurtosis exceso: {kurt - 3:.4f}")
print("\n🧪 TESTS DE NORMALIDAD:")
print("-" * 30)
print(f"🔬 Jarque-Bera test:")
print(f"   Estadístico: {jarque_bera_stat:.4f}")
print(f"   P-value: {jarque_bera_p:.6f}")
print(f"   ¿Normal?: {'NO' if jarque_bera_p < 0.05 else 'SÍ'}")

if len(returns) < 5000:
    print(f"🔬 Shapiro-Wilk test:")
    print(f"   Estadístico: {shapiro_stat:.4f}")
    print(f"   P-value: {shapiro_p:.6f}")
    print(f"   ¿Normal?: {'NO' if shapiro_p < 0.05 else 'SÍ'}")
else:
    print(f"🔬 Kolmogorov-Smirnov test:")
    print(f"   Estadístico: {ks_stat:.4f}")
    print(f"   P-value: {ks_p:.6f}")
    print(f"   ¿Normal?: {'NO' if ks_p < 0.05 else 'SÍ'}")

# Crear figura con subplots
fig = make_subplots(
    rows=2, cols=2,
    subplot_titles=(
        '📊 Distribución de Retornos vs Normal',
        '📐 Q-Q Plot vs Distribución Normal', 
        '📈 Colas de la Distribución (Log Scale)',
        '🎯 Análisis de Outliers'
    ),
    specs=[[{"secondary_y": False}, {"secondary_y": False}],
           [{"secondary_y": False}, {"secondary_y": False}]]
)

# 1. Histograma con comparación normal
fig.add_trace(
    go.Histogram(
        x=returns,
        nbinsx=50,
        histnorm='probability density',
        name='Retornos Observados',
        marker_color='lightblue',
        opacity=0.7
    ),
    row=1, col=1
)

# Distribución normal teórica
x_normal = np.linspace(returns.min(), returns.max(), 100)
normal_dist = stats.norm.pdf(x_normal, mean_return, std_return)
fig.add_trace(
    go.Scatter(
        x=x_normal,
        y=normal_dist,
        mode='lines',
        name='Normal Teórica',
        line=dict(color='red', width=2)
    ),
    row=1, col=1
)

# 2. Q-Q Plot
sorted_returns = np.sort(returns)
theoretical_quantiles = stats.norm.ppf(np.linspace(0.01, 0.99, len(returns)), mean_return, std_return)

fig.add_trace(
    go.Scatter(
        x=theoretical_quantiles,
        y=sorted_returns,
        mode='markers',
        name='Q-Q Plot',
        marker=dict(color='blue', size=4, opacity=0.6)
    ),
    row=1, col=2
)

# Línea de referencia para Q-Q plot
min_val = min(theoretical_quantiles.min(), sorted_returns.min())
max_val = max(theoretical_quantiles.max(), sorted_returns.max())
fig.add_trace(
    go.Scatter(
        x=[min_val, max_val],
        y=[min_val, max_val],
        mode='lines',
        name='Línea 45°',
        line=dict(color='red', dash='dash')
    ),
    row=1, col=2
)

# 3. Análisis de colas (Log scale)
hist_values, bin_edges = np.histogram(returns, bins=50, density=True)
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

# Filtrar valores positivos para log scale
positive_hist = hist_values[hist_values > 0]
positive_centers = bin_centers[hist_values > 0]

fig.add_trace(
    go.Scatter(
        x=positive_centers,
        y=positive_hist,
        mode='lines+markers',
        name='Densidad Observada',
        line=dict(color='blue'),
        marker=dict(size=4)
    ),
    row=2, col=1
)

normal_density = stats.norm.pdf(positive_centers, mean_return, std_return)
fig.add_trace(
    go.Scatter(
        x=positive_centers,
        y=normal_density,
        mode='lines',
        name='Densidad Normal',
        line=dict(color='red', dash='dash')
    ),
    row=2, col=1
)

# 4. Box plot para outliers
fig.add_trace(
    go.Box(
        y=returns,
        name='Retornos',
        boxpoints='outliers',
        marker_color='lightgreen'
    ),
    row=2, col=2
)

# Configurar ejes y layout
fig.update_xaxes(title_text="Retornos", row=1, col=1)
fig.update_yaxes(title_text="Densidad", row=1, col=1)

fig.update_xaxes(title_text="Cuantiles Teóricos", row=1, col=2)
fig.update_yaxes(title_text="Cuantiles Observados", row=1, col=2)

fig.update_xaxes(title_text="Retornos", row=2, col=1)
fig.update_yaxes(title_text="Densidad (Log Scale)", type="log", row=2, col=1)

fig.update_yaxes(title_text="Retornos", row=2, col=2)

fig.update_layout(
    height=800,
    title_text="🔬 Análisis Completo de la Distribución de Retornos",
    showlegend=True,
    template="plotly_white"
)

fig.show()

# Calcular percentiles para análisis de colas
percentiles = [0.1, 1, 5, 95, 99, 99.9]
observed_percentiles = np.percentile(returns, percentiles)
normal_percentiles = stats.norm.ppf(np.array(percentiles)/100, mean_return, std_return)

print(f"\n🎯 ANÁLISIS DE COLAS:")
print("-" * 30)
for i, p in enumerate(percentiles):
    obs = observed_percentiles[i]
    norm = normal_percentiles[i]
    ratio = abs(obs/norm) if norm != 0 else float('inf')
    print(f"Percentil {p:4.1f}%: Obs={obs:8.5f}, Normal={norm:8.5f}, Ratio={ratio:.2f}")

# Interpretación automática
print(f"\n🧠 INTERPRETACIÓN AUTOMÁTICA:")
print("=" * 50)

if abs(skewness) > 0.5:
    skew_direction = "derecha (positiva)" if skewness > 0 else "izquierda (negativa)"
    print(f"📐 SKEWNESS: SIGNIFICATIVO hacia la {skew_direction}")
    print(f"    Valor: {skewness:.3f} (>0.5 en valor absoluto)")
else:
    print(f"📐 SKEWNESS: MODERADO ({skewness:.3f})")

if kurt > 3:
    excess_kurt = kurt - 3
    if excess_kurt > 2:
        print(f"📊 KURTOSIS: COLAS MUY GRUESAS (fat tails)")
        print(f"    Exceso de kurtosis: {excess_kurt:.3f} (>>0)")
        print(f"    🚨 Riesgo de eventos extremos ALTO")
    else:
        print(f"📊 KURTOSIS: COLAS GRUESAS moderadas")
        print(f"    Exceso de kurtosis: {excess_kurt:.3f}")
elif kurt < 3:
    print(f"📊 KURTOSIS: COLAS DELGADAS ({kurt:.3f} < 3)")
else:
    print(f"📊 KURTOSIS: NORMAL ({kurt:.3f} ≈ 3)")

if jarque_bera_p < 0.05:
    print(f"🔬 NORMALIDAD: RECHAZADA (p-value: {jarque_bera_p:.6f})")
    print(f"    Los retornos NO siguen una distribución normal")
else:
    print(f"🔬 NORMALIDAD: NO RECHAZADA (p-value: {jarque_bera_p:.6f})")
    print(f"    Los retornos podrían seguir una distribución normal")

print(f"\n💡 IMPLICACIONES PARA TRADING:")
print("-" * 40)
if abs(skewness) > 0.5 or kurt > 5:
    print("⚠️  Usar modelos que capturen asimetría y colas gruesas")
    print("⚠️  VaR tradicional puede subestimar riesgo")
    print("⚠️  Considerar Expected Shortfall (CVaR)")
if jarque_bera_p < 0.05:
    print("⚠️  Los modelos basados en normalidad no son apropiados")
    print("⚠️  Usar distribuciones t de Student o skewed-t")
# Out:
# 🔬 ANÁLISIS ESTADÍSTICO DE LA DISTRIBUCIÓN DE RETORNOS
# ...
# 📊 Número de observaciones: 1,000
# 📈 Media: 0.000111
# 📊 Desviación estándar: 0.000369
# 📐 Skewness: -0.2974
# 📊 Kurtosis: 3.1840
# 📊 Kurtosis exceso: 0.1840
#
# 🧪 TESTS DE NORMALIDAD:
# ------------------------------
# 🔬 Jarque-Bera test:
#    Estadístico: 437.1510
#    P-value: 0.000000
#    ¿Normal?: NO
# 🔬 Shapiro-Wilk test:
#    Estadístico: 0.9724
#    P-value: 0.000000
#    ¿Normal?: NO
# 🎯 ANÁLISIS DE COLAS:
# ------------------------------
# Percentil  0.1%: Obs=-0.00155, Normal=-0.00103, Ratio=1.51
# Percentil  1.0%: Obs=-0.00089, Normal=-0.00075, Ratio=1.19
# Percentil  5.0%: Obs=-0.00046, Normal=-0.00050, Ratio=0.93
# Percentil 95.0%: Obs= 0.00070, Normal= 0.00072, Ratio=0.97
# Percentil 99.0%: Obs= 0.00100, Normal= 0.00097, Ratio=1.03
# Percentil 99.9%: Obs= 0.00138, Normal= 0.00125, Ratio=1.10
#
# 🧠 INTERPRETACIÓN AUTOMÁTICA:
# ...
# 📐 SKEWNESS: MODERADO (-0.297)
# 📊 KURTOSIS: COLAS GRUESAS moderadas
# ...

# %% [markdown]
# ### 📈 **Conclusiones del Análisis de Distribución de Retornos**
#
# <div style='background: linear-gradient(135deg, #2d3436, #636e72); padding: 20px; border-radius: 15px; color: white; margin: 20px 0;'>
# <h3>🔬 INTERPRETACIÓN ESTADÍSTICA PROFESIONAL</h3>
# <p><i>¿Qué nos revela la forma de la distribución sobre la naturaleza del mercado?</i></p>
# </div>
#
# #### 📊 **Diagnóstico de No-Normalidad:**
#
# <div style="background-color: #fff5f5; border: 2px solid #e53e3e; padding: 15px; border-radius: 10px; margin: 15px 0;">
# <h4 style="color: #e53e3e;">🚨 <b>VEREDICTO: DISTRIBUCIÓN NO NORMAL</b></h4>
# <div style="display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 15px; margin: 15px 0;">
# <div style="background-color: #fed7d7; padding: 10px; border-radius: 5px; text-align: center;">
# <h5 style="color: #c53030;">📐 SKEWNESS</h5>
# <p style="color: #822727; font-size: 14px;"><b>-0.297</b><br>Asimetría hacia izquierda<br><i>Colas más gruesas en pérdidas</i></p>
# </div>
# <div style="background-color: #fed7d7; padding: 10px; border-radius: 5px; text-align: center;">
# <h5 style="color: #c53030;">📊 KURTOSIS</h5>
# <p style="color: #822727; font-size: 14px;"><b>3.184</b><br>Exceso: +0.184<br><i>Colas ligeramente más gruesas</i></p>
# </div>
# <div style="background-color: #fed7d7; padding: 10px; border-radius: 5px; text-align: center;">
# <h5 style="color: #c53030;">🔬 JARQUE-BERA</h5>
# <p style="color: #822727; font-size: 14px;"><b>437.15</b><br>p < 0.001<br><i>Rechaza normalidad</i></p>
# </div>
# </div>
# </div>
#
# #### 🎯 **Análisis de Colas - ¿Fat Tails?**
#
# <div style="background-color: #2c3e50; border: 1px solid #34495e; padding: 15px; border-radius: 5px; color: white; margin: 15px 0;">
# <h4 style="color: white;">🔍 <b>Análisis de Percentiles Extremos:</b></h4>
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px; margin: 15px 0;">
# <div style="background: rgba(231, 76, 60, 0.3); padding: 15px; border-radius: 5px; border-left: 4px solid #e74c3c;">
# <h5 style="color: #e74c3c;">📉 <b>COLA IZQUIERDA (Pérdidas)</b></h5>
# <ul style="color: white; font-size: 14px;">
#     <li><b>0.1% extreme:</b> 1.51x más gruesa que normal</li>
#     <li><b>1% tail:</b> 1.19x más gruesa que normal</li>
#     <li><b>Interpretación:</b> Mayor riesgo de pérdidas extremas</li>
# </ul>
# </div>
# <div style="background: rgba(46, 204, 113, 0.3); padding: 15px; border-radius: 5px; border-left: 4px solid #2ecc71;">
# <h5 style="color: #2ecc71;">📈 <b>COLA DERECHA (Ganancias)</b></h5>
# <ul style="color: white; font-size: 14px;">
#     <li><b>99% tail:</b> 1.03x similar a normal</li>
#     <li><b>99.9% extreme:</b> 1.10x ligeramente gruesa</li>
#     <li><b>Interpretación:</b> Ganancias extremas menos probables</li>
# </ul>
# </div>
# </div>
# </div>
#
# #### 🧮 **Implicaciones Cuantitativas:**
#
# <div style="display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 15px; margin: 20px 0;">
#
# <div style="background-color: #e8f5e8; border-left: 5px solid #28a745; padding: 15px; color: #155724;">
# <h4 style="color: #28a745;">📊 <b>Risk Management</b></h4>
# <ul style="color: #155724; font-size: 13px;">
#     <li><b>VaR tradicional:</b> Subestima riesgo</li>
#     <li><b>Usar CVaR:</b> Expected Shortfall</li>
#     <li><b>Stress testing:</b> Obligatorio</li>
#     <li><b>Backtesting:</b> Frecuente</li>
# </ul>
# </div>
#
# <div style="background-color: #fff3cd; border-left: 5px solid #f39c12; padding: 15px; color: #856404;">
# <h4 style="color: #f39c12;">🎯 <b>Option Pricing</b></h4>
# <ul style="color: #856404; font-size: 13px;">
#     <li><b>Black-Scholes:</b> No apropiado</li>
#     <li><b>Volatility smile:</b> Incorporar</li>
#     <li><b>Jump models:</b> Considerar</li>
#     <li><b>Stochastic vol:</b> Heston, SABR</li>
# </ul>
# </div>
#
# <div style="background-color: #f8d7da; border-left: 5px solid #dc3545; padding: 15px; color: #721c24;">
# <h4 style="color: #dc3545;">🤖 <b>Algorithmic Trading</b></h4>
# <ul style="color: #721c24; font-size: 13px;">
#     <li><b>Stop losses:</b> Más conservadores</li>
#     <li><b>Position sizing:</b> Kelly ajustado</li>
#     <li><b>Regime detection:</b> Crucial</li>
#     <li><b>Diversification:</b> Premium</li>
# </ul>
# </div>
#
# </div>
#
# #### 📚 **Distribuciones Alternativas Recomendadas:**
#
# <div style="background: linear-gradient(90deg, #667eea, #764ba2); padding: 15px; border-radius: 8px; color: white; margin: 15px 0;">
# <h4>🎲 <b>¿Qué distribuciones usar en lugar de la Normal?</b></h4>
#
# <div style="display: grid; grid-template-columns: 1fr 1fr 1fr; gap: 15px; margin: 15px 0;">
# <div style="background: rgba(255,255,255,0.2); padding: 10px; border-radius: 5px;">
# <h5 style="color: #FFD700;">📊 t-STUDENT</h5>
# <ul style="color: white; font-size: 13px;">
#     <li>Colas más gruesas</li>
#     <li>Parameter: degrees of freedom</li>
#     <li>Usado en: VaR, CVaR</li>
# </ul>
# </div>
# <div style="background: rgba(255,255,255,0.2); padding: 10px; border-radius: 5px;">
# <h5 style="color: #FF6B35;">📊 SKEWED-t</h5>
# <ul style="color: white; font-size: 13px;">
#     <li>Asimetría + colas gruesas</li>
#     <li>Más realista</li>
#     <li>Usado en: option pricing</li>
# </ul>
# </div>
# <div style="background: rgba(255,255,255,0.2); padding: 10px; border-radius: 5px;">
# <h5 style="color: #00C851;">📊 MIXTURE</h5>
# <ul style="color: white; font-size: 13px;">
#     <li>Combina regímenes</li>
#     <li>Jump diffusion</li>
#     <li>Usado en: crisis modeling</li>
# </ul>
# </div>
# </div>
# </div>
#
# #### ⚡ **Impacto en Estrategias de Trading:**
#
# <div style="background-color: #f8f9fa; border: 2px solid #6c757d; padding: 20px; border-radius: 10px; margin: 15px 0;">
# <h4 style="color: #495057;">💼 <b>Ajustes Estratégicos Recomendados:</b></h4>
#
# | 🎯 **Aspecto** | ❌ **Enfoque Normal** | ✅ **Enfoque No-Normal** |
# |:---|:---|:---|
# | **Position Sizing** | Kelly simple | Kelly ajustado por fat tails |
# | **Stop Losses** | 2σ = 95% confianza | 2.5-3σ para mismo nivel |
# | **Volatility Forecasting** | GARCH simple | GARCH-t, GJR-GARCH |
# | **Portfolio Optimization** | Mean-variance | CVaR optimization |
# | **Hedging** | Delta hedging | Gamma hedging obligatorio |
# | **Backtesting** | Shaprio-ratio | Sortino, Calmar ratios |
#
# </div>
#
# #### 🔬 **Interpretación del Q-Q Plot:**
#
# <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px; margin: 20px 0;">
#
# <div style="background-color: #e8f4f8; border: 2px solid #007BFF; padding: 15px; border-radius: 10px;">
# <h4 style="color: #007BFF;">📈 <b>¿Qué vemos en el gráfico?</b></h4>
# <ul style="color: #004085; font-size: 14px;">
#     <li><b>Línea recta:</b> Distribución normal perfecta</li>
#     <li><b>S-shape:</b> Colas más gruesas que normal</li>
#     <li><b>Desviación extremos:</b> Fat tails confirmadas</li>
#     <li><b>Curvatura:</b> Indica kurtosis excess</li>
# </ul>
# </div>
#
# <div style="background-color: #f3e2f3; border: 2px solid #6f42c1; padding: 15px; border-radius: 10px;">
# <h4 style="color: #6f42c1;">🎯 <b>¿Cómo interpretarlo?</b></h4>
# <ul style="color: #493558; font-size: 14px;">
#     <li><b>Zona central:</b> Comportamiento normal</li>
#     <li><b>Extremos inferiores:</b> Más pérdidas severas</li>
#     <li><b>Extremos superiores:</b> Ganancias limitadas</li>
#     <li><b>Patrón asimétrico:</b> Skew negativo</li>
# </ul>
# </div>
#
# </div>
#
# #### 💡 **Conclusión Ejecutiva:**
#
# <div style="background: linear-gradient(45deg, #ff6b6b, #feca57); padding: 20px; border-radius: 10px; color: white; margin: 20px 0; border: 3px solid #ff4757;">
# <h4>🧠 <b>INSIGHTS CLAVE PARA STUDENTS:</b></h4>
# <div style="margin: 15px 0;">
# <p style="font-size: 16px; margin: 10px 0;"><b>1. 🚫 MITO:</b> "Los retornos financieros son normales" ➜ <b>FALSO</b></p>
# <p style="font-size: 16px; margin: 10px 0;"><b>2. ⚠️ REALIDAD:</b> Colas gruesas y asimetría son la norma</p>
# <p style="font-size: 16px; margin: 10px 0;"><b>3. 🎯 IMPLICACIÓN:</b> Los modelos tradicionales subestiman riesgo</p>
# <p style="font-size: 16px; margin: 10px 0;"><b>4. 🛡️ SOLUCIÓN:</b> Usar modelos más sofisticados y robustos</p>
# </div>
# </div>
#
# ---
