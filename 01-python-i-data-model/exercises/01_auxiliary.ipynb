# %% [markdown]
# # Clase 1 · Práctica para casa
#
# 10 ejercicios de refuerzo · unos 23 min orientativos. Consolidan lo necesario para la siguiente clase.
#
# Completa una celda y ejecuta su comprobación con **Shift+Enter**. Abre la pista si te atascas.

# %% [markdown]
# <a id="L01-B03"></a>
#
# ### Una lista que crece
#
# Añade `102` al final de `mids` y guarda `first_mid`, `last_mid` y `n_mids`.
# Después guarda `first2` y `last3` con los dos primeros y los tres últimos precios:
# deben ser `[99, 100]` y `[98, 101, 102]`.

# %%
mids = [99, 100, 98, 101]
# Añade el precio antes de consultar la lista.
first_mid = None
last_mid = None
n_mids = None
first2 = None
last3 = None

# %%
from practice_checks import comprobar
comprobar('L01-B03')

# %% [markdown]
# <details>
# <summary>Pista</summary>
#
# `append` modifica la lista; `[-3:]` selecciona sus tres últimos elementos.
#
# </details>

# %% [markdown]
# <a id="L01-B04"></a>
#
# ### Suma y media
#
# Recorre `mids` con un `for` para calcular `total` y después `average`.
# Comprueba la suma con `total_sum = sum(mids)` y guarda también `lowest` y `highest`:
# la suma debe ser `404`, la media `101`, el mínimo `99` y el máximo `104`.

# %%
mids = [99, 101, 100, 104]
total = 0
# Acumula con un for y calcula la media fuera del bucle.
average = None
total_sum = None
lowest = None
highest = None

# %%
from practice_checks import comprobar
comprobar('L01-B04')

# %% [markdown]
# <details>
# <summary>Pista</summary>
#
# Empieza en cero; divide por `len(mids)` después del bucle.
#
# </details>

# %% [markdown]
# <a id="L01-B05"></a>
#
# ### Los campos de una orden
#
# Crea `order` con `symbol='BTCUSDT'`, `side='buy'`, `price=100` y `size=0.5`.
# Lee su lado en `order_side` y calcula `order_notional` multiplicando los campos
# de precio y tamaño: deben resultar `'buy'` y `50`.

# %%
order = {}
order_side = None
order_notional = None

# %%
from practice_checks import comprobar
comprobar('L01-B05')

# %% [markdown]
# <details>
# <summary>Pista</summary>
#
# Lee un campo con `order['campo']`.
#
# </details>

# %% [markdown]
# <a id="L01-A09"></a>
#
# ### Un ticket legible
#
# Construye `ticket` con una f-string a partir de los cuatro datos dados.
# Debe resultar exactamente `'BUY 0.5 BTCUSDT @ 99950.00'`, con el lado en
# mayúsculas y el precio con dos decimales.

# %%
side = 'buy'
size = 0.5
symbol = 'BTCUSDT'
price = 99950
ticket = None

# %%
from practice_checks import comprobar
comprobar('L01-A09')

# %% [markdown]
# <details>
# <summary>Pista</summary>
#
# `f"{price:.2f}"` inserta el precio con dos decimales.
#
# </details>

# %% [markdown]
# <a id="L01-A07"></a>
#
# ### Limpia un símbolo
#
# Guarda en `clean` el texto de `raw` sin espacios exteriores y en mayúsculas.
# Guarda en `is_usdt` si termina en `'USDT'`: deben resultar `'BTCUSDT'` y `True`.

# %%
raw = '  btcusdt '
clean = None
is_usdt = None

# %%
from practice_checks import comprobar
comprobar('L01-A07')

# %% [markdown]
# <details>
# <summary>Pista</summary>
#
# Puedes encadenar `raw.strip().upper()`.
#
# </details>

# %% [markdown]
# <a id="L01-A08"></a>
#
# ### Del texto a los precios
#
# El texto `quote_str` contiene un bid y un ask separados por `/`.
# Sepáralos y guarda `bid=99` y `ask=101` como enteros.

# %%
quote_str = '99/101'
bid = None
ask = None

# %%
from practice_checks import comprobar
comprobar('L01-A08')

# %% [markdown]
# <details>
# <summary>Pista</summary>
#
# `split('/')` devuelve los fragmentos; `int` convierte cada uno.
#
# </details>

# %% [markdown]
# <a id="L01-A18"></a>
#
# ### Consulta y actualiza posiciones
#
# Antes de modificar `positions`, guarda `btc_pos` y `eth_pos` usando `get`
# con default `0`, y `had_eth` comprobando si existe la clave `'ETHUSDT'`.
# Después suma `0.2` a BTC y añade `1.0` ETH: los valores iniciales deben ser
# `0.5`, `0` y `False`, y las posiciones finales `0.7` y `1.0`.

# %%
positions = {'BTCUSDT': 0.5}
btc_pos = None
eth_pos = None
had_eth = None
# Actualiza las dos posiciones después de consultarlas.

# %%
from practice_checks import comprobar
comprobar('L01-A18')

# %% [markdown]
# <details>
# <summary>Pista</summary>
#
# `get` consulta sin añadir la clave; asignar a `positions[clave]` sí la actualiza.
#
# </details>

# %% [markdown]
# <a id="L01-B06"></a>
#
# ### Clasifica cuatro spreads
#
# Recorre `spreads` y añade a `market_states` una clasificación por valor:
# `'tight'` hasta `20`, `'normal'` por encima de `20` y hasta `60`, o `'wide'` si supera `60`.
# Debes obtener `['tight', 'normal', 'normal', 'wide']` usando `if`, `elif` y `else`.

# %%
spreads = [20, 21, 60, 61]
market_states = []
for spread in spreads:
    # Clasifica spread y añade su estado a market_states.
    pass

# %%
from practice_checks import comprobar
comprobar('L01-B06')

# %% [markdown]
# <details>
# <summary>Pista</summary>
#
# Comprueba primero `<= 20`; el `elif <= 60` recibe los que no entraron antes.
#
# </details>

# %% [markdown]
# <a id="L01-A11"></a>
#
# ### Permiso y revisión
#
# Calcula `can_trade`: exige caja, mercado abierto y riesgo válido a la vez.
# Calcula también `needs_review`: será verdadero si falta caja o el riesgo no es
# válido; con los datos dados deben resultar `False` y `True`.

# %%
has_cash = True
market_open = True
risk_ok = False
can_trade = None
needs_review = None

# %%
from practice_checks import comprobar
comprobar('L01-A11')

# %% [markdown]
# <details>
# <summary>Pista</summary>
#
# `and` exige todas, `or` alguna y `not` invierte un booleano.
#
# </details>

# %% [markdown]
# <a id="L01-A02"></a>
#
# ### Redondea un número
#
# Guarda `price_2dec` redondeando `raw_price` a dos decimales y `size_whole`
# redondeando `3.7` al entero más cercano.
# Deben resultar `125.46` y `4`.

# %%
raw_price = 125.4567
price_2dec = None
size_whole = None

# %%
from practice_checks import comprobar
comprobar('L01-A02')

# %% [markdown]
# <details>
# <summary>Pista</summary>
#
# `round(valor, 2)` redondea a dos decimales.
#
# </details>

# %% [markdown]
# Al terminar, guarda el notebook. Retomaremos tu proyecto en la siguiente clase.
