# %% [markdown]
# # Clase 1 — Auxiliares · el gimnasio
#
# 22 ejercicios cortos sobre *Python I — El modelo de datos*: drills para ganar soltura y abordar la misma pieza desde otros ángulos. Todo este cuaderno es OPTIONAL; la construcción completa está en el principal.
#
# ⏱️ 🟢 LIVE ~0 min · 🟣 OPTIONAL +60 min.
#
# ## Tu recorrido de estudio
#
# **Pregunta de hoy:** ¿Cómo paso de dos precios en pantalla a una decisión que otra persona pueda reproducir?
#
# **Punto de partida.** Sin programar: con bid 99 y ask 101, distingue el coste de cruzar ambos lados del punto medio de la quote.
#
# **Comprueba antes de avanzar:** Spread 2 y mid 100; ninguno dice por sí solo que comprar vaya a ser rentable.
#
# Sigue los bloques en orden. En clase haces los **LIVE**; después completas los **REQUIRED** del principal, incluida la construcción en tus archivos. El auxiliar contiene solo variantes OPTIONAL. Los IDs históricos A/B identifican ejercicios, no su ruta. Los tiempos son orientativos, no un límite para aprender.
#
# ### 1. Nombrar y calcular una quote
#
# Pon nombres al dato y unidades a cada cálculo; los ejercicios numéricos auxiliares consolidan después lo construido en clase.
#
# **Presentación:** [escena 1](../presentation/python-i-data-model-doc.html?mode=estudio#s0) · [escena 2](../presentation/python-i-data-model-doc.html?mode=estudio#s1) · [escena 3](../presentation/python-i-data-model-doc.html?mode=estudio#s2).
#
# **Prepara y construye en el principal:** [B01](01_build_exercises.ipynb#L01-B01) (LIVE, 3 min) · [B02](01_build_exercises.ipynb#L01-B02) (LIVE, 4 min) · [A01](01_build_exercises.ipynb#L01-A01) (REQUIRED, 2 min) · [A02](01_build_exercises.ipynb#L01-A02) (REQUIRED, 2 min) · [A03](01_build_exercises.ipynb#L01-A03) (REQUIRED, 2 min).
#
# **Puedes seguir cuando:** Explica por qué ask − bid es spread y por qué formatear o redondear no valida una orden.
#
# ### 2. Leer una secuencia sin perder observaciones
#
# Pasa de índices a ventana y acumulador; conserva una predicción pequeña antes de ejecutar el bucle.
#
# **Presentación:** [escena 4](../presentation/python-i-data-model-doc.html?mode=estudio#s3).
#
# **Prepara y construye en el principal:** [B03](01_build_exercises.ipynb#L01-B03) (LIVE, 3 min) · [B04](01_build_exercises.ipynb#L01-B04) (REQUIRED, 6 min) · [A13](01_build_exercises.ipynb#L01-A13) (REQUIRED, 2 min) · [A14](01_build_exercises.ipynb#L01-A14) (REQUIRED, 2 min).
#
# **Puedes seguir cuando:** Identifica qué ticks entran y comprueba suma, longitud y media por separado.
#
# ### 3. Dar significado a los campos de una orden
#
# Distingue texto recibido, número convertido y registro de orden; recupera el símbolo al mostrar el ticket.
#
# **Presentación:** [escena 5](../presentation/python-i-data-model-doc.html?mode=estudio#s4).
#
# **Prepara y construye en el principal:** [B05](01_build_exercises.ipynb#L01-B05) (REQUIRED, 6 min) · [A06](01_build_exercises.ipynb#L01-A06) (REQUIRED, 2 min) · [A07](01_build_exercises.ipynb#L01-A07) (REQUIRED, 2 min) · [A08](01_build_exercises.ipynb#L01-A08) (REQUIRED, 2 min) · [A09](01_build_exercises.ipynb#L01-A09) (REQUIRED, 2 min) · [A18](01_build_exercises.ipynb#L01-A18) (REQUIRED, 2 min).
#
# **Puedes seguir cuando:** Lee side, price y size sin mezclar claves y valores; explica cuándo un default es válido y cuándo ocultaría un campo obligatorio.
#
# ### 4. Cerrar dato → cálculo → decisión
#
# La práctica LIVE termina clasificando el mercado y tomando una decisión; en el estudio autónomo comprueba además la puerta de permiso.
#
# **Presentación:** [escena 6](../presentation/python-i-data-model-doc.html?mode=estudio#s5) · [escena 7](../presentation/python-i-data-model-doc.html?mode=estudio#s6) · [escena 8](../presentation/python-i-data-model-doc.html?mode=estudio#s7).
#
# **Prepara y construye en el principal:** [B06](01_build_exercises.ipynb#L01-B06) (LIVE, 4 min) · [B07](01_build_exercises.ipynb#L01-B07) (LIVE, 6 min) · [A11](01_build_exercises.ipynb#L01-A11) (REQUIRED, 2 min).
#
# **Puedes seguir cuando:** Predice las ramas en los límites y separa señal buy, condiciones para operar y promesa de beneficio.
#
# ### Elige tu refuerzo OPTIONAL
#
# Después de la ruta obligatoria, elige el bloque que responda a tu dificultad o curiosidad. No necesitas hacerlos todos; ninguno desbloquea una entrega ni añade materia evaluable. Regresa al ejercicio indicado y comprueba si ahora puedes explicarlo sin copiar.
#
# | Si necesitas… | Practica | Aplica y vuelve |
# |---|---|---|
# | Si mezclas acumulación porcentual, suma y media. | [A4. Interés compuesto](01_auxiliary.ipynb#L01-A04) (2 min) · [A5. Agregados de un vistazo](01_auxiliary.ipynb#L01-A05) (2 min) | Compara potencias con incrementos simples y contrasta un bucle con agregados. Vuelve a [B04](01_build_exercises.ipynb#L01-B04). |
# | Si una condición falla en el borde o confundes and con or. | [A10. Dentro de banda](01_auxiliary.ipynb#L01-A10) (2 min) · [A12. Señal y cautela](01_auxiliary.ipynb#L01-A12) (2 min) · [A25. Semáforo de presión](01_auxiliary.ipynb#L01-A25) (2 min) · [A26. Tarifa por tramos](01_auxiliary.ipynb#L01-A26) (2 min) | Cambia intervalos y magnitudes, pero conserva una tabla mental de casos y fronteras. Vuelve a [B06](01_build_exercises.ipynb#L01-B06). |
# | Si confundes leer una lista, buscar un valor y modificarla. | [A15. Deshaz el último](01_auxiliary.ipynb#L01-A15) (2 min) · [A16. ¿Está el nivel?](01_auxiliary.ipynb#L01-A16) (2 min) · [A17. Ordena el lado bid](01_auxiliary.ipynb#L01-A17) (2 min) | Comprueba qué colección cambia y cuál conserva su orden original. Vuelve a [B03](01_build_exercises.ipynb#L01-B03). |
# | Si cuesta distinguir presencia de una clave, valor guardado y actualización. | [A19. Actualiza la posición](01_auxiliary.ipynb#L01-A19) (2 min) · [A20. ¿Tiene el campo?](01_auxiliary.ipynb#L01-A20) (2 min) · [A21. Radiografía de comisiones](01_auxiliary.ipynb#L01-A21) (2 min) | Usa posiciones y comisiones para afianzar el registro sin mezclar unidades. Vuelve a [B05](01_build_exercises.ipynb#L01-B05). |
# | Si un recorrido necesita varios intentos o el acumulador conserva el dato equivocado. | [A22. Ticks alcistas](01_auxiliary.ipynb#L01-A22) (2 min) · [A23. Censo del libro](01_auxiliary.ipynb#L01-A23) (2 min) · [A24. max() a mano](01_auxiliary.ipynb#L01-A24) (2 min) · [A28. Mejor bid y mejor ask](01_auxiliary.ipynb#L01-A28) (5 min) | Pasa de contar a buscar extremos y filtrar lados de un libro de un solo símbolo. Vuelve a [B04](01_build_exercises.ipynb#L01-B04). |
# | Si ya dominas B07 y quieres reconocer por qué duplicar cálculos será incómodo. | [A27. Función nocional](01_auxiliary.ipynb#L01-A27) (5 min) · [A29. El problema que viene: dos activos](01_auxiliary.ipynb#L01-A29) (5 min) | Anticipa funciones reutilizables y separación por instrumento; L2 las enseñará de nuevo como parte obligatoria. Vuelve a [B07](01_build_exercises.ipynb#L01-B07). |
# | Si el algoritmo ya está claro y quieres inspeccionar cómo lo representa el intérprete. | [8. Pregunta qué Python estás usando](01_auxiliary.ipynb#L01-B08) (2 min) · [9. Mira el bytecode real](01_auxiliary.ipynb#L01-B09) (3 min) · [A30. El alfabeto de la máquina](01_auxiliary.ipynb#L01-A30) (5 min) · [A31. Ver el bytecode con dis](01_auxiliary.ipynb#L01-A31) (5 min) | Distingue texto, código compilado y ejecución sin memorizar herramientas opcionales. Vuelve a [B07](01_build_exercises.ipynb#L01-B07). |
#
# ### De la práctica a tu proyecto
#
# Lleva solo las fórmulas de spread y mid a student_project/exchange/snapshot.py. Comprueba allí una quote nueva; la decisión del notebook usa esos cálculos, pero no sustituye tus funciones persistentes.
#
# **Siguiente paso:** En L2 conservaremos dato, cálculo y decisión, pero dejaremos de copiar fórmulas: una función recibirá órdenes y leerá el libro de un instrumento.

# %% [markdown]
# ### El gimnasio
#
# Cada ejercicio declara una ruta pedagógica, decidida por contenido y no por posición: **🟢 LIVE** (núcleo presencial) · **🔵 REQUIRED** (consolidación autónoma requerida y evaluable) · **🟣 OPTIONAL** (profundización no obligatoria y no evaluable). Escribe tu respuesta, ejecuta la **✅ comprobación plegada** con `Shift+Enter` y usa la pista cuando la necesites; las soluciones docentes no se incluyen.

# %% [markdown]
# <a id="L01-A04"></a>
#
# ### A4. Interés compuesto
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~2 min</sub>
#
# **Por qué lo hacemos.** Practica potencias distinguiendo repetir un porcentaje de sumar porcentajes. El 1% diario es un supuesto de cálculo, no una previsión de BTC; compáralo con diez incrementos simples.
#
# **Tu tarea.** Si BTC subiera un 1% al día durante 10 días, el multiplicador total es `(1 + 0.01) ** 10`. Guárdalo en `growth`.
#
# <sub>practicas: ** (potencias)</sub>

# %%
growth = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert growth is not None, '⏸ growth sigue en None: completa el ejercicio antes de validar'
assert round(growth, 4) == 1.1046, 'mas que 1.10: el interes compuesto compone'
print('ok ->', round(growth, 4))

# %% [markdown]
# <a id="L01-A05"></a>
#
# ### A5. Agregados de un vistazo
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~2 min</sub>
#
# **Por qué lo hacemos.** Comprueba el bucle de B04 con agregados incorporados. Si la suma coincide pero la media no, revisa el número de observaciones antes de cambiar el acumulador.
#
# **Tu tarea.** De `mids`, guarda `lowest`, `highest` y `total` usando `min`, `max` y `sum` (sin bucles).
#
# <sub>practicas: min / max / sum</sub>

# %%
mids = [99975, 99980, 99970, 99990, 100005]
lowest = None
highest = None
total = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert lowest is not None, '⏸ lowest sigue en None: completa el ejercicio antes de validar'
assert highest is not None, '⏸ highest sigue en None: completa el ejercicio antes de validar'
assert total is not None, '⏸ total sigue en None: completa el ejercicio antes de validar'
assert lowest == 99970 and highest == 100005
assert total == 499920
print('ok')

# %% [markdown]
# <a id="L01-A10"></a>
#
# ### A10. Dentro de banda
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~2 min</sub>
#
# **Por qué lo hacemos.** Practica los límites de una condición con un precio dentro, fuera y exactamente en el borde. Vuelve a B06 y comprueba allí qué rama recibe cada frontera.
#
# **Tu tarea.** Guarda `in_band` (si `mid` está entre `low` y `high`, ambos incluidos) y `outside` (lo contrario, usando `not`).
#
# <sub>practicas: comparaciones encadenadas</sub>

# %%
mid = 99975
low = 99900
high = 100000
in_band = None
outside = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert in_band is not None, '⏸ in_band sigue en None: completa el ejercicio antes de validar'
assert outside is not None, '⏸ outside sigue en None: completa el ejercicio antes de validar'
assert in_band is True and outside is False
print('ok')

# %% [markdown]
# <a id="L01-A12"></a>
#
# ### A12. Señal y cautela
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~2 min</sub>
#
# **Por qué lo hacemos.** Combina dos observaciones sin confundir and con or: aquí imbalance es un dato proporcionado, no una fórmula pendiente. Explica cuándo puede aparecer cautela aunque la señal de compra sea falsa.
#
# **Tu tarea.** `signal` = spread estrecho (`< 20`) **y** imbalance comprador (`> 0.3`). `caution` = spread ancho (`>= 60`) **o** imbalance vendedor (`< 0`).
#
# <sub>practicas: and / or</sub>

# %%
spread = 15
imbalance = 0.4
signal = None
caution = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert signal is not None, '⏸ signal sigue en None: completa el ejercicio antes de validar'
assert caution is not None, '⏸ caution sigue en None: completa el ejercicio antes de validar'
assert signal is True
assert caution is False
print('ok')

# %% [markdown]
# <a id="L01-A25"></a>
#
# ### A25. Semáforo de presión
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~2 min</sub>
#
# **Por qué lo hacemos.** Repite las ramas de B06 con una magnitud que puede ser positiva o negativa. Comprueba especialmente ±0.3: una frontera mal escrita cambia qué significa estar equilibrado.
#
# **Tu tarea.** Clasifica `pressure`: `'buy_pressure'` si imbalance > 0.3, `'sell_pressure'` si < -0.3, `'balanced'` en medio.
#
# <sub>practicas: if / elif / else</sub>

# %%
imbalance = 0.42
# escribe el if / elif / else

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert pressure == 'buy_pressure'
print('ok ->', pressure)

# %% [markdown]
# <a id="L01-A26"></a>
#
# ### A26. Tarifa por tramos
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~2 min</sub>
#
# **Por qué lo hacemos.** Una tabla de tarifas convierte intervalos de nocional en una comisión monetaria. Revisa los umbrales antes de multiplicar y distingue bps de porcentaje al volver a B06.
#
# **Tu tarea.** Comisión por tramos: <10k → 10 bps; <100k → 8; <1M → 5; si no → 3. Guarda `fee_bps` y calcula `fee = notional * fee_bps / 10000`.
#
# <sub>practicas: umbrales escalonados + cálculo</sub>

# %%
notional = 250000
fee_bps = None
# ... y calcula fee

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert fee_bps is not None, '⏸ fee_bps sigue en None: completa el ejercicio antes de validar'
assert fee_bps == 5, 'con 250k caes en el tramo <1M'
assert abs(fee - 125.0) < 1e-9
print('ok -> pagas', fee)

# %% [markdown]
# <a id="L01-A15"></a>
#
# ### A15. Deshaz el último
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~2 min</sub>
#
# **Por qué lo hacemos.** Practica una mutación reversible sobre un tick que el ejemplo identifica como erróneo. Distingue el precio retirado de la lista que permanece antes de volver a leer sus índices.
#
# **Tu tarea.** El último precio de `queue` fue un error: sácalo con `pop()` y guárdalo en `removed`.
#
# <sub>practicas: pop</sub>

# %%
queue = [99950, 99960, 99970]
removed = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert removed is not None, '⏸ removed sigue en None: completa el ejercicio antes de validar'
assert removed == 99970
assert queue == [99950, 99960], 'pop saca el elemento de la lista'
print('ok')

# %% [markdown]
# <a id="L01-A16"></a>
#
# ### A16. ¿Está el nivel?
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~2 min</sub>
#
# **Por qué lo hacemos.** Busca pertenencia sin confundir el valor de un precio con su posición en una lista. Úsalo para explicar por qué levels[0] e «in levels» responden preguntas distintas.
#
# **Tu tarea.** Guarda `has_950` (¿está 99950 en `levels`?) y `has_million` (¿está 1000000?).
#
# <sub>practicas: operador in</sub>

# %%
levels = [99950, 99940, 99930]
has_950 = None
has_million = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert has_950 is not None, '⏸ has_950 sigue en None: completa el ejercicio antes de validar'
assert has_million is not None, '⏸ has_million sigue en None: completa el ejercicio antes de validar'
assert has_950 is True and has_million is False
print('ok')

# %% [markdown]
# <a id="L01-A17"></a>
#
# ### A17. Ordena el lado bid
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~2 min</sub>
#
# **Por qué lo hacemos.** El mejor bid exige ordenar por precio descendente, no por orden de llegada. Comprueba también que sorted conserva la lista recibida; retoma después la lectura de datos de B03.
#
# **Tu tarea.** Los bids se leen de mayor a menor. Guarda `bids_sorted` (descendente, sin tocar `bids`) y `best` (el primero).
#
# > 💡 `sorted(..., reverse=True)` devuelve una lista nueva.
#
# <sub>practicas: sorted(reverse=True)</sub>

# %%
bids = [99930, 99950, 99940]
bids_sorted = None
best = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert bids_sorted is not None, '⏸ bids_sorted sigue en None: completa el ejercicio antes de validar'
assert best is not None, '⏸ best sigue en None: completa el ejercicio antes de validar'
assert bids_sorted == [99950, 99940, 99930]
assert best == 99950
assert bids == [99930, 99950, 99940], 'sorted no debe modificar la original'
print('ok')

# %% [markdown]
# <a id="L01-A19"></a>
#
# ### A19. Actualiza la posición
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~2 min</sub>
#
# **Por qué lo hacemos.** Leer y actualizar un diccionario son acciones distintas. Tras cada compra, compara el valor anterior con el nuevo y vuelve a A18 para comprobar que get por sí solo no actualiza nada.
#
# **Tu tarea.** Compras 0.2 BTC más y abres 1.0 ETH. Actualiza `positions` (BTC pasa a 0.7, ETH aparece con 1.0).
#
# <sub>practicas: escribir en un dict</sub>

# %%
positions = {'BTCUSDT': 0.5}
# actualiza BTC y crea ETH

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(positions['BTCUSDT'] - 0.7) < 1e-9
assert positions['ETHUSDT'] == 1.0
print('ok')

# %% [markdown]
# <a id="L01-A20"></a>
#
# ### A20. ¿Tiene el campo?
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~2 min</sub>
#
# **Por qué lo hacemos.** Una orden puede carecer de un campo; pertenencia comprueba su presencia sin inventar un valor. Vuelve a B05 y separa campo ausente de campo presente con valor cero.
#
# **Tu tarea.** Guarda `has_price` y `has_venue` comprobando con `in` si esas claves existen en `order`.
#
# <sub>practicas: in sobre dicts</sub>

# %%
order = {'symbol': 'BTCUSDT', 'side': 'buy', 'price': 99950}
has_price = None
has_venue = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert has_price is not None, '⏸ has_price sigue en None: completa el ejercicio antes de validar'
assert has_venue is not None, '⏸ has_venue sigue en None: completa el ejercicio antes de validar'
assert has_price is True and has_venue is False
print('ok')

# %% [markdown]
# <a id="L01-A21"></a>
#
# ### A21. Radiografía de comisiones
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~2 min</sub>
#
# **Por qué lo hacemos.** Resume costes de varias sedes sin sumar sus nombres. Este recorrido de valores recupera el acumulador de B04 y ayuda a distinguir cantidad de elementos de suma monetaria.
#
# **Tu tarea.** Guarda `n_venues` (cuántos exchanges hay) y `total_fees` (la suma de todas las comisiones).
#
# <sub>practicas: values / len / sum</sub>

# %%
fees = {'binance': 10, 'kraken': 26, 'coinbase': 60}
n_venues = None
total_fees = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert n_venues is not None, '⏸ n_venues sigue en None: completa el ejercicio antes de validar'
assert total_fees is not None, '⏸ total_fees sigue en None: completa el ejercicio antes de validar'
assert n_venues == 3
assert total_fees == 96, 'sum(fees.values()) suma los valores'
print('ok')

# %% [markdown]
# <a id="L01-A22"></a>
#
# ### A22. Ticks alcistas
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~2 min</sub>
#
# **Por qué lo hacemos.** Contar subidas requiere comparar parejas consecutivas, no contar precios positivos. Empieza en el segundo tick para que la primera comparación tenga un pasado válido.
#
# **Tu tarea.** Cuenta en `ups` cuántos ticks subieron respecto al anterior. Compara `mids[i]` con `mids[i-1]` usando `range(1, len(mids))`.
#
# <sub>practicas: range(1, n) e índices</sub>

# %%
mids = [99975, 99980, 99970, 99990, 100005, 99995, 100010]
ups = 0
# recorre con range y compara con el anterior

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert ups == 4, 'suben 4 de los 6 saltos'
print('ok ->', ups, 'ticks alcistas')

# %% [markdown]
# <a id="L01-A23"></a>
#
# ### A23. Censo del libro
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~2 min</sub>
#
# **Por qué lo hacemos.** Clasifica cada orden una sola vez y conserva dos contadores. Recupera B05 para leer side y B04 para recorrer el libro sin confundir número de órdenes con volumen.
#
# **Tu tarea.** Cuenta `n_buys` y `n_sells` recorriendo `book` una sola vez.
#
# <sub>practicas: contador con condición</sub>

# %%
book = [
    {'side':'buy','price':99980,'size':0.1}, {'side':'buy','price':99990,'size':0.2},
    {'side':'sell','price':100010,'size':0.15}, {'side':'sell','price':100005,'size':0.1},
    {'side':'buy','price':99970,'size':0.3},
]
n_buys = 0
n_sells = 0

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert n_buys == 3 and n_sells == 2
print('ok')

# %% [markdown]
# <a id="L01-A24"></a>
#
# ### A24. max() a mano
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~2 min</sub>
#
# **Por qué lo hacemos.** Reconstruye max para entender qué estado conserva un recorrido. Predice el candidato tras cada tick y contrasta al final con el agregado de A05.
#
# **Tu tarea.** Encuentra `highest` recorriendo `mids` **sin usar `max()`**: arranca con el primero y ve quedándote con el mayor.
#
# <sub>practicas: el patrón del campeón</sub>

# %%
mids = [99975, 99980, 99970, 99990, 100005, 99995]
highest = mids[0]
# recorre y compara

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert highest == 100005
print('ok -> acabas de reinventar max()')

# %% [markdown]
# <a id="L01-A28"></a>
#
# ### A28. Mejor bid y mejor ask
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~5 min</sub>
#
# **Por qué lo hacemos.** Integra filtrado por side y selección por precio sobre órdenes de un único símbolo. Si eliges min para los bids, vuelve al significado de comprador y vendedor antes de ajustar el bucle.
#
# **Tu tarea.** De `book` (lista de órdenes), saca `best_bid` (precio de compra más alto) y `best_ask` (precio de venta más bajo).
#
# > 💡 Recorre el libro con un for y quédate con el mejor de cada lado.
#
# <sub>practicas: max / min con filtro</sub>

# %%
book = [
    {'side':'buy','price':99980,'size':0.1}, {'side':'buy','price':99990,'size':0.2},
    {'side':'sell','price':100010,'size':0.15}, {'side':'sell','price':100005,'size':0.1},
]
best_bid = None
best_ask = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert best_bid is not None, '⏸ best_bid sigue en None: completa el ejercicio antes de validar'
assert best_ask is not None, '⏸ best_ask sigue en None: completa el ejercicio antes de validar'
assert best_bid == 99990, 'best_bid debe ser 99990'
assert best_ask == 100005, 'best_ask debe ser 100005'
print('ok')

# %% [markdown]
# <a id="L01-A27"></a>
#
# ### A27. Función nocional
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~5 min</sub>
#
# **Por qué lo hacemos.** Anticipa cómo reutilizar el cálculo de B05 sin copiarlo para cada orden. Definir funciones se enseñará en la ruta obligatoria de L2; este adelanto no es necesario para avanzar.
#
# **Tu tarea.** Escribe `compute_notional(price, size)` que devuelva `price * size`.
#
# <sub>practicas: funciones</sub>

# %%
def compute_notional(price, size):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(compute_notional(100, 0.5) - 50) < 1e-9
print('ok')

# %% [markdown]
# <a id="L01-A29"></a>
#
# ### A29. El problema que viene: dos activos
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~5 min</sub>
#
# **Por qué lo hacemos.** Cuenta cuánto código duplicarías al seguir dos instrumentos con variables separadas. La salida prepara la motivación de L2: funciones reutilizables y un libro separado por símbolo.
#
# **Tu tarea.** Imagina que sigues `buy_volume` y `sell_volume` para CADA activo por separado. Con `activos = ['BTCUSDT', 'ETHUSDT']`, ¿cuántas variables de volumen necesitas? Guárdalo en `n_vars`.
#
# > 💡 2 variables (buy y sell) por cada activo.
#
# <sub>practicas: reflexión → POO</sub>

# %%
activos = ['BTCUSDT', 'ETHUSDT']
n_vars = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert n_vars is not None, '⏸ n_vars sigue en None: completa el ejercicio antes de validar'
assert n_vars == 4, '2 por activo x 2 activos = 4 (y con 10 activos, 20...)'
print('ok -> L2 lo agrupa en estructuras; L4-L5 lo encapsulan en CLASES.')

# %% [markdown]
# <a id="L01-B08"></a>
#
# ### 8. Pregunta qué Python estás usando
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~2 min</sub>
#
# **Por qué lo hacemos.** OPTIONAL. Solo después del algoritmo miramos qué intérprete lo ejecuta, para entender por qué el entorno importa.
#
# **Herramienta de observación.** `sys` es un módulo incluido con Python: `import sys` hace accesible información del intérprete actual. `sys.implementation.name` no recibe argumentos; leerlo devuelve un texto como `'cpython'`. No modifica ni selecciona el intérprete. Este diagnóstico es opcional y no es requisito para los ejercicios de trading.
#
# **Tu tarea.** Importa `sys` y guarda `implementation = sys.implementation.name`. En este curso esperamos la implementación CPython.
#
# <sub>practicas: sys.implementation</sub>

# %%
import sys
implementation = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert implementation is not None, '⏸ implementation sigue en None: completa el ejercicio antes de validar'
assert implementation == 'cpython', f'esta actividad espera CPython, no {implementation}'
print('ok ->', implementation)

# %% [markdown]
# <a id="L01-B09"></a>
#
# ### 9. Mira el bytecode real
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~3 min</sub>
#
# **Por qué lo hacemos.** OPTIONAL. El bytecode permite observar cómo trabaja Python; no es requisito para construir ni para corregir los ejercicios.
#
# **Herramienta proporcionada.** La función `mid` de abajo ya está escrita; no tienes que aprender a definirla en este ejercicio. `dis.dis(mid)` recibe esa función (sin llamarla), imprime sus instrucciones y devuelve `None`. `dis.get_instructions(mid)` recibe lo mismo, pero devuelve instrucciones recorribles; cada una tiene un nombre en `.opname`. El patrón `[instruction.opname for instruction in dis.get_instructions(mid)]` recoge esos nombres en una lista. Solo inspeccionamos el código, sin ejecutar una operación de mercado. Los nombres exactos pueden variar según la versión de Python.
#
# **Tu tarea.** Ejecuta `dis.dis(mid)` y guarda en `opnames` los nombres de sus instrucciones con `dis.get_instructions(mid)`. No memorices los opcodes: comprueba que el bytecode existe.
#
# <sub>practicas: dis</sub>

# %%
import dis

def mid(bid, ask):
    return (bid + ask) / 2
opnames = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert opnames is not None, '⏸ opnames sigue en None: completa el ejercicio antes de validar'
assert 'RETURN_VALUE' in opnames
assert any(name in opnames for name in ('BINARY_OP','BINARY_ADD','BINARY_TRUE_DIVIDE'))
print('ok ->', opnames)

# %% [markdown]
# <a id="L01-A30"></a>
#
# ### A30. El alfabeto de la máquina
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~5 min</sub>
#
# **Por qué lo hacemos.** Relaciona un carácter con su código numérico y representación binaria. Es una exploración del intérprete, no una destreza que necesites para calcular spread o tomar la decisión de B07.
#
# **Tu tarea.** Como viste en la presentación, cada carácter es un número y ese número son bits. Guarda `code_A = ord('A')` y `bits_A = bin(ord('A'))`.
#
# > 💡 `ord` da el código del carácter; `bin` lo pasa a binario.
#
# <sub>practicas: ord y bin (texto → 1s y 0s)</sub>

# %%
code_A = None
bits_A = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert code_A is not None, '⏸ code_A sigue en None: completa el ejercicio antes de validar'
assert bits_A is not None, '⏸ bits_A sigue en None: completa el ejercicio antes de validar'
assert code_A == 65, "ord('A') es 65"
assert bits_A == '0b1000001', 'bin(65) es 0b1000001'
print('ok  A ->', code_A, '->', bits_A)

# %% [markdown]
# <a id="L01-A31"></a>
#
# ### A31. Ver el bytecode con dis
#
# <sub>🟣 OPTIONAL · profundización no evaluable · ~5 min</sub>
#
# **Por qué lo hacemos (OPTIONAL).** Observa ahora el programa como texto compilado y contrástalo con la función inspeccionada en B09. Las herramientas vienen proporcionadas: vuelve a B07 si todavía no puedes explicar dato, cálculo y decisión.
#
# **Entrada, salida y mecanismo.** `src` es el texto de un programa. `compile(src, '<x>', 'exec')` recibe ese texto y devuelve código compilado: no lo ejecuta; `'<x>'` solo es una etiqueta para mensajes de error. `io.StringIO()` crea una libreta vacía en memoria. `dis.dis(codigo, file=buf)` escribe la representación de las instrucciones en esa libreta y devuelve `None`; `buf.getvalue()` recupera lo escrito como texto. El patrón de la pista está proporcionado para observar, no para aprender todas estas APIs ahora.
#
# **Tu tarea.** Python compila tu texto a bytecode. Compila `'mid = (bid + ask) / 2'` y captura su desensamblado en `bytecode` (string). Comprueba que contiene instrucciones de la VM.
#
# > 💡 `dis.dis(compile(src, '<x>', 'exec'), file=buf)` escribe el bytecode en un buffer.
#
# <sub>practicas: compilar texto a bytecode</sub>

# %%
import dis, io
src = 'mid = (bid + ask) / 2'
bytecode = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert bytecode is not None, '⏸ bytecode sigue en None: completa el ejercicio antes de validar'
assert isinstance(bytecode, str) and 'LOAD_NAME' in bytecode, 'debe contener instrucciones como LOAD_NAME'
print('ok — esto es lo que ejecuta la máquina virtual de Python')

# %% [markdown]
# ## Cierra el ciclo de práctica
#
# Comprueba los criterios de dominio del recorrido. Si elegiste un drill, vuelve a su ejercicio de construcción y explica qué dificultad has resuelto. Los REQUIRED están en el principal; no necesitas los OPTIONAL para entregar.
#
# Lleva solo las fórmulas de spread y mid a student_project/exchange/snapshot.py. Comprueba allí una quote nueva; la decisión del notebook usa esos cálculos, pero no sustituye tus funciones persistentes.
#
# En L2 conservaremos dato, cálculo y decisión, pero dejaremos de copiar fórmulas: una función recibirá órdenes y leerá el libro de un instrumento.

# %% [markdown]
# ## 🚀 Llévatelo a un `.py`
#
# Un notebook va genial para explorar, pero el código de verdad vive en archivos `.py` que se ejecutan enteros de una vez. Abre **`trading_snapshot.py`**: es un ejemplo de referencia para leer de una pieza. Tu entrega acumulativa está en `student_project/exchange/`.
#
# Ejecútalo desde una terminal:
#
# ```bash
# python trading_snapshot.py
# ```
#
# …o aquí mismo, en la siguiente celda:

# %%
# !python trading_snapshot.py

# %% [markdown]
# Este archivo es una lectura OPTIONAL de referencia. La entrega principal utiliza tus archivos y contratos propios.
