# %% [markdown]
# # Clase 1 — Auxiliares · el gimnasio
#
# 31 ejercicios cortos sobre *Python I — El modelo de datos*: drills para ganar soltura con las primitivas y profundizaciones opcionales.

# %% [markdown]
# ### El gimnasio
#
# Drills cortos para automatizar las primitivas de Python con datos de mercado, más una profundización final. Mismo formato de siempre: escribe tu código, ejecuta la **✅ comprobación plegada** (`Shift+Enter`) y, si te atascas, abre **💡 Ver solución**. Ninguno debería llevarte más de un par de minutos. No hacen falta para seguir el curso — pero te hacen rápido.

# %% [markdown]
# ---
#
# ## 🏋️ Gimnasio · Bloque 1 — Números y operadores del mercado
#
# Los operadores que usarás cada día: división entera, resto, potencias, redondeos y agregados.

# %% [markdown]
# ### A1. Ticks enteros
#
# El spread mide 55 y el tick 10. ¿Cuántos ticks *enteros* caben (`ticks`) y qué resto queda (`resto`)?
#
# > 💡 `//` da el cociente entero; `%` el resto.
#
# <sub>practicas: // y % (división entera y resto)</sub>

# %%
spread = 55
tick_size = 10
ticks = None
resto = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert ticks == 5, 'en 55 caben 5 ticks de 10'
assert resto == 5, 'y sobran 5'
print('ok ->', ticks, 'ticks y resto', resto)

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# ticks = spread // tick_size
# resto = spread % tick_size
# ```
#
# </details>

# %% [markdown]
# ### A2. Redondea como un exchange
#
# Guarda `price_2dec` = `raw_price` redondeado a 2 decimales, y `size_whole` = `3.7` redondeado al entero más cercano.
#
# <sub>practicas: round</sub>

# %%
raw_price = 99975.4567
price_2dec = None
size_whole = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert price_2dec == 99975.46, 'round(x, 2) redondea a 2 decimales'
assert size_whole == 4
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# price_2dec = round(raw_price, 2)
# size_whole = round(3.7)
# ```
#
# </details>

# %% [markdown]
# ### A3. PnL con signo
#
# Compraste a `entry` y vendiste a `exit_price`, tamaño 2. Calcula `pnl = (exit_price - entry) * size` y su magnitud `pnl_abs`.
#
# <sub>practicas: abs y signo</sub>

# %%
entry = 99950
exit_price = 99920
size = 2
pnl = None
pnl_abs = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert pnl == -60, 'vendiste mas barato: el PnL es negativo'
assert pnl_abs == 60
print('ok -> perdiste', pnl_abs)

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# pnl = (exit_price - entry) * size
# pnl_abs = abs(pnl)
# ```
#
# </details>

# %% [markdown]
# ### A4. Interés compuesto
#
# Si BTC subiera un 1% al día durante 10 días, el multiplicador total es `(1 + 0.01) ** 10`. Guárdalo en `growth`.
#
# <sub>practicas: ** (potencias)</sub>

# %%
growth = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert round(growth, 4) == 1.1046, 'mas que 1.10: el interes compuesto compone'
print('ok ->', round(growth, 4))

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# growth = (1 + 0.01) ** 10
# ```
#
# </details>

# %% [markdown]
# ### A5. Agregados de un vistazo
#
# De `mids`, guarda `lowest`, `highest` y `total` usando `min`, `max` y `sum` (sin bucles).
#
# <sub>practicas: min / max / sum</sub>

# %%
mids = [99975, 99980, 99970, 99990, 100005]
lowest = None
highest = None
total = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert lowest == 99970 and highest == 100005
assert total == 499920
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# lowest = min(mids)
# highest = max(mids)
# total = sum(mids)
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## 🏋️ Gimnasio · Bloque 2 — Strings: símbolos y tickets
#
# Los datos de mercado llegan como texto: aprende a trocearlo, limpiarlo y formatearlo.

# %% [markdown]
# ### A6. Base y quote
#
# De `symbol = 'BTCUSDT'` saca `base` (3 primeras letras) y `quote` (el resto) con slicing.
#
# > 💡 Un string se trocea igual que una lista: `symbol[:3]`.
#
# <sub>practicas: slicing de strings</sub>

# %%
symbol = 'BTCUSDT'
base = None
quote = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert base == 'BTC' and quote == 'USDT'
print('ok ->', base, '/', quote)

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# base = symbol[:3]
# quote = symbol[3:]
# ```
#
# </details>

# %% [markdown]
# ### A7. Limpia el input
#
# `raw` llega sucio de un formulario. Guarda `clean` (sin espacios y en mayúsculas) y `is_usdt` (si termina en `'USDT'`).
#
# <sub>practicas: strip / upper / endswith</sub>

# %%
raw = '  btcusdt '
clean = None
is_usdt = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert clean == 'BTCUSDT', 'strip() quita espacios, upper() sube a mayusculas'
assert is_usdt is True
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# clean = raw.strip().upper()
# is_usdt = clean.endswith('USDT')
# ```
#
# </details>

# %% [markdown]
# ### A8. Parsea una quote
#
# El feed manda `'99950/100000'`. Sepáralo y guarda `bid` y `ask` como **enteros**.
#
# > 💡 `.split('/')` devuelve una lista de trozos; `int(...)` convierte.
#
# <sub>practicas: split + int</sub>

# %%
quote_str = '99950/100000'
bid = None
ask = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert bid == 99950 and ask == 100000
assert isinstance(bid, int), 'convierte con int(): el feed manda texto'
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# parts = quote_str.split('/')
# bid = int(parts[0])
# ask = int(parts[1])
# ```
#
# </details>

# %% [markdown]
# ### A9. El ticket perfecto
#
# Construye `ticket` con una f-string: `'BUY 0.5 BTCUSDT @ 99950.00'` (lado en mayúsculas, precio con 2 decimales).
#
# > 💡 `f"{side.upper()} ... {price:.2f}"`.
#
# <sub>practicas: f-strings con formato</sub>

# %%
side = 'buy'
size = 0.5
symbol = 'BTCUSDT'
price = 99950
ticket = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert ticket == 'BUY 0.5 BTCUSDT @ 99950.00'
print('ok ->', ticket)

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# ticket = f"{side.upper()} {size} {symbol} @ {price:.2f}"
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## 🏋️ Gimnasio · Bloque 3 — Booleanos: condiciones de riesgo
#
# Toda decisión de trading es al final un True/False. Componlos con and, or y not.

# %% [markdown]
# ### A10. Dentro de banda
#
# Guarda `in_band` (si `mid` está entre `low` y `high`, ambos incluidos) y `outside` (lo contrario, usando `not`).
#
# <sub>practicas: comparaciones encadenadas</sub>

# %%
mid = 99975
low = 99900
high = 100000
in_band = None
outside = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert in_band is True and outside is False
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# in_band = low <= mid <= high
# outside = not in_band
# ```
#
# </details>

# %% [markdown]
# ### A11. ¿Puedo operar?
#
# Solo operas si tienes caja, el mercado está abierto **y** el riesgo está OK. Calcula `can_trade`.
#
# <sub>practicas: and</sub>

# %%
has_cash = True
market_open = True
risk_ok = False
can_trade = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert can_trade is False, 'con risk_ok False no se opera: and exige que TODO sea True'
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# can_trade = has_cash and market_open and risk_ok
# ```
#
# </details>

# %% [markdown]
# ### A12. Señal y cautela
#
# `signal` = spread estrecho (`< 20`) **y** imbalance alto (`> 0.6`). `caution` = spread ancho (`>= 60`) **o** imbalance flojo (`< 0.3`).
#
# <sub>practicas: and / or</sub>

# %%
spread = 15
imbalance = 0.7
signal = None
caution = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert signal is True
assert caution is False
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# signal = spread < 20 and imbalance > 0.6
# caution = spread >= 60 or imbalance < 0.3
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## 🏋️ Gimnasio · Bloque 4 — Listas a fondo
#
# La serie de precios es una lista. Trocéala, ordénala y pregúntale cosas.

# %% [markdown]
# ### A13. Ventana de ticks
#
# Guarda `last3` (los 3 últimos mids) y `first2` (los 2 primeros) con slicing.
#
# > 💡 `mids[-3:]` y `mids[:2]`.
#
# <sub>practicas: slicing</sub>

# %%
mids = [99975, 99980, 99970, 99990, 100005, 99995, 100010]
last3 = None
first2 = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert last3 == [100005, 99995, 100010]
assert first2 == [99975, 99980]
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# last3 = mids[-3:]
# first2 = mids[:2]
# ```
#
# </details>

# %% [markdown]
# ### A14. Llega un tick
#
# Añade el tick `100020` al final de `mids` y guarda en `n` cuántos hay ahora.
#
# <sub>practicas: append</sub>

# %%
mids = [99975, 99980, 99970, 99990]
# anade el tick y cuenta
n = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert mids[-1] == 100020, 'append anade al final'
assert n == 5
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# mids.append(100020)
# n = len(mids)
# ```
#
# </details>

# %% [markdown]
# ### A15. Deshaz el último
#
# El último precio de `queue` fue un error: sácalo con `pop()` y guárdalo en `removed`.
#
# <sub>practicas: pop</sub>

# %%
queue = [99950, 99960, 99970]
removed = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert removed == 99970
assert queue == [99950, 99960], 'pop saca el elemento de la lista'
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# removed = queue.pop()
# ```
#
# </details>

# %% [markdown]
# ### A16. ¿Está el nivel?
#
# Guarda `has_950` (¿está 99950 en `levels`?) y `has_million` (¿está 1000000?).
#
# <sub>practicas: operador in</sub>

# %%
levels = [99950, 99940, 99930]
has_950 = None
has_million = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert has_950 is True and has_million is False
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# has_950 = 99950 in levels
# has_million = 1000000 in levels
# ```
#
# </details>

# %% [markdown]
# ### A17. Ordena el lado bid
#
# Los bids se leen de mayor a menor. Guarda `bids_sorted` (descendente, sin tocar `bids`) y `best` (el primero).
#
# > 💡 `sorted(..., reverse=True)` devuelve una lista nueva.
#
# <sub>practicas: sorted(reverse=True)</sub>

# %%
bids = [99930, 99950, 99940]
bids_sorted = None
best = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert bids_sorted == [99950, 99940, 99930]
assert best == 99950
assert bids == [99930, 99950, 99940], 'sorted no debe modificar la original'
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# bids_sorted = sorted(bids, reverse=True)
# best = bids_sorted[0]
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## 🏋️ Gimnasio · Bloque 5 — Diccionarios a fondo
#
# Posiciones, comisiones, órdenes: en trading casi todo es un dict.

# %% [markdown]
# ### A18. Lee con red
#
# Guarda `btc_pos` y `eth_pos` usando `.get(clave, 0)` — ETH no existe todavía y no debe explotar.
#
# <sub>practicas: get con default</sub>

# %%
positions = {'BTCUSDT': 0.5}
btc_pos = None
eth_pos = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert btc_pos == 0.5
assert eth_pos == 0, 'get con default evita el KeyError'
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# btc_pos = positions.get('BTCUSDT', 0)
# eth_pos = positions.get('ETHUSDT', 0)
# ```
#
# </details>

# %% [markdown]
# ### A19. Actualiza la posición
#
# Compras 0.2 BTC más y abres 1.0 ETH. Actualiza `positions` (BTC pasa a 0.7, ETH aparece con 1.0).
#
# <sub>practicas: escribir en un dict</sub>

# %%
positions = {'BTCUSDT': 0.5}
# actualiza BTC y crea ETH

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(positions['BTCUSDT'] - 0.7) < 1e-9
assert positions['ETHUSDT'] == 1.0
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# positions['BTCUSDT'] = positions['BTCUSDT'] + 0.2
# positions['ETHUSDT'] = 1.0
# ```
#
# </details>

# %% [markdown]
# ### A20. ¿Tiene el campo?
#
# Guarda `has_price` y `has_venue` comprobando con `in` si esas claves existen en `order`.
#
# <sub>practicas: in sobre dicts</sub>

# %%
order = {'symbol': 'BTCUSDT', 'side': 'buy', 'price': 99950}
has_price = None
has_venue = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert has_price is True and has_venue is False
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# has_price = 'price' in order
# has_venue = 'venue' in order
# ```
#
# </details>

# %% [markdown]
# ### A21. Radiografía de comisiones
#
# Guarda `n_venues` (cuántos exchanges hay) y `total_fees` (la suma de todas las comisiones).
#
# <sub>practicas: values / len / sum</sub>

# %%
fees = {'binance': 10, 'kraken': 26, 'coinbase': 60}
n_venues = None
total_fees = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert n_venues == 3
assert total_fees == 96, 'sum(fees.values()) suma los valores'
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# n_venues = len(fees)
# total_fees = sum(fees.values())
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## 🏋️ Gimnasio · Bloque 6 — Bucles con oficio
#
# El for + un if dentro: el patrón que resuelve el 80% de los problemas de datos.

# %% [markdown]
# ### A22. Ticks alcistas
#
# Cuenta en `ups` cuántos ticks subieron respecto al anterior. Compara `mids[i]` con `mids[i-1]` usando `range(1, len(mids))`.
#
# <sub>practicas: range(1, n) e índices</sub>

# %%
mids = [99975, 99980, 99970, 99990, 100005, 99995, 100010]
ups = 0
# recorre con range y compara con el anterior

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert ups == 4, 'suben 4 de los 6 saltos'
print('ok ->', ups, 'ticks alcistas')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# ups = 0
# for i in range(1, len(mids)):
#     if mids[i] > mids[i-1]:
#         ups = ups + 1
# ```
#
# </details>

# %% [markdown]
# ### A23. Censo del libro
#
# Cuenta `n_buys` y `n_sells` recorriendo `book` una sola vez.
#
# <sub>practicas: contador con condición</sub>

# %%
book = [
    {'side':'buy','price':99980,'size':0.1}, {'side':'buy','price':99990,'size':0.2},
    {'side':'sell','price':100010,'size':0.15}, {'side':'sell','price':100005,'size':0.1},
    {'side':'buy','price':99970,'size':0.3},
]
n_buys = 0
n_sells = 0

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert n_buys == 3 and n_sells == 2
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# n_buys = 0
# n_sells = 0
# for o in book:
#     if o['side'] == 'buy':
#         n_buys = n_buys + 1
#     else:
#         n_sells = n_sells + 1
# ```
#
# </details>

# %% [markdown]
# ### A24. max() a mano
#
# Encuentra `highest` recorriendo `mids` **sin usar `max()`**: arranca con el primero y ve quedándote con el mayor.
#
# <sub>practicas: el patrón del campeón</sub>

# %%
mids = [99975, 99980, 99970, 99990, 100005, 99995]
highest = mids[0]
# recorre y compara

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert highest == 100005
print('ok -> acabas de reinventar max()')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# highest = mids[0]
# for m in mids:
#     if m > highest:
#         highest = m
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## 🏋️ Gimnasio · Bloque 7 — Decisiones con más ramas
#
# if/elif/else con la complejidad de verdad: umbrales escalonados y decisiones que alimentan un cálculo.

# %% [markdown]
# ### A25. Semáforo de presión
#
# Clasifica `pressure`: `'buy_pressure'` si imbalance > 0.65, `'sell_pressure'` si < 0.35, `'balanced'` en medio.
#
# <sub>practicas: if / elif / else</sub>

# %%
imbalance = 0.72
# escribe el if / elif / else

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert pressure == 'buy_pressure'
print('ok ->', pressure)

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# if imbalance > 0.65:
#     pressure = 'buy_pressure'
# elif imbalance < 0.35:
#     pressure = 'sell_pressure'
# else:
#     pressure = 'balanced'
# ```
#
# </details>

# %% [markdown]
# ### A26. Tarifa por tramos
#
# Comisión por tramos: <10k → 10 bps; <100k → 8; <1M → 5; si no → 3. Guarda `fee_bps` y calcula `fee = notional * fee_bps / 10000`.
#
# <sub>practicas: umbrales escalonados + cálculo</sub>

# %%
notional = 250000
fee_bps = None
# ... y calcula fee

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert fee_bps == 5, 'con 250k caes en el tramo <1M'
assert abs(fee - 125.0) < 1e-9
print('ok -> pagas', fee)

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# if notional < 10000:
#     fee_bps = 10
# elif notional < 100000:
#     fee_bps = 8
# elif notional < 1000000:
#     fee_bps = 5
# else:
#     fee_bps = 3
# fee = notional * fee_bps / 10000
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## 🏋️ Para curiosos — internals y el puente a la clase 2
#
# Un vistazo a lo que viene (funciones) y a lo que hay debajo (1s, 0s y bytecode).

# %% [markdown]
# ### A27. Función nocional
#
# Escribe `compute_notional(price, size)` que devuelva `price * size`.
#
# <sub>practicas: funciones</sub>

# %%
def compute_notional(price, size):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(compute_notional(100, 0.5) - 50) < 1e-9
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def compute_notional(price, size):
#     return price * size
# ```
#
# </details>

# %% [markdown]
# ### A28. Mejor bid y mejor ask
#
# De `book` (lista de órdenes), saca `best_bid` (precio de compra más alto) y `best_ask` (precio de venta más bajo).
#
# > 💡 Filtra por `side` dentro de un `max`/`min` con generador.
#
# <sub>practicas: max / min con filtro</sub>

# %%
book = [
    {'side':'buy','price':99980,'size':0.1}, {'side':'buy','price':99990,'size':0.2},
    {'side':'sell','price':100010,'size':0.15}, {'side':'sell','price':100005,'size':0.1},
]
best_bid = None
best_ask = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert best_bid == 99990, 'best_bid debe ser 99990'
assert best_ask == 100005, 'best_ask debe ser 100005'
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# best_bid = max(o['price'] for o in book if o['side']=='buy')
# best_ask = min(o['price'] for o in book if o['side']=='sell')
# ```
#
# </details>

# %% [markdown]
# ### A29. El problema que viene: dos activos
#
# Imagina que sigues `buy_volume` y `sell_volume` para CADA activo por separado. Con `activos = ['BTCUSDT', 'ETHUSDT']`, ¿cuántas variables de volumen necesitas? Guárdalo en `n_vars`.
#
# > 💡 2 variables (buy y sell) por cada activo.
#
# <sub>practicas: reflexión → POO</sub>

# %%
activos = ['BTCUSDT', 'ETHUSDT']
n_vars = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert n_vars == 4, '2 por activo x 2 activos = 4 (y con 10 activos, 20...)'
print('ok -> anadir activos duplica variables. En la clase 2-3 esto lo resuelven las CLASES.')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# n_vars = len(activos) * 2
# ```
#
# </details>

# %% [markdown]
# ### A30. El alfabeto de la máquina
#
# Como viste en la presentación, cada carácter es un número y ese número son bits. Guarda `code_A = ord('A')` y `bits_A = bin(ord('A'))`.
#
# > 💡 `ord` da el código del carácter; `bin` lo pasa a binario.
#
# <sub>practicas: ord y bin (texto → 1s y 0s)</sub>

# %%
code_A = None
bits_A = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert code_A == 65, "ord('A') es 65"
assert bits_A == '0b1000001', 'bin(65) es 0b1000001'
print('ok  A ->', code_A, '->', bits_A)

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# code_A = ord('A')
# bits_A = bin(ord('A'))
# ```
#
# </details>

# %% [markdown]
# ### A31. Ver el bytecode con dis
#
# Python compila tu texto a bytecode. Compila `'mid = (bid + ask) / 2'` y captura su desensamblado en `bytecode` (string). Comprueba que contiene instrucciones de la VM.
#
# > 💡 `dis.dis(compile(src, '<x>', 'exec'), file=buf)` escribe el bytecode en un buffer.
#
# <sub>practicas: compilar texto a bytecode</sub>

# %%
import dis, io
src = 'mid = (bid + ask) / 2'
bytecode = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert isinstance(bytecode, str) and 'LOAD_NAME' in bytecode, 'debe contener instrucciones como LOAD_NAME'
print('ok — esto es lo que ejecuta la máquina virtual de Python')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# buf = io.StringIO()
# dis.dis(compile(src, '<x>', 'exec'), file=buf)
# bytecode = buf.getvalue()
# print(bytecode)
# ```
#
# </details>

# %% [markdown]
# ## Fin de los auxiliares
#
# Vuelve al cuaderno principal cuando quieras.
