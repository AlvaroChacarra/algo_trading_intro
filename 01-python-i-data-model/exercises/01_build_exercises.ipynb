# %% [markdown]
# # 🐍 Clase 1 · Python I — El modelo de datos
#
# > Entender cómo CPython transforma nuestra intención en operaciones ejecutables y usar las primitivas de Python para leer un order book, calcular información y decidir.
#
# Empezamos frente a una pantalla: hay un precio de compra y otro de venta. Queremos pasar de mirar números a formular una decisión reproducible. Primero observamos, después calculamos y solo al final decidimos.
#
# **Hoy construyes:** order y snapshot como dicts.
#
# ⏱️ 🟢 LIVE ~20 min · 🔵 REQUIRED +34 min.
#
# ## Tu recorrido de estudio
#
# **Pregunta de hoy:** ¿Cómo paso de dos precios en pantalla a una decisión que otra persona pueda reproducir?
#
# **Punto de partida.** Sin programar: con bid 99 y ask 101, distingue el coste de cruzar ambos lados del punto medio de la quote.
#
# **Comprueba antes de avanzar:** Spread 2 y mid 100; ninguno dice por sí solo que comprar vaya a ser rentable.
#
# Sigue los bloques en orden. En clase haces los **LIVE**; después completas los **REQUIRED** del principal, incluida la construcción en tus archivos. El auxiliar contiene solo variantes OPTIONAL. Los IDs históricos A/B identifican ejercicios, no su ruta. Los tiempos son orientativos, no un límite para aprender.
#
# ### 1. Nombrar y calcular una quote
#
# Pon nombres al dato y unidades a cada cálculo; los ejercicios numéricos auxiliares consolidan después lo construido en clase.
#
# **Presentación:** [escena 1](../presentation/python-i-data-model-doc.html?mode=estudio#s0) · [escena 2](../presentation/python-i-data-model-doc.html?mode=estudio#s1) · [escena 3](../presentation/python-i-data-model-doc.html?mode=estudio#s2).
#
# **Prepara y construye en el principal:** [B01](01_build_exercises.ipynb#L01-B01) (LIVE, 3 min) · [B02](01_build_exercises.ipynb#L01-B02) (LIVE, 4 min) · [A01](01_build_exercises.ipynb#L01-A01) (REQUIRED, 2 min) · [A02](01_build_exercises.ipynb#L01-A02) (REQUIRED, 2 min) · [A03](01_build_exercises.ipynb#L01-A03) (REQUIRED, 2 min).
#
# **Puedes seguir cuando:** Explica por qué ask − bid es spread y por qué formatear o redondear no valida una orden.
#
# ### 2. Leer una secuencia sin perder observaciones
#
# Pasa de índices a ventana y acumulador; conserva una predicción pequeña antes de ejecutar el bucle.
#
# **Presentación:** [escena 4](../presentation/python-i-data-model-doc.html?mode=estudio#s3).
#
# **Prepara y construye en el principal:** [B03](01_build_exercises.ipynb#L01-B03) (LIVE, 3 min) · [B04](01_build_exercises.ipynb#L01-B04) (REQUIRED, 6 min) · [A13](01_build_exercises.ipynb#L01-A13) (REQUIRED, 2 min) · [A14](01_build_exercises.ipynb#L01-A14) (REQUIRED, 2 min).
#
# **Puedes seguir cuando:** Identifica qué ticks entran y comprueba suma, longitud y media por separado.
#
# ### 3. Dar significado a los campos de una orden
#
# Distingue texto recibido, número convertido y registro de orden; recupera el símbolo al mostrar el ticket.
#
# **Presentación:** [escena 5](../presentation/python-i-data-model-doc.html?mode=estudio#s4).
#
# **Prepara y construye en el principal:** [B05](01_build_exercises.ipynb#L01-B05) (REQUIRED, 6 min) · [A06](01_build_exercises.ipynb#L01-A06) (REQUIRED, 2 min) · [A07](01_build_exercises.ipynb#L01-A07) (REQUIRED, 2 min) · [A08](01_build_exercises.ipynb#L01-A08) (REQUIRED, 2 min) · [A09](01_build_exercises.ipynb#L01-A09) (REQUIRED, 2 min) · [A18](01_build_exercises.ipynb#L01-A18) (REQUIRED, 2 min).
#
# **Puedes seguir cuando:** Lee side, price y size sin mezclar claves y valores; explica cuándo un default es válido y cuándo ocultaría un campo obligatorio.
#
# ### 4. Cerrar dato → cálculo → decisión
#
# La práctica LIVE termina clasificando el mercado y tomando una decisión; en el estudio autónomo comprueba además la puerta de permiso.
#
# **Presentación:** [escena 6](../presentation/python-i-data-model-doc.html?mode=estudio#s5) · [escena 7](../presentation/python-i-data-model-doc.html?mode=estudio#s6) · [escena 8](../presentation/python-i-data-model-doc.html?mode=estudio#s7).
#
# **Prepara y construye en el principal:** [B06](01_build_exercises.ipynb#L01-B06) (LIVE, 4 min) · [B07](01_build_exercises.ipynb#L01-B07) (LIVE, 6 min) · [A11](01_build_exercises.ipynb#L01-A11) (REQUIRED, 2 min).
#
# **Puedes seguir cuando:** Predice las ramas en los límites y separa señal buy, condiciones para operar y promesa de beneficio.
#
# ### Elige tu refuerzo OPTIONAL
#
# Después de la ruta obligatoria, elige el bloque que responda a tu dificultad o curiosidad. No necesitas hacerlos todos; ninguno desbloquea una entrega ni añade materia evaluable. Regresa al ejercicio indicado y comprueba si ahora puedes explicarlo sin copiar.
#
# | Si necesitas… | Practica | Aplica y vuelve |
# |---|---|---|
# | Si mezclas acumulación porcentual, suma y media. | [A4. Interés compuesto](01_auxiliary.ipynb#L01-A04) (2 min) · [A5. Agregados de un vistazo](01_auxiliary.ipynb#L01-A05) (2 min) | Compara potencias con incrementos simples y contrasta un bucle con agregados. Vuelve a [B04](01_build_exercises.ipynb#L01-B04). |
# | Si una condición falla en el borde o confundes and con or. | [A10. Dentro de banda](01_auxiliary.ipynb#L01-A10) (2 min) · [A12. Señal y cautela](01_auxiliary.ipynb#L01-A12) (2 min) · [A25. Semáforo de presión](01_auxiliary.ipynb#L01-A25) (2 min) · [A26. Tarifa por tramos](01_auxiliary.ipynb#L01-A26) (2 min) | Cambia intervalos y magnitudes, pero conserva una tabla mental de casos y fronteras. Vuelve a [B06](01_build_exercises.ipynb#L01-B06). |
# | Si confundes leer una lista, buscar un valor y modificarla. | [A15. Deshaz el último](01_auxiliary.ipynb#L01-A15) (2 min) · [A16. ¿Está el nivel?](01_auxiliary.ipynb#L01-A16) (2 min) · [A17. Ordena el lado bid](01_auxiliary.ipynb#L01-A17) (2 min) | Comprueba qué colección cambia y cuál conserva su orden original. Vuelve a [B03](01_build_exercises.ipynb#L01-B03). |
# | Si cuesta distinguir presencia de una clave, valor guardado y actualización. | [A19. Actualiza la posición](01_auxiliary.ipynb#L01-A19) (2 min) · [A20. ¿Tiene el campo?](01_auxiliary.ipynb#L01-A20) (2 min) · [A21. Radiografía de comisiones](01_auxiliary.ipynb#L01-A21) (2 min) | Usa posiciones y comisiones para afianzar el registro sin mezclar unidades. Vuelve a [B05](01_build_exercises.ipynb#L01-B05). |
# | Si un recorrido necesita varios intentos o el acumulador conserva el dato equivocado. | [A22. Ticks alcistas](01_auxiliary.ipynb#L01-A22) (2 min) · [A23. Censo del libro](01_auxiliary.ipynb#L01-A23) (2 min) · [A24. max() a mano](01_auxiliary.ipynb#L01-A24) (2 min) · [A28. Mejor bid y mejor ask](01_auxiliary.ipynb#L01-A28) (5 min) | Pasa de contar a buscar extremos y filtrar lados de un libro de un solo símbolo. Vuelve a [B04](01_build_exercises.ipynb#L01-B04). |
# | Si ya dominas B07 y quieres reconocer por qué duplicar cálculos será incómodo. | [A27. Función nocional](01_auxiliary.ipynb#L01-A27) (5 min) · [A29. El problema que viene: dos activos](01_auxiliary.ipynb#L01-A29) (5 min) | Anticipa funciones reutilizables y separación por instrumento; L2 las enseñará de nuevo como parte obligatoria. Vuelve a [B07](01_build_exercises.ipynb#L01-B07). |
# | Si el algoritmo ya está claro y quieres inspeccionar cómo lo representa el intérprete. | [8. Pregunta qué Python estás usando](01_auxiliary.ipynb#L01-B08) (2 min) · [9. Mira el bytecode real](01_auxiliary.ipynb#L01-B09) (3 min) · [A30. El alfabeto de la máquina](01_auxiliary.ipynb#L01-A30) (5 min) · [A31. Ver el bytecode con dis](01_auxiliary.ipynb#L01-A31) (5 min) | Distingue texto, código compilado y ejecución sin memorizar herramientas opcionales. Vuelve a [B07](01_build_exercises.ipynb#L01-B07). |
#
# ### De la práctica a tu proyecto
#
# Lleva solo las fórmulas de spread y mid a student_project/exchange/snapshot.py. Comprueba allí una quote nueva; la decisión del notebook usa esos cálculos, pero no sustituye tus funciones persistentes.
#
# **Siguiente paso:** En L2 conservaremos dato, cálculo y decisión, pero dejaremos de copiar fórmulas: una función recibirá órdenes y leerá el libro de un instrumento.
#
#
# ## La pieza que construyes en tu sistema
#
# **Partes de:** Partimos de una quote de un único instrumento: bid es el precio disponible para vender y ask el precio disponible para comprar. En snapshot.py ya están nombrados bid y ask; todavía no hay funciones ni ejecución de órdenes.
#
# **Problema:** Convertir esos dos datos en dos lecturas distintas y comprobables: cuánto separa ambos lados y dónde está su punto medio. El sistema necesita conservar los números, no solo imprimir una frase con ellos.
#
# ### Cómo lo hemos pensado
#
# 1. Lee primero bid y ask y conserva su unidad: USD por unidad del instrumento. Una resta de precios sigue siendo un precio; no es un porcentaje ni el coste total de una orden de cualquier tamaño.
# 2. Asigna a spread la distancia desde bid hasta ask. El orden de la resta importa: para una quote normal, el resultado es no negativo; invertir la resta cambia el significado.
# 3. Asigna a mid el promedio de los dos precios. Agrupa la suma antes de dividir para que ambos lados tengan el mismo peso.
# 4. Calcula ambos derivados después de los datos de entrada. Son variables calculadas una vez al ejecutar el archivo: cambiar bid más tarde no recalcula automáticamente spread ni mid.
#
# **Predice y contrasta:** Con bid=99 y ask=101, la distancia es 101−99=2 USD por unidad y el promedio es (99+101)/2=100 USD por unidad. Por tanto snapshot.py debe dejar spread=2 y mid=100. Si repetimos el cálculo para bid=102 y ask=106, esperamos spread=4 y mid=104. Comprar una unidad a 101 y venderla inmediatamente a 99 perdería 2 antes de costes; el mid 100 por sí solo no es un precio garantizado de ejecución.
#
# **Del ejemplo a tu implementación:** B01–B02 nombran una quote y calculan sus derivados; B07 los usa para razonar una decisión. El proyecto conserva exactamente ese cálculo en snapshot.py, con precios pequeños para verificarlo a mano. Sus targets spread y mid son variables asignadas, no funciones; las listas, órdenes y decisiones practicadas en el principal aportan contexto sin cambiar esta entrega.
#
# ### Construcción principal
#
# Trabaja en `student_project/exchange/`. Los ejercicios preparan las decisiones; la entrega central es completar estos cuerpos en tus archivos. El resto del código del starter está proporcionado y se puede leer.
#
# - **`snapshot.py:spread`** — En snapshot.py localiza bid y ask y completa spread con la distancia entre ambos. Predice su signo y valor para 99/101 antes de ejecutar; después cambia ambos datos y vuelve a ejecutar para comprobar que la fórmula depende de ellos. Preparación: [L01-B01](01_build_exercises.ipynb#L01-B01) · [L01-B02](01_build_exercises.ipynb#L01-B02).
# - **`snapshot.py:mid`** — Completa mid usando ambos precios con igual peso. Comprueba que para 99/101 queda a una unidad de cada extremo y explica por qué leer mid no demuestra que puedas comprar o vender a ese precio. Preparación: [L01-B02](01_build_exercises.ipynb#L01-B02) · [L01-B07](01_build_exercises.ipynb#L01-B07).
#
# **Comprobación acumulativa:** desde la raíz de tu carpeta de estudio, ejecuta `python check_project.py 1` después de completar tus archivos. Que pase un miniejercicio no sustituye esta integración.
#
# **Lo siguiente reutiliza:** L2 seleccionará los mejores precios entre varias órdenes. L3 aplicará estas mismas fórmulas al par seleccionado, en vez de usar una quote fija.

# %% [markdown]
# ### Cómo funciona este cuaderno
#
# Cada ejercicio declara una ruta pedagógica, decidida por contenido y no por posición: **🟢 LIVE** (núcleo presencial) · **🔵 REQUIRED** (consolidación autónoma requerida y evaluable) · **🟣 OPTIONAL** (profundización no obligatoria y no evaluable). Escribe tu respuesta, ejecuta la **✅ comprobación plegada** con `Shift+Enter` y usa la pista cuando la necesites; las soluciones docentes no se incluyen.

# %% [markdown]
# <a id="L01-B01"></a>
#
# ### 1. Enciende el mercado
#
# <sub>🟢 LIVE · núcleo presencial · ~3 min</sub>
#
# **Por qué lo hacemos.** Antes de operar necesitamos nombrar lo que vemos. Una variable nos permite conservar una observación y usarla después.
#
# **Tu tarea.** Guarda el snapshot en variables: `symbol = 'BTCUSDT'`, `bid = 99950`, `ask = 100000`.
#
# > 💡 Tres asignaciones simples.
#
# <sub>practicas: variables</sub>

# %%
# Escribe aquí

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert symbol == 'BTCUSDT', 'symbol debe ser BTCUSDT'
assert bid == 99950 and ask == 100000
print('ok')

# %% [markdown]
# <a id="L01-B02"></a>
#
# ### 2. Spread y mid
#
# <sub>🟢 LIVE · núcleo presencial · ~4 min</sub>
#
# **Por qué lo hacemos.** El precio al que puedes comprar y el precio al que puedes vender no coinciden. Calcula esa diferencia antes de hablar de beneficio.
#
# **Tu tarea.** Calcula `spread = ask - bid` y `mid = (bid + ask) / 2`. Fíjate: la resta da entero; la división `/` siempre da decimal (`float`).
#
# <sub>practicas: operaciones y tipos</sub>

# %%
bid = 99950
ask = 100000
# Escribe aquí

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert spread == 50, 'spread debe ser 50'
assert mid == 99975.0, 'mid debe ser 99975.0'
assert isinstance(mid, float), 'mid es float: la division / siempre da float'
print('ok')

# %% [markdown]
# <a id="L01-A01"></a>
#
# ### A1. Ticks enteros
#
# <sub>🔵 REQUIRED · consolidación requerida · ~2 min</sub>
#
# **Por qué lo hacemos.** Separa distancia de precio y número de ticks: 55 unidades no son 55 escalones de una rejilla de 10. Tras calcular cociente y resto, vuelve al spread de B02 y explica qué unidad tiene cada resultado.
#
# **Tu tarea.** El spread mide 55 y el tick 10. ¿Cuántos ticks *enteros* caben (`ticks`) y qué resto queda (`resto`)?
#
# > 💡 `//` da el cociente entero; `%` el resto.
#
# <sub>practicas: // y % (división entera y resto)</sub>

# %%
spread = 55
tick_size = 10
ticks = None
resto = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert ticks is not None, '⏸ ticks sigue en None: completa el ejercicio antes de validar'
assert resto is not None, '⏸ resto sigue en None: completa el ejercicio antes de validar'
assert ticks == 5, 'en 55 caben 5 ticks de 10'
assert resto == 5, 'y sobran 5'
print('ok ->', ticks, 'ticks y resto', resto)

# %% [markdown]
# <a id="L01-A02"></a>
#
# ### A2. Redondeo decimal, no rejilla de ticks
#
# <sub>🔵 REQUIRED · consolidación requerida · ~2 min</sub>
#
# **Por qué lo hacemos.** Distingue presentar un decimal de imponer una rejilla de precios. Este redondeo numérico prepara la lectura del ticket; no valida tamaños mínimos ni ticks de un exchange.
#
# **Alcance.** `round(x, 2)` redondea a dos decimales. No comprueba que el resultado sea múltiplo de un tick de 10 ni que una cantidad sea negociable.
#
# **Tu tarea.** Guarda `price_2dec` = `raw_price` redondeado a 2 decimales, y `size_whole` = `3.7` redondeado al entero más cercano.
#
# <sub>practicas: round</sub>

# %%
raw_price = 99975.4567
price_2dec = None
size_whole = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert price_2dec is not None, '⏸ price_2dec sigue en None: completa el ejercicio antes de validar'
assert size_whole is not None, '⏸ size_whole sigue en None: completa el ejercicio antes de validar'
assert price_2dec == 99975.46, 'round(x, 2) redondea a 2 decimales'
assert size_whole == 4
print('ok')

# %% [markdown]
# <a id="L01-A03"></a>
#
# ### A3. PnL con signo
#
# <sub>🔵 REQUIRED · consolidación requerida · ~2 min</sub>
#
# **Por qué lo hacemos.** Una compra seguida de venta mueve caja con signo, no solo una distancia absoluta. Predice si ganas o pierdes antes de calcular; conserva esta diferencia al construir fills en L4.
#
# **Tu tarea.** Compraste a `entry` y vendiste a `exit_price`, tamaño 2. Calcula `pnl = (exit_price - entry) * size` y su magnitud `pnl_abs`.
#
# <sub>practicas: abs y signo</sub>

# %%
entry = 99950
exit_price = 99920
size = 2
pnl = None
pnl_abs = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert pnl is not None, '⏸ pnl sigue en None: completa el ejercicio antes de validar'
assert pnl_abs is not None, '⏸ pnl_abs sigue en None: completa el ejercicio antes de validar'
assert pnl == -60, 'vendiste mas barato: el PnL es negativo'
assert pnl_abs == 60
print('ok -> perdiste', pnl_abs)

# %% [markdown]
# <a id="L01-B03"></a>
#
# ### 3. Una lista de mids
#
# <sub>🟢 LIVE · núcleo presencial · ~3 min</sub>
#
# **Por qué lo hacemos.** Una foto no cuenta cómo se mueve el mercado. Guardamos varias observaciones para poder compararlas en orden.
#
# **Tu tarea.** Dada `mids`, guarda el primero (`first_mid`), el último (`last_mid`) y cuántos hay (`n_mids`).
#
# > 💡 `mids[0]` es el primero, `mids[-1]` el último, `len(mids)` cuántos hay.
#
# <sub>practicas: listas e indexing</sub>

# %%
mids = [99975, 99980, 99970, 99990, 100005]
first_mid = None
last_mid = None
n_mids = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert first_mid is not None, '⏸ first_mid sigue en None: completa el ejercicio antes de validar'
assert last_mid is not None, '⏸ last_mid sigue en None: completa el ejercicio antes de validar'
assert n_mids is not None, '⏸ n_mids sigue en None: completa el ejercicio antes de validar'
assert first_mid == 99975
assert last_mid == 100005
assert n_mids == 5
print('ok')

# %% [markdown]
# <a id="L01-B04"></a>
#
# ### 4. Media con un bucle
#
# <sub>🔵 REQUIRED · consolidación requerida · ~6 min</sub>
#
# **Por qué lo hacemos.** Ya tenemos una pequeña historia de precios. Queremos resumirla con una referencia; el acumulador evita hacer la suma a mano cada vez.
#
# **Tu tarea.** Recorre `mids` con un `for`, ve sumando en `total` y calcula `average`.
#
# > 💡 Empieza con `total = 0`; dentro del bucle, `total = total + m`.
#
# <sub>practicas: for y acumuladores</sub>

# %%
mids = [99975, 99980, 99970, 99990, 100005]
total = 0
# recorre mids y calcula average

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(average - 99984.0) < 1e-9, 'la media debe ser 99984.0'
print('ok')

# %% [markdown]
# <details>
# <summary>💭 Pista (antes de mirar la solución)</summary>
#
# Tres piezas: parte de `total = 0`, dentro del bucle acumula con `total = total + m`, y **fuera** del bucle divide: `average = total / len(mids)`. Cuidado con la indentación de la última línea.
#
# </details>

# %% [markdown]
# <a id="L01-A13"></a>
#
# ### A13. Ventana de ticks
#
# <sub>🔵 REQUIRED · consolidación requerida · ~2 min</sub>
#
# **Por qué lo hacemos.** Una ventana selecciona observaciones recientes, no calcula todavía una señal. Compara índices y slicing con B03 antes de promediar la parte equivocada de una serie.
#
# **Tu tarea.** Guarda `last3` (los 3 últimos mids) y `first2` (los 2 primeros) con slicing.
#
# > 💡 `mids[-3:]` y `mids[:2]`.
#
# <sub>practicas: slicing</sub>

# %%
mids = [99975, 99980, 99970, 99990, 100005, 99995, 100010]
last3 = None
first2 = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert last3 is not None, '⏸ last3 sigue en None: completa el ejercicio antes de validar'
assert first2 is not None, '⏸ first2 sigue en None: completa el ejercicio antes de validar'
assert last3 == [100005, 99995, 100010]
assert first2 == [99975, 99980]
print('ok')

# %% [markdown]
# <a id="L01-A14"></a>
#
# ### A14. Llega un tick
#
# <sub>🔵 REQUIRED · consolidación requerida · ~2 min</sub>
#
# **Por qué lo hacemos.** Llegar un tick cambia la colección y su longitud. Comprueba que append añade un dato al final sin sustituir la lista; después recupera el último precio como en B03.
#
# **Tu tarea.** Añade el tick `100020` al final de `mids` y guarda en `n` cuántos hay ahora.
#
# <sub>practicas: append</sub>

# %%
mids = [99975, 99980, 99970, 99990]
# anade el tick y cuenta
n = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert n is not None, '⏸ n sigue en None: completa el ejercicio antes de validar'
assert mids[-1] == 100020, 'append anade al final'
assert n == 5
print('ok')

# %% [markdown]
# <a id="L01-B05"></a>
#
# ### 5. Una orden, y cómo leerla
#
# <sub>🔵 REQUIRED · consolidación requerida · ~6 min</sub>
#
# **Por qué lo hacemos.** Una decisión necesita lado, precio y tamaño juntos. El diccionario evita perder la relación entre esos datos.
#
# **Tu tarea.** Crea `order` con `symbol`, `side='buy'`, `price=99950`, `size=0.10`. Luego lee `order_side` (su lado) y calcula `order_notional` (precio × tamaño).
#
# > 💡 Accedes a un campo con `order['campo']`.
#
# <sub>practicas: diccionarios: crear y acceder</sub>

# %%
order = {
    # completa
}
order_side = None
order_notional = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert order_side is not None, '⏸ order_side sigue en None: completa el ejercicio antes de validar'
assert order_notional is not None, '⏸ order_notional sigue en None: completa el ejercicio antes de validar'
assert isinstance(order, dict)
for k in ('symbol','side','price','size'):
    assert k in order, f'falta el campo {k}'
assert order_side == 'buy'
assert abs(order_notional - 9995.0) < 1e-9, 'price * size = 9995.0'
print('ok')

# %% [markdown]
# <details>
# <summary>💭 Pista (antes de mirar la solución)</summary>
#
# El dict se escribe con pares `'clave': valor` separados por comas. Para leer: `order['side']`. El nocional multiplica dos campos del propio dict.
#
# </details>

# %% [markdown]
# <a id="L01-A06"></a>
#
# ### A6. Base y quote
#
# <sub>🔵 REQUIRED · consolidación requerida · ~2 min</sub>
#
# **Por qué lo hacemos.** Un símbolo contiene información que necesitaremos guardar en cada orden de B05. Este corte sirve para el formato fijo BTCUSDT del ejemplo, no como parser universal de símbolos.
#
# **Tu tarea.** De `symbol = 'BTCUSDT'` saca `base` (3 primeras letras) y `quote` (el resto) con slicing.
#
# > 💡 Un string se trocea igual que una lista: `symbol[:3]`.
#
# <sub>practicas: slicing de strings</sub>

# %%
symbol = 'BTCUSDT'
base = None
quote = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert base is not None, '⏸ base sigue en None: completa el ejercicio antes de validar'
assert quote is not None, '⏸ quote sigue en None: completa el ejercicio antes de validar'
assert base == 'BTC' and quote == 'USDT'
print('ok ->', base, '/', quote)

# %% [markdown]
# <a id="L01-A07"></a>
#
# ### A7. Limpia el input
#
# <sub>🔵 REQUIRED · consolidación requerida · ~2 min</sub>
#
# **Por qué lo hacemos.** El texto de entrada y el identificador normalizado no son lo mismo. Recupera esta limpieza antes de crear la orden de B05 y explica por qué limpiar no demuestra que el símbolo exista.
#
# **Tu tarea.** `raw` llega sucio de un formulario. Guarda `clean` (sin espacios y en mayúsculas) y `is_usdt` (si termina en `'USDT'`).
#
# <sub>practicas: strip / upper / endswith</sub>

# %%
raw = '  btcusdt '
clean = None
is_usdt = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert clean is not None, '⏸ clean sigue en None: completa el ejercicio antes de validar'
assert is_usdt is not None, '⏸ is_usdt sigue en None: completa el ejercicio antes de validar'
assert clean == 'BTCUSDT', 'strip() quita espacios, upper() sube a mayusculas'
assert is_usdt is True
print('ok')

# %% [markdown]
# <a id="L01-A08"></a>
#
# ### A8. Parsea una quote
#
# <sub>🔵 REQUIRED · consolidación requerida · ~2 min</sub>
#
# **Por qué lo hacemos.** El feed entrega texto, pero restar un bid y un ask exige números. Separa primero los campos y conviértelos después; vuelve a B02 para calcular el spread de esa misma quote.
#
# **Tu tarea.** El feed manda `'99950/100000'`. Sepáralo y guarda `bid` y `ask` como **enteros**.
#
# > 💡 `.split('/')` devuelve una lista de trozos; `int(...)` convierte.
#
# <sub>practicas: split + int</sub>

# %%
quote_str = '99950/100000'
bid = None
ask = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert bid is not None, '⏸ bid sigue en None: completa el ejercicio antes de validar'
assert ask is not None, '⏸ ask sigue en None: completa el ejercicio antes de validar'
assert bid == 99950 and ask == 100000
assert isinstance(bid, int), 'convierte con int(): el feed manda texto'
print('ok')

# %% [markdown]
# <a id="L01-A09"></a>
#
# ### A9. El ticket perfecto
#
# <sub>🔵 REQUIRED · consolidación requerida · ~2 min</sub>
#
# **Por qué lo hacemos.** Un ticket legible permite revisar lado, cantidad y precio antes de interpretar una orden. El formato cambia su presentación, no el precio guardado en B05.
#
# **Tu tarea.** Una f-string empieza por `f` y evalúa lo que pongas entre llaves: `{size}` inserta el valor y `{price:.2f}` lo formatea con 2 decimales. Construye `ticket = 'BUY 0.5 BTCUSDT @ 99950.00'`.
#
# > 💡 Patrón: `f"{side.upper()} ... {price:.2f}"`. Las llaves no se imprimen: se sustituyen por el resultado de cada expresión.
#
# <sub>practicas: f-strings con formato</sub>

# %%
side = 'buy'
size = 0.5
symbol = 'BTCUSDT'
price = 99950
ticket = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert ticket is not None, '⏸ ticket sigue en None: completa el ejercicio antes de validar'
assert ticket == 'BUY 0.5 BTCUSDT @ 99950.00'
print('ok ->', ticket)

# %% [markdown]
# <a id="L01-A18"></a>
#
# ### A18. Lee con red
#
# <sub>🔵 REQUIRED · consolidación requerida · ~2 min</sub>
#
# **Por qué lo hacemos.** Una posición ausente puede representar cero en este registro de cartera. Distingue esa convención de una clave obligatoria como price en B05: un default no debe ocultar datos de orden incompletos.
#
# **Tu tarea.** `dict.get(clave, default)` devuelve el valor si la clave existe y, si falta, devuelve el default en vez de lanzar `KeyError`. Guarda `btc_pos` y `eth_pos` con default 0: ETH todavía no existe.
#
# > 💡 Compara mentalmente: `positions['ETHUSDT']` fallaría; `positions.get('ETHUSDT', 0)` devuelve 0 sin modificar el dict.
#
# <sub>practicas: get con default</sub>

# %%
positions = {'BTCUSDT': 0.5}
btc_pos = None
eth_pos = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert btc_pos is not None, '⏸ btc_pos sigue en None: completa el ejercicio antes de validar'
assert eth_pos is not None, '⏸ eth_pos sigue en None: completa el ejercicio antes de validar'
assert btc_pos == 0.5
assert eth_pos == 0, 'get con default evita el KeyError'
print('ok')

# %% [markdown]
# <a id="L01-B06"></a>
#
# ### 6. Clasifica el mercado
#
# <sub>🟢 LIVE · núcleo presencial · ~4 min</sub>
#
# **Por qué lo hacemos.** El mismo cálculo puede llevar a decisiones diferentes. Escribe primero qué harías con spread pequeño, mediano y grande.
#
# **Tu tarea.** Según el `spread`, guarda `market_state`: `'tight'` si es ≤ 20, `'normal'` si es ≤ 60, y `'wide'` en cualquier otro caso.
#
# > 💡 Tres ramas: `if`, `elif`, `else`.
#
# <sub>practicas: if / elif / else</sub>

# %%
spread = 50
# Escribe el if / elif / else

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert market_state == 'normal', 'con spread 50 el mercado es normal'
print('ok ->', market_state)

# %% [markdown]
# <details>
# <summary>💭 Pista (antes de mirar la solución)</summary>
#
# El orden importa: comprueba primero `<= 20`, luego `elif <= 60`; el `else` recoge todo lo demás. En cada rama, una asignación a `market_state`.
#
# </details>

# %% [markdown]
# <a id="L01-B07"></a>
#
# ### 7. Tu primer algoritmo
#
# <sub>🟢 LIVE · núcleo presencial · ~6 min</sub>
#
# **Por qué lo hacemos.** Ahora conecta observación, cálculo y decisión. El objetivo es que puedas explicar cada paso del primer algoritmo, aunque todavía no ejecute órdenes.
#
# **Tu tarea.** Júntalo todo. Desde `bid`/`ask` calcula `spread`, `mid` y `market_state`, y decide: `action = 'buy'` si `mid <= 100000`, si no `'hold'`. El spread es el *estado*; el mid, tu *señal*.
#
# > 💡 Reutiliza lo de los ejercicios 2 y 6.
#
# <sub>practicas: dato → cálculo → decisión</sub>

# %%
bid = 99950
ask = 100000
# spread, mid, market_state y action

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert spread == 50 and mid == 99975.0
assert market_state == 'normal'
assert action == 'buy'
print('ok  decision ->', action)

# %% [markdown]
# <details>
# <summary>💭 Pista (antes de mirar la solución)</summary>
#
# Ve por capas: (1) `spread = ask - bid` y `mid = (bid + ask) / 2`; (2) copia el if/elif/else del ejercicio 6; (3) un segundo `if` para `action`, comparando `mid` con 100000.
#
# </details>

# %% [markdown]
# <a id="L01-A11"></a>
#
# ### A11. ¿Puedo operar?
#
# <sub>🔵 REQUIRED · consolidación requerida · ~2 min</sub>
#
# **Por qué lo hacemos.** Separa tener una señal de tener permiso para operar. Aunque B07 diga buy, una sola condición de seguridad falsa debe bloquear esta puerta lógica.
#
# **Tu tarea.** Solo operas si tienes caja, el mercado está abierto **y** el riesgo está OK. Calcula `can_trade`.
#
# <sub>practicas: and</sub>

# %%
has_cash = True
market_open = True
risk_ok = False
can_trade = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert can_trade is not None, '⏸ can_trade sigue en None: completa el ejercicio antes de validar'
assert can_trade is False, 'con risk_ok False no se opera: and exige que TODO sea True'
print('ok')

# %% [markdown]
# ## Cierre
#
# Un algoritmo es siempre lo mismo: dato <span class='dot'>→</span> cálculo <span class='dot'>→</span> decisión.
#
# Completa los LIVE y REQUIRED de este cuaderno y su construcción en tus archivos. El auxiliar contiene variantes OPTIONAL del mismo problema.
#
# En L2 conservaremos dato, cálculo y decisión, pero dejaremos de copiar fórmulas: una función recibirá órdenes y leerá el libro de un instrumento.
#
# ## Construcción principal: deja funcionando la siguiente pieza
#
# **REQUIRED · ~5 min de implementación e integración**, contabilizados por separado de los ejercicios de preparación anteriores. Abre los siguientes archivos de `student_project/exchange/` en tu carpeta de estudio. Completa los huecos reutilizando las ideas anteriores. El resto es andamiaje legible: puedes seguir sus llamadas hasta tus propias funciones.
#
# - `snapshot.py`: `spread`, `mid`
#
# Con bid=99 y ask=101 esperamos spread=2 y mid=100. Completa las dos asignaciones en snapshot.py. Cambia mentalmente ask a 103: ¿por qué spread sube dos unidades y mid solo una? Todavía no hace falta una función ni una clase.
#
# Los miniejercicios anteriores permiten aislar cada idea; este paso verifica que funciona con lo que construiste en las clases anteriores. No copies el paquete de referencia de `exercises/exchange/` sobre tu proyecto.
#
# Desde la raíz de tu carpeta de estudio ejecuta:
#
# ```bash
# python check_project.py 1
# ```
#
# Si falla una clase anterior, repara ese archivo: la siguiente utiliza tu implementación. La comprobación muestra la ruta real importada. Al actualizar el curso se añaden archivos nuevos y se conservan tus cambios.
#
# Antes de cerrar, explica qué dato entra, qué estado cambia y qué resultado te convencería de que la implementación es incorrecta.
