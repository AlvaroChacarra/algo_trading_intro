# %% [markdown]
# # Clase 1 · Construcción en clase
#
# Resuelve en el notebook: dos precios se convierten en spread y mid. Después ejecuta el mismo cálculo como un programa Python.
#
# Guarda una copia como **mi_principal.ipynb** aquí. Completa y ejecuta las celdas de arriba abajo con **Shift+Enter**. Compara las salidas con lo esperado. `None` o `pass` marcan una respuesta pendiente.
#
# Al terminar: **Restart Kernel and Run All Cells** para comprobar que no dependes de ejecuciones antiguas.

# %% [markdown]
# <a id="L01-P01"></a>
#
# ### Una foto del mercado
#
# Completa `spread` con la distancia ask − bid y `mid` con el promedio de ambos precios.
#
# Ejecuta la celda y observa los dos resultados. Después cambia `ask` a `103`: predice qué cambia y vuelve a ejecutar desde los datos.

# %%
bid = 99
ask = 101
spread = None
mid = None

# %%
print('spread:', spread)
print('mid:', mid)

# %% [markdown]
# **Resultado esperado:** `bid=99`, `ask=101` → spread `2`, mid `100`. Si ask pasa a `103` → spread `4`, mid `101`.

# %% [markdown]
# <details>
# <summary>Pista</summary>
#
# Calcula a partir de `bid` y `ask`. Agrupa la suma con paréntesis antes de dividir.
#
# </details>

# %% [markdown]
# ## El mismo ejercicio como programa
#
# El notebook sirve para investigar por partes. Un `.py` ejecuta un programa entero y permite reutilizar funciones.
#
# Copia **main.py** como **mi_main.py** aquí y traslada las mismas respuestas. `main()` reúne las llamadas; la condición final lo inicia al ejecutar el archivo. Lo estudiaremos en L3.
#
# Desde esta carpeta `exercises`:
#
# ```bash
# python mi_main.py
# ```
#
# Deben salir los mismos resultados. El notebook ya cubre el ejercicio.
#
# En L2 seleccionarás precios entre varias órdenes con las listas, bucles y diccionarios explicados en la presentación. El auxiliar ofrece práctica voluntaria.
