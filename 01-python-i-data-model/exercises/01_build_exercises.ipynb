# %% [markdown]
# # Clase 1 · Construcción en clase
#
# Calcula spread y mid. Después completa el bucle guiado que resume y clasifica dos quotes.
#
# Guarda una copia como **mi_principal.ipynb** aquí. Completa y ejecuta las celdas de arriba abajo con **Shift+Enter**. Compara las salidas con lo esperado. Los huecos pendientes están marcados; `None` también puede representar un dato ausente.
#
# Al terminar: **Restart Kernel and Run All Cells** para comprobar que no dependes de ejecuciones antiguas.

# %% [markdown]
# <a id="L01-P01"></a>
#
# ### Una foto del mercado
#
# 1. Completa `spread` y `mid` a partir de `bid` y `ask`. Predice qué cambia si ask pasa a 103; prueba y vuelve a los datos iniciales.
#
# 2. El bucle ya recorre dos diccionarios `quote`. Completa los cálculos y las etiquetas: spread ≤ 2 es `"estrecho"`; si no, `"amplio"`. `append` añade un resumen a `results` en cada vuelta.
#
# No necesitas definir funciones. Compara los dos resúmenes y ejecuta todas las celdas desde un kernel nuevo.

# %%
bid = 99
ask = 101
quotes = [
    {"bid": 99, "ask": 101},
    {"bid": 99, "ask": 103},
]
spread = None  # pendiente
mid = None  # pendiente

results = []
for quote in quotes:
    quote_spread = None  # pendiente
    quote_mid = None  # pendiente
    if quote["ask"] - quote["bid"] <= 2:
        state = None  # etiqueta pendiente
    else:
        state = None  # etiqueta pendiente
    results.append({"spread": quote_spread, "mid": quote_mid, "state": state})

# %%
print('spread:', spread)
print('mid:', mid)
print('resúmenes:', results)

# %% [markdown]
# **Resultado esperado:** `99/101` → spread `2`, mid `100`. Resúmenes de las dos quotes: `2, 100, estrecho` y `4, 101, amplio`. Al cambiar un dato, ejecuta desde el inicio.

# %% [markdown]
# <details>
# <summary>Pista</summary>
#
# Primero calcula con bid y ask. En el bucle, quote es cada diccionario y results.append(...) conserva un resumen por vuelta.
#
# </details>

# %% [markdown]
# ## El mismo ejercicio como programa
#
# El notebook sirve para investigar por partes. Un `.py` ejecuta un programa entero y permite reutilizar funciones.
#
# Copia **main.py** como **mi_main.py** aquí y traslada las mismas respuestas. `main()` reúne las llamadas; la condición final lo inicia al ejecutar el archivo. Lo estudiaremos en L3.
#
# Desde esta carpeta `exercises`:
#
# ```bash
# python mi_main.py
# ```
#
# Deben salir los mismos resultados. El notebook ya cubre el ejercicio.
#
# En L2 aplicarás listas, diccionarios y bucles a órdenes de compra y venta; una función seleccionará sus mejores precios.
