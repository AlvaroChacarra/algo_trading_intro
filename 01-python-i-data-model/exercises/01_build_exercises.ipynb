# %% [markdown]
# # Clase 1 · Tu proyecto
#
# Partimos de dos precios. Hoy guardas su distancia y su punto medio: serán las primeras lecturas de tu sistema.

# %% [markdown]
# <a id="L01-P01"></a>
#
# ### Una foto del mercado
#
# Abre [snapshot.py](../../student_project/exchange/snapshot.py). Conserva `bid=99` y `ask=101`.
#
# Completa `spread` con la distancia ask − bid y `mid` con el promedio de ambos precios. Esperamos `spread=2` y `mid=100`.
#
# Antes de ejecutar: si ask fuese 103, ¿cuánto cambiaría cada resultado?
#
# <details><summary>Pista</summary>
#
# Una variable guarda un valor. Calcula a partir de `bid` y `ask`; agrupa la suma con paréntesis antes de dividir.
#
# </details>
#
# Guarda el archivo y ejecuta la comprobación siguiente con **Shift+Enter**.

# %%
from practice_checks import comprobar_proyecto
comprobar_proyecto(1)

# %% [markdown]
# En L2 pasarás de una quote fija a leer varias órdenes. Antes, practica listas, bucles y diccionarios en el auxiliar.
