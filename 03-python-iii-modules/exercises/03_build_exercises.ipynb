# %% [markdown]
# # 🐍 Clase 3 · Python III — Módulos y errores
#
# > Sacar las funciones del libro del notebook y meterlas en un módulo .py reutilizable que puedes importar desde otro archivo. Y blindarlo: que un libro vacío no lo reviente.
#
# **Hoy construyes:** tu order_book.py se vuelve un módulo importable y robusto.

# %% [markdown]
# ### Cómo funciona este cuaderno
#
# 1. Escribe tu respuesta en la celda de código.
# 2. Debajo hay una **✅ comprobación plegada**: ejecútala con `Shift+Enter` para validarte (despliégala si quieres ver el `assert`).
# 3. ¿Atascado? Abre **💡 Ver solución**.
#
# **Núcleo:** los primeros (en clase) · **Si vamos bien:** el resto · **Más:** el cuaderno de auxiliares.

# %% [markdown]
# ### 1. Importa una función del módulo
#
# Importa `imbalance` desde el módulo `order_book` y úsala sobre `book`. Guarda el resultado en `imb`.
#
# > 💡 `from order_book import imbalance`.
#
# <sub>practicas: from ... import</sub>

# %%
book = [{'side':'buy','size':3},{'side':'sell','size':1}]
imb = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert imb is not None, '⏸ imb sigue en None: completa el ejercicio antes de validar'
assert abs(imb - 0.5) < 1e-9, 'imbalance de ese libro es 0.5'
print('ok  imb=%.2f' % imb)

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# from order_book import imbalance
# imb = imbalance(book)
# ```
#
# </details>

# %% [markdown]
# ### 2. Importa el módulo entero
#
# Importa el módulo `order_book` completo y calcula el spread del libro con `order_book.spread(book)`. Guarda `sp`.
#
# > 💡 `import order_book` y luego `order_book.spread(book)`.
#
# <sub>practicas: import módulo</sub>

# %%
book = [{'side':'buy','price':100},{'side':'sell','price':102}]
sp = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert sp is not None, '⏸ sp sigue en None: completa el ejercicio antes de validar'
assert sp == 2, 'spread debe ser 2'
print('ok  sp=%d' % sp)

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# import order_book
# sp = order_book.spread(book)
# ```
#
# </details>

# %% [markdown]
# ### 3. Blinda con try/except
#
# Escribe `safe_best_bid(book)` que devuelva el mejor bid, o `None` si el libro no tiene compras (best_bid revienta con `ValueError`).
#
# > 💡 Llama a `order_book.best_bid` dentro de un `try`.
#
# <sub>practicas: manejo de errores</sub>

# %%
import order_book

def safe_best_bid(book):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert safe_best_bid([]) is None, 'libro vacío -> None'
assert safe_best_bid([{'side':'buy','price':100}]) == 100
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# import order_book
#
# def safe_best_bid(book):
#     try:
#         return order_book.best_bid(book)
#     except ValueError:
#         return None
# ```
#
# </details>

# %% [markdown]
# ### 4. Lanza un error claro
#
# Escribe `check_size(size)` que devuelva `size` si es positivo, y lance `ValueError` si es <= 0.
#
# <sub>practicas: raise</sub>

# %%
def check_size(size):
    pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert check_size(0.1) == 0.1
try:
    check_size(-1); raise SystemExit('deberia fallar')
except ValueError:
    pass
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def check_size(size):
#     if size <= 0:
#         raise ValueError('size debe ser positivo')
#     return size
# ```
#
# </details>

# %% [markdown]
# ### 5. Combina funciones del módulo
#
# Usando `best_bid` y `best_ask` del módulo, calcula el `mid` del libro a mano. Guarda `mid`.
#
# > 💡 `from order_book import best_bid, best_ask`.
#
# <sub>practicas: usar varias del módulo</sub>

# %%
book = [{'side':'buy','price':100},{'side':'sell','price':102}]
mid = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert mid is not None, '⏸ mid sigue en None: completa el ejercicio antes de validar'
assert mid == 101
print('ok  mid=%d' % mid)

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# from order_book import best_bid, best_ask
# mid = (best_bid(book) + best_ask(book)) / 2
# ```
#
# </details>

# %% [markdown]
# ### 6. Construye y lee un libro con el módulo
#
# Con `order_book`, monta un libro (compra 99980/0.10, compra 99990/0.20, venta 100010/0.15) y léelo: guarda `bb = best_bid`, `sp = spread`, `imb = imbalance`.
#
# <sub>practicas: juntar el módulo</sub>

# %%
import order_book
book = []
# usa order_book.make_order / add_order y luego lee bb, sp, imb

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert bb == 99990 and sp == 20
assert abs(imb - 1/3) < 1e-9
print('ok  ->', bb, sp, round(imb,3))

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# import order_book
# book = []
# order_book.add_order(book, order_book.make_order('BTCUSDT','buy',99980,0.10))
# order_book.add_order(book, order_book.make_order('BTCUSDT','buy',99990,0.20))
# order_book.add_order(book, order_book.make_order('BTCUSDT','sell',100010,0.15))
# bb = order_book.best_bid(book)
# sp = order_book.spread(book)
# imb = order_book.imbalance(book)
# ```
#
# </details>

# %% [markdown]
# ## Cierre
#
# Tu código deja de vivir en celdas: se vuelve una librería que importas. Y una librería de verdad no se cae con un dato raro.
#
# Si llegas al ejercicio 3 ya tienes el núcleo. Los siguientes y los auxiliares consolidan.
#
# **Siguiente clase:** seguimos construyendo el motor sobre esta pieza.

# %% [markdown]
# ## 🚀 Llévatelo a un `.py`
#
# Un notebook va genial para explorar, pero el código de verdad vive en archivos `.py` que se ejecutan enteros de una vez. Abre **`main.py`**: es lo que acabas de construir, ordenado y de una pieza.
#
# Ejecútalo desde una terminal:
#
# ```bash
# python main.py
# ```
#
# …o aquí mismo, en la siguiente celda:

# %%
# !python main.py

# %% [markdown]
# > En la **clase 4** este código dará el salto a **clases** (POO): el mismo código, mejor organizado.
