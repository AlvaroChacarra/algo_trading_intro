# %% [markdown]
# # Clase 3 · Tu proyecto
#
# Continúas con tu función de L2. Hoy la importas para describir el mercado sin copiar su código.

# %% [markdown]
# <a id="L03-P01"></a>
#
# ### Reutilizar tu módulo
#
# Abre [application.py](../../student_project/exchange/application.py). Completa `describe(orders)` usando el `best_prices` que importas de tu archivo de L2.
#
# Devuelve un diccionario con `mid` y `spread`. Si falta algún lado, ambos valores deben ser `None`.
#
# Una compra a 98 y una venta a 102 → `{'mid': 100, 'spread': 4}`. Solo una compra → `{'mid': None, 'spread': None}`.
#
# <details><summary>Pista</summary>
#
# `bid, ask = best_prices(orders)` recoge los dos resultados. Comprueba los `None` antes de hacer aritmética. La demo bajo `if __name__ == '__main__':` se ejecuta al lanzar el archivo; importar solo proporciona sus funciones.
#
# </details>
#
# Guarda el archivo y ejecuta la comprobación siguiente con **Shift+Enter**.

# %%
from practice_checks import comprobar_proyecto
comprobar_proyecto(3)

# %% [markdown]
# En L4 darás estado y métodos a las órdenes y ejecuciones.
