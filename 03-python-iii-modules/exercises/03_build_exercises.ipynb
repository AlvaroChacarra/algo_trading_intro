# %% [markdown]
# # Clase 3 · Construcción en clase
#
# Reutiliza tu best_prices de L2 en este notebook y añade describe. Después lleva ambas funciones a un módulo .py que puedas ejecutar e importar.
#
# Guarda una copia como **mi_principal.ipynb** aquí. Completa y ejecuta las celdas de arriba abajo con **Shift+Enter**. Compara las salidas con lo esperado. `None` o `pass` marcan una respuesta pendiente.
#
# Al terminar: **Restart Kernel and Run All Cells** para comprobar que no dependes de ejecuciones antiguas.

# %% [markdown]
# <a id="L03-P01"></a>
#
# ### Reutilizar tu módulo
#
# Pega tu función `best_prices` de L2 en el hueco indicado y completa `describe(orders)` usando esa función.
#
# Devuelve un diccionario con `mid` y `spread`, aplicando las fórmulas de L1 al par recibido. Si falta algún lado, ambos valores serán `None`.
#
# Ejecuta los cuatro casos. Al terminar, llevarás estas mismas funciones a `mi_main.py`: el notebook permite investigar por celdas; el archivo permite ejecutar el programa e importar sus funciones.

# %%
orders = [
    {'side': 'buy', 'price': 98, 'size': 1},
    {'side': 'sell', 'price': 103, 'size': 2},
    {'side': 'buy', 'price': 99, 'size': 4},
    {'side': 'sell', 'price': 101, 'size': 1},
]
# Sustituye esta función por TU best_prices del notebook de L2.
def best_prices(orders):
    pass

def describe(orders):
    # Usa best_prices y devuelve las dos métricas.
    pass

# %%
print('ambos lados:', describe(orders))
print('solo compras:', describe([{'side': 'buy', 'price': 99}]))
print('solo ventas:', describe([{'side': 'sell', 'price': 101}]))
print('vacío:', describe([]))

# %% [markdown]
# **Resultado esperado:** Ambos lados: `{'mid': 100, 'spread': 2}`. En los otros tres casos: `{'mid': None, 'spread': None}`.

# %% [markdown]
# <details>
# <summary>Pista</summary>
#
# `bid, ask = best_prices(orders)` recoge el par. Comprueba los `None` antes de calcular; devuelve las mismas dos claves en ambos caminos.
#
# </details>

# %% [markdown]
# ## El mismo ejercicio como programa
#
# El notebook sirve para investigar por partes. Un `.py` ejecuta un programa entero y permite reutilizar funciones.
#
# Copia **main.py** como **mi_main.py** aquí y traslada las mismas respuestas. `main()` reúne las llamadas; la condición final lo inicia al ejecutar el archivo. Lo estudiaremos en L3.
#
# Desde esta carpeta `exercises`:
#
# ```bash
# python mi_main.py
# ```
#
# Deben salir los mismos resultados. El notebook ya cubre el ejercicio.
#
# Reutiliza tu archivo con `from mi_main import describe`: importar no arranca `main()`. Si modificas el archivo después de importarlo, reinicia el kernel.
#
# En L4 representarás órdenes y ejecuciones como objetos, conservando la separación entre datos válidos y funciones reutilizables.
