# %% [markdown]
# # Clase 14 — Auxiliares · el gimnasio
#
# 10 ejercicios cortos sobre *Avellaneda-Stoikov — modelo y simulación*: drills para ganar soltura con las primitivas y profundizaciones opcionales.
#
# ⏱️ 🟢 núcleo ~6 min · 🔵 si vamos bien +6 min · 🟣 bonus +15 min.

# %% [markdown]
# ### El gimnasio
#
# Drills cortos para automatizar las primitivas de Python con datos de mercado, más una profundización final. Mismo formato de siempre: escribe tu código, ejecuta la **✅ comprobación plegada** (`Shift+Enter`) y, si te atascas, abre **💡 Ver solución**. Ninguno debería llevarte más de un par de minutos. No hacen falta para seguir el curso — pero te hacen rápido.
#
# **Dosis mínima** = todo lo marcado **🟢 núcleo**: el calentamiento entero y los dos primeros drills de cada bloque. Lo **🔵 si vamos bien** y lo **🟣 bonus**, para volver otro día.

# %% [markdown]
# ---
#
# ## 🏋️ Gimnasio · Calentamiento — repaso exprés de L13
#
# Reservation y la vuelta completa, antes del modelo.

# %% [markdown]
# ### C1. Reservation exprés
#
# <sub>🟢 núcleo · ~1 min</sub>
#
# mid 100, skew 2.0, inventario +0.4 → calcula `r`.
#
# <sub>practicas: repaso: skew naive</sub>

# %%
r = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert r is not None, '⏸ r sigue en None: completa el ejercicio antes de validar'
assert abs(r - 99.2) < 1e-9
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# r = 100 - 2.0 * 0.4
# ```
#
# </details>

# %% [markdown]
# ### C2. La vuelta exprés
#
# <sub>🟢 núcleo · ~1 min</sub>
#
# Bid 99.4 y ask 100.6, tamaño 0.2 por lado, ida y vuelta completa → `ganancia`.
#
# <sub>practicas: repaso: el spread cobrado</sub>

# %%
ganancia = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert ganancia is not None, '⏸ ganancia sigue en None: completa el ejercicio antes de validar'
assert abs(ganancia - 0.24) < 1e-9
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# ganancia = (100.6 - 99.4) * 0.2
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## 🏋️ Gimnasio · Bloque 1 — Las fórmulas, con las manos
#
# Reservation, optimal spread y el papel de cada letra.

# %% [markdown]
# ### A1. Reservation A-S a mano
#
# <sub>🟢 núcleo · ~2 min</sub>
#
# Con mid=100, q=1, γ=0.5, σ=0.5 y τ=1, calcula `r`.
#
# <sub>practicas: r = mid − q·γ·σ²·τ</sub>

# %%
r = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert r is not None, '⏸ r sigue en None: completa el ejercicio antes de validar'
assert abs(r - 99.875) < 1e-9
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# r = 100 - 1 * 0.5 * 0.5**2 * 1
# ```
#
# </details>

# %% [markdown]
# ### A2. Optimal spread a mano
#
# <sub>🟢 núcleo · ~2 min</sub>
#
# Con γ=0.5, σ=0.5, τ=1 y κ=1.5, calcula `d` (usa `math.log`).
#
# <sub>practicas: δ = γσ²τ + (2/γ)ln(1+γ/κ)</sub>

# %%
import math
d = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert d is not None, '⏸ d sigue en None: completa el ejercicio antes de validar'
assert abs(d - 1.2757) < 1e-3
print(f'ok  d={d:.4f}')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# gamma, sigma, tau, kappa = 0.5, 0.5, 1, 1.5
# d = gamma * sigma**2 * tau + (2 / gamma) * math.log(1 + gamma / kappa)
# ```
#
# </details>

# %% [markdown]
# ### A3. γ manda en el miedo
#
# <sub>🔵 si vamos bien · ~2 min</sub>
#
# Con q=1, σ=0.5, τ=1: calcula el desplazamiento del reservation (|mid−r|) para γ=0.1 y γ=1.0. Guarda `shift_g01`, `shift_g10` y `mas_miedo_mas_skew` (True/False).
#
# <sub>practicas: sensibilidad al inventario</sub>

# %%
shift_g01 = None
shift_g10 = None
mas_miedo_mas_skew = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert shift_g01 is not None, '⏸ shift_g01 sigue en None: completa el ejercicio antes de validar'
assert shift_g10 is not None, '⏸ shift_g10 sigue en None: completa el ejercicio antes de validar'
assert mas_miedo_mas_skew is not None, '⏸ mas_miedo_mas_skew sigue en None: completa el ejercicio antes de validar'
assert abs(shift_g01 - 0.025) < 1e-9
assert abs(shift_g10 - 0.25) < 1e-9
assert mas_miedo_mas_skew is True
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# shift_g01 = 1 * 0.1 * 0.25 * 1
# shift_g10 = 1 * 1.0 * 0.25 * 1
# mas_miedo_mas_skew = shift_g10 > shift_g01
# ```
#
# </details>

# %% [markdown]
# ### A4. El reloj lo apaga
#
# <sub>🔵 si vamos bien · ~2 min</sub>
#
# Crea un `AvellanedaStoikov(horizon=100)`, ponle inventario +1 y avanza su reloj hasta el final (`mm._t = 100`). Comprueba que `reservation_price(100.0)` vuelve al mid.
#
# <sub>practicas: τ = 0</sub>

# %%
from exchange.strategies.market_maker import AvellanedaStoikov
mm = AvellanedaStoikov('SIM', gamma=0.5, sigma=0.5, horizon=100)
mm._inventory = 1.0
r_final = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert r_final is not None, '⏸ r_final sigue en None: completa el ejercicio antes de validar'
assert abs(r_final - 100.0) < 1e-9, 'tau=0 apaga el termino de inventario'
print('ok — se acabo el partido, suelta el skew')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# mm._t = 100
# r_final = mm.reservation_price(100.0)
# ```
#
# </details>

# %% [markdown]
# ### A5. El barrido de γ, tuyo
#
# <sub>🔵 si vamos bien · ~2 min</sub>
#
# Corre `MMSimulation` (50 pasos, seed=3) con γ=0.1 y γ=1.0 y guarda `(inv_low, inv_high)`: el inventario máximo de cada una. ¿Quién controla más?
#
# <sub>practicas: la frontera riesgo/retorno</sub>

# %%
from exchange.simulation import MMSimulation
from exchange.strategies.market_maker import AvellanedaStoikov

def corre(gamma):
    mm = AvellanedaStoikov('SIM', quote_size=0.1, gamma=gamma, sigma=0.5, horizon=50)
    return MMSimulation(mm, steps=50, seed=3).run()
inv_low = None
inv_high = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert inv_low is not None, '⏸ inv_low sigue en None: completa el ejercicio antes de validar'
assert inv_high is not None, '⏸ inv_high sigue en None: completa el ejercicio antes de validar'
assert inv_low >= inv_high, 'mas gamma = menos inventario maximo (o igual)'
print(f'ok  g=0.1 -> {inv_low:.2f} | g=1.0 -> {inv_high:.2f}')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# inv_low = corre(0.1).max_inventory
# inv_high = corre(1.0).max_inventory
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## 🏋️ Para terminar — profundización
#
# El decaimiento temporal completo y TU market maker — la plantilla del examen.

# %% [markdown]
# ### A6. El tiempo apaga el ajuste
#
# <sub>🟣 bonus · ~5 min</sub>
#
# El término de inventario se hace 0 al cierre. Guarda `r_start` (t=0) y `r_end` (t=horizon) con inventario 5: r_end debe estar más cerca del mid.
#
# <sub>practicas: decaimiento temporal</sub>

# %%
from exchange.strategies import AvellanedaStoikov
r_start = None
r_end = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert r_start is not None, '⏸ r_start sigue en None: completa el ejercicio antes de validar'
assert r_end is not None, '⏸ r_end sigue en None: completa el ejercicio antes de validar'
assert abs(r_end - 100) < abs(r_start - 100), 'al cierre, r vuelve al mid'
print('ok  r_start=%.2f r_end=%.2f' % (r_start, r_end))

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# from exchange.strategies import AvellanedaStoikov
# s = AvellanedaStoikov('BTC', gamma=0.1, sigma=10, kappa=1.5, horizon=500)
# s._inventory = 5
# s._t = 0;   r_start = s.reservation_price(100)
# s._t = 500; r_end = s.reservation_price(100)
# ```
#
# </details>

# %% [markdown]
# ### A7. Tu propio market maker
#
# <sub>🟣 bonus · ~5 min</sub>
#
# Crea `FlatMaker(MarketMaker)` que cotice siempre simétrico al mid (sin skew): override `reservation_price` para devolver el mid. Simúlalo y guarda `max_inv`.
#
# <sub>practicas: subclasear MarketMaker</sub>

# %%
from exchange.strategies import MarketMaker
from exchange.simulation import MMSimulation
class FlatMaker(MarketMaker):
    def reservation_price(self, mid):
        pass
max_inv = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert FlatMaker.reservation_price.__code__.co_consts != (None,), '⏸ implementa FlatMaker.reservation_price: su cuerpo sigue siendo pass'
assert max_inv is not None
print('ok — has escrito tu propia estrategia y la has enchufado al simulador')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# from exchange.strategies import MarketMaker
# from exchange.simulation import MMSimulation
# class FlatMaker(MarketMaker):
#     def reservation_price(self, mid):
#         return mid
# max_inv = MMSimulation(FlatMaker('BTC', half_spread=0.3), steps=400).run().max_inventory
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## 🏋️ Transferencia — la misma idea, otro dominio
#
# La γ de Avellaneda-Stoikov es aversión al riesgo: cuánto castigas la incertidumbre. Esa misma idea es la que decide cuánto pagarías por un seguro. Sin mercado, misma fórmula.

# %% [markdown]
# ### T1. Cuánto pagas por dormir tranquilo (la γ, fuera del mercado)
#
# <sub>🟣 bonus · ~5 min</sub>
#
# El reservation price de A-S es `mid − γ·(riesgo)`: al valor justo le restas un castigo proporcional a tu aversión γ. En seguros es idéntico: el **equivalente de certeza** de una apuesta incierta es `media − γ·varianza`. Escribe `equiv_certeza(media, gamma, var)` y guarda `barato` (γ=0.1) y `caro` (γ=2.0) para media 100 y varianza 30. El más averso al riesgo la valora MÁS bajo (y por tanto pagaría más por asegurarse).
#
# <sub>practicas: aversión al riesgo fuera del trading</sub>

# %%
def equiv_certeza(media, gamma, var):
    pass
barato = None
caro = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert barato is not None, '⏸ barato sigue en None: completa el ejercicio antes de validar'
assert caro is not None, '⏸ caro sigue en None: completa el ejercicio antes de validar'
assert equiv_certeza.__code__.co_consts != (None,), '⏸ implementa equiv_certeza: su cuerpo sigue siendo pass'
assert abs(equiv_certeza(100, 0.1, 30) - 97) < 1e-9
assert caro < barato, 'más aversión (γ alta) = valoras más bajo lo incierto = pagas más por el seguro'
print('ok — la γ de Avellaneda-Stoikov era aversión al riesgo; el seguro usa la misma resta')

# %% [markdown]
# <details>
# <summary>💭 Pista (antes de mirar la solución)</summary>
#
# La función es una sola resta: `return media - gamma * var`. Es la misma forma que `reservation_price = mid - gamma * sigma**2 * inventory`, con `var` haciendo de riesgo.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# def equiv_certeza(media, gamma, var):
#     return media - gamma * var
# barato = equiv_certeza(100, 0.1, 30)
# caro = equiv_certeza(100, 2.0, 30)
# ```
#
# </details>

# %% [markdown]
# ## Fin de los auxiliares
#
# Vuelve al cuaderno principal cuando quieras.
