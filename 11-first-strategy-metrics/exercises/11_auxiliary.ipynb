# %% [markdown]
# # Clase 11 — Auxiliares · el gimnasio
#
# 8 ejercicios cortos sobre *Primera estrategia + métricas*: drills para ganar soltura con las primitivas y profundizaciones opcionales.

# %% [markdown]
# ### El gimnasio
#
# Drills cortos para automatizar las primitivas de Python con datos de mercado, más una profundización final. Mismo formato de siempre: escribe tu código, ejecuta la **✅ comprobación plegada** (`Shift+Enter`) y, si te atascas, abre **💡 Ver solución**. Ninguno debería llevarte más de un par de minutos. No hacen falta para seguir el curso — pero te hacen rápido.
#
# **Dosis mínima:** el calentamiento entero + los dos primeros drills de cada bloque. El resto, para volver otro día.

# %% [markdown]
# ---
#
# ## 🏋️ Gimnasio · Calentamiento — repaso exprés de L10
#
# El contrato y el resultado del runner, en dos reps.

# %% [markdown]
# ### C1. Contrato exprés
#
# Escribe `Hold(Strategy)` (devuelve `[]`) e instánciala en `h`.
#
# <sub>practicas: repaso: Strategy</sub>

# %%
from exchange.strategy import Strategy
h = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert h.on_book_update(None) == []
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# class Hold(Strategy):
#     def on_book_update(self, book):
#         return []
#
# h = Hold()
# ```
#
# </details>

# %% [markdown]
# ### C2. Leer el resultado
#
# De un run de Hold, guarda `pasos` y `n_fills`.
#
# <sub>practicas: repaso: BacktestResult</sub>

# %%
from exchange.backtest import Backtest
from exchange.market import Market
from exchange.strategy import Strategy
class Hold(Strategy):
    def on_book_update(self, book):
        return []
result = Backtest(Market.sample(), Hold()).run()
pasos = None
n_fills = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert pasos == 500 and n_fills == 0
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# pasos = result.n_steps
# n_fills = result.n_fills
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## 🏋️ Gimnasio · Bloque 1 — Medir con criterio
#
# Arrival, slippage y benchmarks: la caja de herramientas del juicio.

# %% [markdown]
# ### A1. El arrival mid
#
# Guarda `arrival`: el mid del PRIMER snapshot (el precio que viste al decidir empezar).
#
# <sub>practicas: el benchmark de llegada</sub>

# %%
from exchange.market import Market
m = Market.sample()
arrival = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
m2 = Market.sample()
assert abs(arrival - m2.step().mid) < 1e-9
print(f'ok  arrival={arrival}')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# arrival = m.step().mid
# ```
#
# </details>

# %% [markdown]
# ### A2. Slippage de un fill
#
# Compra a 100024.5 con mid 100000; venta a 99980 con mid 100000. Calcula `slip_buy` y `slip_sell` (positivo = te costó dinero).
#
# <sub>practicas: con el signo correcto</sub>

# %%
slip_buy = None
slip_sell = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(slip_buy - 24.5) < 1e-9, 'compra: precio - mid'
assert abs(slip_sell - 20.0) < 1e-9, 'venta: mid - precio'
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# slip_buy = 100024.5 - 100000
# slip_sell = 100000 - 99980
# ```
#
# </details>

# %% [markdown]
# ### A3. El coste total de ejecutar
#
# Con `slips` (por unidad) y clip 0.05, calcula `coste = media × n × clip`.
#
# <sub>practicas: slippage agregado</sub>

# %%
slips = [5.2, 6.1, 4.8, 7.0, 5.9]
clip = 0.05
coste = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert abs(coste - 1.45) < 1e-6
print(f'ok  coste={coste}')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# media = sum(slips) / len(slips)
# coste = media * len(slips) * clip
# ```
#
# </details>

# %% [markdown]
# ### A4. ¿Fuera de la nube?
#
# Tu equity final fue `-27.3`; tres monos aleatorios hicieron `[5.4, -46.0, 8.6]`. Guarda `fuera` (True si tu resultado queda FUERA del rango de los monos).
#
# <sub>practicas: benchmark contra el azar</sub>

# %%
mi_equity = -27.3
monos = [5.4, -46.0, 8.6]
fuera = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert fuera is False, 'dentro del rango del azar: nada demostrado'
print('ok — humildad estadistica')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# fuera = mi_equity < min(monos) or mi_equity > max(monos)
# ```
#
# </details>

# %% [markdown]
# ### A5. PnL sin riesgo es media verdad
#
# Dos estrategias: A = (PnL 30, máx inventario 2.0), B = (PnL 24, máx inventario 0.4). Guarda `mejor_por_unidad` ('A' o 'B') según PnL por unidad de inventario máximo.
#
# <sub>practicas: comparar con inventario</sub>

# %%
pnl_a, inv_a = 30.0, 2.0
pnl_b, inv_b = 24.0, 0.4
mejor_por_unidad = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert mejor_por_unidad == 'B', '15 vs 60 de PnL por unidad de riesgo'
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# ratio_a = pnl_a / inv_a
# ratio_b = pnl_b / inv_b
# mejor_por_unidad = 'A' if ratio_a > ratio_b else 'B'
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## 🏋️ Para terminar — profundización
#
# La curva de equity completa, con tus propias manos.

# %% [markdown]
# ### A6. Curva de equity
#
# Corre la estrategia y guarda `curve = result.equity_curve`. Verifica que tiene 500 puntos. (En clase la dibujarías con matplotlib.)
#
# <sub>practicas: serie temporal de PnL</sub>

# %%
from exchange import Strategy, NewOrder, Order, Side, OrderType, Market, Backtest
class S(Strategy):
    def on_book_update(self, book):
        return [NewOrder(Order('BTCUSDT', Side.BUY, 0.01, order_type=OrderType.MARKET))]
curve = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert len(curve) == 500
print('ok  puntos=%d' % len(curve))

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# curve = Backtest(Market.sample(), S()).run().equity_curve
# ```
#
# </details>

# %% [markdown]
# ## Fin de los auxiliares
#
# Vuelve al cuaderno principal cuando quieras.
