# %% [markdown]
# # 🐍 Clase 4 · OOP I — Order y Fill
#
# > Convertir el dict de orden en una clase didáctica con métodos, modelar el resultado de un cruce y migrar sin ambigüedad a las firmas estables de Order y Fill del paquete exchange.
#
# **Hoy construyes:** OrderMini y FillMini como modelos didácticos; migración explícita a exchange.Order y exchange.Fill.
#
# ⏱️ 🟢 LIVE ~20 min · 🔵 REQUIRED +12 min.

# %% [markdown]
# ### Cómo funciona este cuaderno
#
# Cada ejercicio declara una ruta pedagógica, decidida por contenido y no por posición: **🟢 LIVE** (núcleo presencial) · **🔵 REQUIRED** (consolidación autónoma requerida y evaluable) · **🟣 OPTIONAL** (profundización no obligatoria y no evaluable). Escribe tu respuesta, ejecuta la **✅ comprobación plegada** con `Shift+Enter` y usa la pista o solución solo cuando la necesites.

# %% [markdown]
# ### 1. La clase Order
#
# <sub>🟢 LIVE · núcleo presencial · ~5 min</sub>
#
# Convierte el dict de orden en una clase didáctica. Define `OrderMini` con `__init__(self, symbol, side, price, size)` que guarde los 4 atributos. El sufijo `Mini` avisa de que aún no es la API pública estable de `exchange`.
#
# > 💡 `self` es el objeto que estás rellenando.
#
# <sub>practicas: class, __init__ y self</sub>

# %%
class OrderMini:
    def __init__(self, symbol, side, price, size):
        pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert OrderMini.__init__.__code__.co_consts != (None,), '⏸ implementa OrderMini.__init__: su cuerpo sigue siendo pass'
o = OrderMini('BTCUSDT','buy',100,0.5)
assert o.symbol=='BTCUSDT' and o.side=='buy' and o.price==100 and o.size==0.5
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# class OrderMini:
#     def __init__(self, symbol, side, price, size):
#         self.symbol = symbol
#         self.side = side
#         self.price = price
#         self.size = size
# ```
#
# </details>

# %% [markdown]
# ### 2. Un método: notional
#
# <sub>🟢 LIVE · núcleo presencial · ~5 min</sub>
#
# Antes tenías `compute_notional(order)`. Ahora la orden lo hace sola: añade el método `notional(self)` que devuelva `price * size`.
#
# <sub>practicas: el dato opera consigo mismo</sub>

# %%
class OrderMini:
    def __init__(self, symbol, side, price, size):
        self.symbol = symbol; self.side = side
        self.price = price; self.size = size
    def notional(self):
        pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert OrderMini.notional.__code__.co_consts != (None,), '⏸ implementa OrderMini.notional: su cuerpo sigue siendo pass'
o = OrderMini('X','buy',100,0.5)
assert abs(o.notional() - 50) < 1e-9
print('ok')

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# class OrderMini:
#     def __init__(self, symbol, side, price, size):
#         self.symbol = symbol; self.side = side
#         self.price = price; self.size = size
#     def notional(self):
#         return self.price * self.size
# ```
#
# </details>

# %% [markdown]
# ### 3. __repr__: que sepa describirse
#
# <sub>🟢 LIVE · núcleo presencial · ~5 min</sub>
#
# Añade `__repr__(self)` que devuelva, p.ej., `'OrderMini(buy 0.5 X @ 100)'`. Así el objeto se imprime legible.
#
# <sub>practicas: dunder methods</sub>

# %%
class OrderMini:
    def __init__(self, symbol, side, price, size):
        self.symbol=symbol; self.side=side; self.price=price; self.size=size
    def __repr__(self):
        pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert OrderMini.__repr__.__code__.co_consts != (None,), '⏸ implementa OrderMini.__repr__: su cuerpo sigue siendo pass'
o = OrderMini('X','buy',100,0.5)
assert repr(o) == 'OrderMini(buy 0.5 X @ 100)', repr(o)
print('ok')

# %% [markdown]
# <details>
# <summary>💭 Pista (antes de mirar la solución)</summary>
#
# Es un f-string que mezcla los cuatro atributos: `f'OrderMini({self.side} {self.size} {self.symbol} @ {self.price})'`. `__repr__` debe *devolverlo*, no imprimirlo.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# class OrderMini:
#     def __init__(self, symbol, side, price, size):
#         self.symbol=symbol; self.side=side; self.price=price; self.size=size
#     def __repr__(self):
#         return f'OrderMini({self.side} {self.size} {self.symbol} @ {self.price})'
# ```
#
# </details>

# %% [markdown]
# ### 4. La clase Fill y su cash_flow
#
# <sub>🟢 LIVE · núcleo presencial · ~5 min</sub>
#
# Cuando una orden se ejecuta, genera un fill. Define la versión didáctica `FillMini(symbol, side, price, size)` con `cash_flow()`: **negativo** si compras, **positivo** si vendes.
#
# <sub>practicas: segunda clase + signo</sub>

# %%
class FillMini:
    def __init__(self, symbol, side, price, size):
        pass
    def cash_flow(self):
        pass

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert FillMini.__init__.__code__.co_consts != (None,), '⏸ implementa FillMini.__init__: su cuerpo sigue siendo pass'
assert FillMini.cash_flow.__code__.co_consts != (None,), '⏸ implementa FillMini.cash_flow: su cuerpo sigue siendo pass'
assert abs(FillMini('X','buy',100,0.5).cash_flow() + 50) < 1e-9, 'compra -> -50'
assert abs(FillMini('X','sell',100,0.5).cash_flow() - 50) < 1e-9, 'venta -> +50'
print('ok')

# %% [markdown]
# <details>
# <summary>💭 Pista (antes de mirar la solución)</summary>
#
# En `__init__`, guarda los 4 argumentos en `self.<nombre>`. En `cash_flow`, calcula un `sign` (−1 si `self.side=='buy'`, +1 si no) y devuelve `sign * self.price * self.size`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# class FillMini:
#     def __init__(self, symbol, side, price, size):
#         self.symbol=symbol; self.side=side; self.price=price; self.size=size
#     def cash_flow(self):
#         sign = -1 if self.side=='buy' else 1
#         return sign * self.price * self.size
# ```
#
# </details>

# %% [markdown]
# ### 5. Instánciala y opérala
#
# <sub>🔵 REQUIRED · consolidación requerida · ~6 min</sub>
#
# Crea una `OrderMini` de compra (BTCUSDT, 100, 0.5). Guarda su `nocional` (`order.notional()`) y su `texto` (`repr(order)`).
#
# <sub>practicas: crear objetos y llamar métodos</sub>

# %%
class OrderMini:
    def __init__(self, symbol, side, price, size):
        self.symbol=symbol; self.side=side; self.price=price; self.size=size
    def notional(self):
        return self.price*self.size
    def __repr__(self):
        return f'OrderMini({self.side} {self.size} {self.symbol} @ {self.price})'
order = None
nocional = None
texto = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert order is not None, '⏸ order sigue en None: completa el ejercicio antes de validar'
assert nocional is not None, '⏸ nocional sigue en None: completa el ejercicio antes de validar'
assert texto is not None, '⏸ texto sigue en None: completa el ejercicio antes de validar'
assert isinstance(order, OrderMini)
assert abs(nocional - 50) < 1e-9
assert texto == 'OrderMini(buy 0.5 BTCUSDT @ 100)', texto
print('ok ', texto)

# %% [markdown]
# <details>
# <summary>💭 Pista (antes de mirar la solución)</summary>
#
# Instanciar es llamar a la clase: `OrderMini('BTCUSDT', 'buy', 100, 0.5)`. Los métodos se llaman con paréntesis (`order.notional()`); `repr(order)` usa tu `__repr__`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# order = OrderMini('BTCUSDT','buy',100,0.5)
# nocional = order.notional()
# texto = repr(order)
# ```
#
# </details>

# %% [markdown]
# ### 6. De la orden al dinero
#
# <sub>🔵 REQUIRED · consolidación requerida · ~6 min</sub>
#
# Modela una vuelta completa: compras 0.5 @ 100 y luego vendes 0.5 @ 110. Crea los dos `FillMini` y guarda `total_cash` = suma de sus `cash_flow()`.
#
# > 💡 Compra resta (-50), venta suma (+55) -> total +5.
#
# <sub>practicas: juntar Order, Fill y cash_flow</sub>

# %%
class FillMini:
    def __init__(self, symbol, side, price, size):
        self.symbol=symbol; self.side=side; self.price=price; self.size=size
    def cash_flow(self):
        return (-1 if self.side=='buy' else 1)*self.price*self.size
buy = None
sell = None
total_cash = None

# %%
# ✅ Comprobación — ejecútala (Shift+Enter). Está plegada a propósito.
assert buy is not None, '⏸ buy sigue en None: completa el ejercicio antes de validar'
assert sell is not None, '⏸ sell sigue en None: completa el ejercicio antes de validar'
assert total_cash is not None, '⏸ total_cash sigue en None: completa el ejercicio antes de validar'
assert abs(total_cash - 5.0) < 1e-9, 'compra -50, venta +55 -> +5'
print('ok  total_cash=%.1f' % total_cash)

# %% [markdown]
# <details>
# <summary>💭 Pista (antes de mirar la solución)</summary>
#
# Dos objetos: `FillMini('BTCUSDT','buy',100,0.5)` y el de venta a 110. `total_cash` suma las dos llamadas a `cash_flow()` — deben dar −50 y +55.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Ver solución</summary>
#
# ```python
# buy = FillMini('BTCUSDT','buy',100,0.5)
# sell = FillMini('BTCUSDT','sell',110,0.5)
# total_cash = buy.cash_flow() + sell.cash_flow()
# ```
#
# </details>

# %% [markdown]
# ## Cierre
#
# Un objeto empaqueta datos y comportamiento: la orden ya sabe calcular su nocional.
#
# Cada ejercicio lleva una ruta explícita: LIVE, REQUIRED u OPTIONAL. Sigue REQUIRED para el itinerario autónomo y elige OPTIONAL solo si tienes margen.
#
# **L5:** seguimos construyendo el sistema sobre esta pieza.

# %% [markdown]
# ## 🚀 Llévatelo a un `.py`
#
# Un notebook va genial para explorar, pero el código de verdad vive en archivos `.py` que se ejecutan enteros de una vez. Abre **`orders_demo.py`**: es lo que acabas de construir, ordenado y de una pieza.
#
# Ejecútalo desde una terminal:
#
# ```bash
# python orders_demo.py
# ```
#
# …o aquí mismo, en la siguiente celda:

# %%
# !python orders_demo.py

# %% [markdown]
# > Es la misma pieza que vive en el paquete `exchange/` — aquí, condensada en un archivo que puedes leer de una sentada.
